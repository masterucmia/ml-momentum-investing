# %%
# ====================================================================
# ================= SILVER OHLCV 1m (STATEFUL STREAMING) ==============
# ====================================================================

from pyspark.sql import SparkSession, Row
from pyspark.sql.functions import col, lag, when, log
from pyspark.sql.window import Window
from pyspark.sql.types import (
    StructType, StructField,
    TimestampType, StringType,
    DoubleType, IntegerType
)
import math

# %%
# =========================================================
# ================= SILVER OHLCV 1m (STREAMING) ===========
# =========================================================

from pyspark.sql import SparkSession, Row
from pyspark.sql.functions import (
    col, when, from_utc_timestamp, regexp_replace
)

# ================= CONFIG =================

bronze_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/bronze/activos"
silver_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/silver/activos"
checkpoint_path = silver_path + "/_checkpoint"

# ================= SPARK =================

spark = (
    SparkSession.builder
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

spark.conf.set("spark.sql.session.timeZone", "UTC")

# ================= DIMENSIÓN DE ACTIVOS =================
# symbol | asset_class | asset_name

asset_rows = [
    # Acciones
    Row("TSLA","Acciones","Tesla"),
    Row("NVDA","Acciones","Nvidia"),
    Row("AMD","Acciones","AMD"),
    Row("COIN","Acciones","Coinbase"),
    Row("PLTR","Acciones","Palantir"),
    Row("RIVN","Acciones","Rivian"),
    Row("SHOP","Acciones","Shopify"),
    Row("LCID","Acciones","Lucid Motors"),
    Row("ZM","Acciones","Zoom"),
    Row("SPCE","Acciones","Virgin Galactic"),
    Row("KO","Acciones","Coca Cola Company"),
    Row("PG","Acciones","Procter & Gamble"),
    Row("JNJ","Acciones","Johnson & Johnson"),
    Row("PEP","Acciones","PepsiCo"),
    Row("WMT","Acciones","Walmart"),
    Row("MCD","Acciones","McDonalds"),
    Row("VZ","Acciones","Verizon"),
    Row("DUK","Acciones","Duke Energy"),
    Row("UL","Acciones","Unilever"),
    Row("V","Acciones","VISA"),

    # Fondos
    Row("SPY","Fondos","SPDR S&P 500 ETF Trust"),
    Row("QQQ","Fondos","Invesco QQQ Trust"),
    Row("EEM","Fondos","iShares MSCI Emerging Markets ETF"),
    Row("VGK","Fondos","Vanguard FTSE Europe ETF"),
    Row("AGG","Fondos","iShares Core U.S. Aggregate Bond ETF"),
    Row("VNQ","Fondos","Vanguard Real Estate ETF"),
    Row("ARKK","Fondos","ARK Innovation ETF"),
    Row("VUG","Fondos","Vanguard Growth ETF"),
    Row("SCHD","Fondos","Schwab US Dividend Equity ETF"),
    Row("SOXX","Fondos","iShares Semiconductor ETF"),

    # Forex
    Row("EURUSD","Forex","Euro / Dólar"),
    Row("USDJPY","Forex","Dólar / Yen"),
    Row("GBPUSD","Forex","Libra / Dólar"),
    Row("USDCHF","Forex","Dólar / Franco Suizo"),
    Row("AUDUSD","Forex","Dólar Australiano / Dólar"),
    Row("USDCAD","Forex","Dólar / Dólar Canadiense"),
    Row("NZDUSD","Forex","Dólar Nueva Zelanda / Dólar"),
    Row("EURGBP","Forex","Euro / Libra"),
    Row("EURJPY","Forex","Euro / Yen"),
    Row("GBPJPY","Forex","Libra / Yen"),

    # Cripto
    Row("BTC-USD","Cripto","Bitcoin"),
    Row("ETH-USD","Cripto","Ethereum"),
    Row("BNB-USD","Cripto","Binance Coin"),
    Row("XRP-USD","Cripto","Ripple"),
    Row("SOL-USD","Cripto","Solana"),
    Row("TRX-USD","Cripto","Tron"),
    Row("DOGE-USD","Cripto","Dogecoin"),
    Row("ADA-USD","Cripto","Cardano"),
    Row("AVAX-USD","Cripto","Avalanche"),
    Row("LTC-USD","Cripto","Litecoin"),


    # Commodities
    Row("GLD","Commodities","Oro"),
    Row("SLV","Commodities","Plata"),
    Row("PPLT","Commodities","Platino"),
    Row("PALL","Commodities","Paladio"),
    Row("USO","Commodities","Petróleo"),
    Row("UNG","Commodities","Gas Natural"),
    Row("CORN","Commodities","Maiz"),
    Row("SOYB","Commodities","Soja"),
    Row("WEAT","Commodities","Trigo"),
    Row("CANE","Commodities","Azucar"),
]

asset_dim = spark.createDataFrame(
    asset_rows,
    ["symbol", "asset_class", "asset_name"]
)

# ================= FOREACH BATCH =================

def process_batch(df, batch_id):
    try:
        print(f"[SILVER] Procesando batch_id={batch_id}")

        df_clean = (
            df
            .dropDuplicates(["symbol", "timestamp"])
            .filter(col("timestamp").isNotNull())
            .filter(col("close").isNotNull())
            .filter(col("symbol").isNotNull())
            .filter(col("source").isNotNull())
        )

        # 🔹 LIMPIAR =X EN FOREX
        df_clean = df_clean.withColumn(
            "symbol",
            regexp_replace(col("symbol"), "=X$", "")
        )

        # 🔹 TIMESTAMP A EUROPE/MADRID
        df_clean = df_clean.withColumn(
            "timestamp",
            from_utc_timestamp(col("timestamp"), "Europe/Madrid")
        )

        if df_clean.rdd.isEmpty():
            print(f"[SILVER] batch_id={batch_id} vacío")
            return

        # 🔹 JOIN CON DIMENSIÓN DE ACTIVOS
        silver_df = (
            df_clean
            .join(asset_dim, on="symbol", how="left")
            .withColumn(
                "coste_opera_h",
                when(col("asset_class") == "Acciones", 0.01)
                .when(col("asset_class") == "Fondos", 0.0001)
                .when(col("asset_class") == "Forex", 0.0002)
                .when(col("asset_class") == "Cripto", 0.01)
                .when(col("asset_class") == "Commodities", 0.01)
                .otherwise(None)
            )
            .select(
                "timestamp",
                "symbol",
                "asset_class",
                "asset_name",
                "coste_opera_h",
                "open",
                "high",
                "low",
                "close",
                "volume",
                "timezone",
                "source",
                "year",
                "month",
                "day",
            )
        )


        silver_df.write \
            .format("delta") \
            .mode("append") \
            .partitionBy("year", "month", "day") \
            .save(silver_path)

        print(f"[SILVER] batch_id={batch_id} escrito correctamente")

    except Exception as e:
        print("🔥 ERROR REAL EN FOREACH BATCH 🔥")
        import traceback
        traceback.print_exc()
        raise e

# ================= STREAM =================

bronze_stream = (
    spark.readStream
    .format("delta")
    .option("ignoreDeletes", "true")
    .load(bronze_path)
)

query = (
    bronze_stream.writeStream
    .foreachBatch(process_batch)
    .option("checkpointLocation", checkpoint_path)
    .start()
)

query.awaitTermination()
# Out:
# [SILVER] Procesando batch_id=712
# [SILVER] batch_id=712 escrito correctamente
# [SILVER] Procesando batch_id=713
# [SILVER] batch_id=713 escrito correctamente
# [SILVER] Procesando batch_id=714
# [SILVER] batch_id=714 escrito correctamente
# [SILVER] Procesando batch_id=715
# [SILVER] batch_id=715 escrito correctamente
# [SILVER] Procesando batch_id=716
# [SILVER] batch_id=716 escrito correctamente
# [SILVER] Procesando batch_id=717
# [SILVER] batch_id=717 escrito correctamente
# [SILVER] Procesando batch_id=718
# [SILVER] batch_id=718 escrito correctamente
# [SILVER] Procesando batch_id=719
# [SILVER] batch_id=719 escrito correctamente
# [SILVER] Procesando batch_id=720
# [SILVER] batch_id=720 escrito correctamente
# [SILVER] Procesando batch_id=721
# [SILVER] batch_id=721 escrito correctamente
# [SILVER] Procesando batch_id=722
# [SILVER] batch_id=722 escrito correctamente
# [SILVER] Procesando batch_id=723
# [SILVER] batch_id=723 escrito correctamente
# [SILVER] Procesando batch_id=724
# [SILVER] batch_id=724 escrito correctamente
# [SILVER] Procesando batch_id=725
# [SILVER] batch_id=725 escrito correctamente
# [SILVER] Procesando batch_id=726
# [SILVER] batch_id=726 escrito correctamente
# [SILVER] Procesando batch_id=727
# [SILVER] batch_id=727 escrito correctamente
# [SILVER] Procesando batch_id=728
# [SILVER] batch_id=728 escrito correctamente
# [SILVER] Procesando batch_id=729
# [SILVER] batch_id=729 escrito correctamente
# [SILVER] Procesando batch_id=730
# [SILVER] batch_id=730 escrito correctamente
# [SILVER] Procesando batch_id=731
# [SILVER] batch_id=731 escrito correctamente
# [SILVER] Procesando batch_id=732
# [SILVER] batch_id=732 escrito correctamente
# [SILVER] Procesando batch_id=733
# [SILVER] batch_id=733 escrito correctamente
# [SILVER] Procesando batch_id=734
# [SILVER] batch_id=734 escrito correctamente
# [SILVER] Procesando batch_id=735
# [SILVER] batch_id=735 escrito correctamente
# [SILVER] Procesando batch_id=736
# [SILVER] batch_id=736 escrito correctamente
# [SILVER] Procesando batch_id=737
# [SILVER] batch_id=737 escrito correctamente
# [SILVER] Procesando batch_id=738
# [SILVER] batch_id=738 escrito correctamente
# [SILVER] Procesando batch_id=739
# [SILVER] batch_id=739 escrito correctamente
# [SILVER] Procesando batch_id=740
# [SILVER] batch_id=740 escrito correctamente
# [SILVER] Procesando batch_id=741
# [SILVER] batch_id=741 escrito correctamente
# [SILVER] Procesando batch_id=742
# [SILVER] batch_id=742 escrito correctamente
# [SILVER] Procesando batch_id=743
# [SILVER] batch_id=743 escrito correctamente
# [SILVER] Procesando batch_id=744
# [SILVER] batch_id=744 escrito correctamente
# [SILVER] Procesando batch_id=745
# [SILVER] batch_id=745 escrito correctamente
# [SILVER] Procesando batch_id=746
# [SILVER] batch_id=746 escrito correctamente
# [SILVER] Procesando batch_id=747
# [SILVER] batch_id=747 escrito correctamente
# [SILVER] Procesando batch_id=748
# [SILVER] batch_id=748 escrito correctamente
# [SILVER] Procesando batch_id=749
# [SILVER] batch_id=749 escrito correctamente
# [SILVER] Procesando batch_id=750
# [SILVER] batch_id=750 escrito correctamente
# [SILVER] Procesando batch_id=751
# [SILVER] batch_id=751 escrito correctamente
# [SILVER] Procesando batch_id=752
# [SILVER] batch_id=752 escrito correctamente
# [SILVER] Procesando batch_id=753
# [SILVER] batch_id=753 escrito correctamente
# [SILVER] Procesando batch_id=754
# [SILVER] batch_id=754 escrito correctamente
# [SILVER] Procesando batch_id=755
# [SILVER] batch_id=755 escrito correctamente
# [SILVER] Procesando batch_id=756
# [SILVER] batch_id=756 escrito correctamente
# [SILVER] Procesando batch_id=757
# [SILVER] batch_id=757 escrito correctamente
# [SILVER] Procesando batch_id=758
# [SILVER] batch_id=758 escrito correctamente
# [SILVER] Procesando batch_id=759
# [SILVER] batch_id=759 escrito correctamente
# [SILVER] Procesando batch_id=760
# [SILVER] batch_id=760 escrito correctamente
# [SILVER] Procesando batch_id=761
# [SILVER] batch_id=761 escrito correctamente
# [SILVER] Procesando batch_id=762
# [SILVER] batch_id=762 escrito correctamente
# [SILVER] Procesando batch_id=763
# [SILVER] batch_id=763 escrito correctamente
# [SILVER] Procesando batch_id=764
# [SILVER] batch_id=764 escrito correctamente
# [SILVER] Procesando batch_id=765
# [SILVER] batch_id=765 escrito correctamente
# [SILVER] Procesando batch_id=766
# [SILVER] batch_id=766 escrito correctamente
# [SILVER] Procesando batch_id=767
# [SILVER] batch_id=767 escrito correctamente
# [SILVER] Procesando batch_id=768
# [SILVER] batch_id=768 escrito correctamente
# [SILVER] Procesando batch_id=769
# [SILVER] batch_id=769 escrito correctamente
# [SILVER] Procesando batch_id=770
# [SILVER] batch_id=770 escrito correctamente
# [SILVER] Procesando batch_id=771
# [SILVER] batch_id=771 escrito correctamente
# [SILVER] Procesando batch_id=772
# [SILVER] batch_id=772 escrito correctamente
# [SILVER] Procesando batch_id=773
# [SILVER] batch_id=773 escrito correctamente
# [SILVER] Procesando batch_id=774
# [SILVER] batch_id=774 escrito correctamente
# [SILVER] Procesando batch_id=775
# [SILVER] batch_id=775 escrito correctamente
# [SILVER] Procesando batch_id=776
# [SILVER] batch_id=776 escrito correctamente
# [SILVER] Procesando batch_id=777
# [SILVER] batch_id=777 escrito correctamente
# [SILVER] Procesando batch_id=778
# [SILVER] batch_id=778 escrito correctamente
# [SILVER] Procesando batch_id=779
# [SILVER] batch_id=779 escrito correctamente
# [SILVER] Procesando batch_id=780
# [SILVER] batch_id=780 escrito correctamente
# [SILVER] Procesando batch_id=781
# [SILVER] batch_id=781 escrito correctamente
# [SILVER] Procesando batch_id=782
# [SILVER] batch_id=782 escrito correctamente
# [SILVER] Procesando batch_id=783
# [SILVER] batch_id=783 escrito correctamente
# [SILVER] Procesando batch_id=784
# [SILVER] batch_id=784 escrito correctamente
# [SILVER] Procesando batch_id=785
# [SILVER] batch_id=785 escrito correctamente
# [SILVER] Procesando batch_id=786
# [SILVER] batch_id=786 escrito correctamente
# [SILVER] Procesando batch_id=787
# [SILVER] batch_id=787 escrito correctamente
# [SILVER] Procesando batch_id=788
# [SILVER] batch_id=788 escrito correctamente
# [SILVER] Procesando batch_id=789
# [SILVER] batch_id=789 escrito correctamente
# [SILVER] Procesando batch_id=790
# [SILVER] batch_id=790 escrito correctamente
# [SILVER] Procesando batch_id=791
# [SILVER] batch_id=791 escrito correctamente
# [SILVER] Procesando batch_id=792
# [SILVER] batch_id=792 escrito correctamente
# [SILVER] Procesando batch_id=793
# [SILVER] batch_id=793 escrito correctamente
# [SILVER] Procesando batch_id=794
# [SILVER] batch_id=794 escrito correctamente
# [SILVER] Procesando batch_id=795
# [SILVER] batch_id=795 escrito correctamente
# [SILVER] Procesando batch_id=796
# [SILVER] batch_id=796 escrito correctamente
# [SILVER] Procesando batch_id=797
# [SILVER] batch_id=797 escrito correctamente
# [SILVER] Procesando batch_id=798
# [SILVER] batch_id=798 escrito correctamente
# [SILVER] Procesando batch_id=799
# [SILVER] batch_id=799 escrito correctamente
# [SILVER] Procesando batch_id=800
# [SILVER] batch_id=800 escrito correctamente
# [SILVER] Procesando batch_id=801
# [SILVER] batch_id=801 escrito correctamente
# [SILVER] Procesando batch_id=802
# [SILVER] batch_id=802 escrito correctamente
# [SILVER] Procesando batch_id=803
# [SILVER] batch_id=803 escrito correctamente
# [SILVER] Procesando batch_id=804
# [SILVER] batch_id=804 escrito correctamente
# [SILVER] Procesando batch_id=805
# [SILVER] batch_id=805 escrito correctamente
# [SILVER] Procesando batch_id=806
# [SILVER] batch_id=806 escrito correctamente
# [SILVER] Procesando batch_id=807
# [SILVER] batch_id=807 escrito correctamente
# [SILVER] Procesando batch_id=808
# [SILVER] batch_id=808 escrito correctamente
# [SILVER] Procesando batch_id=809
# [SILVER] batch_id=809 escrito correctamente
# [SILVER] Procesando batch_id=810
# [SILVER] batch_id=810 escrito correctamente
# [SILVER] Procesando batch_id=811
# [SILVER] batch_id=811 escrito correctamente
# [SILVER] Procesando batch_id=812
# [SILVER] batch_id=812 escrito correctamente
# [SILVER] Procesando batch_id=813
# [SILVER] batch_id=813 escrito correctamente
# [SILVER] Procesando batch_id=814
# [SILVER] batch_id=814 escrito correctamente
# [SILVER] Procesando batch_id=815
# [SILVER] batch_id=815 escrito correctamente
# [SILVER] Procesando batch_id=816
# [SILVER] batch_id=816 escrito correctamente
# [SILVER] Procesando batch_id=817
# [SILVER] batch_id=817 escrito correctamente
# [SILVER] Procesando batch_id=818
# [SILVER] batch_id=818 escrito correctamente
# [SILVER] Procesando batch_id=819
# [SILVER] batch_id=819 escrito correctamente
# [SILVER] Procesando batch_id=820
# [SILVER] batch_id=820 escrito correctamente
# [SILVER] Procesando batch_id=821
# [SILVER] batch_id=821 escrito correctamente
# [SILVER] Procesando batch_id=822
# [SILVER] batch_id=822 escrito correctamente
# [SILVER] Procesando batch_id=823
# [SILVER] batch_id=823 escrito correctamente
# [SILVER] Procesando batch_id=824
# [SILVER] batch_id=824 escrito correctamente
# [SILVER] Procesando batch_id=825
# [SILVER] batch_id=825 escrito correctamente
# [SILVER] Procesando batch_id=826
# [SILVER] batch_id=826 escrito correctamente
# [SILVER] Procesando batch_id=827
# [SILVER] batch_id=827 escrito correctamente
# [SILVER] Procesando batch_id=828
# [SILVER] batch_id=828 escrito correctamente
# [SILVER] Procesando batch_id=829
# [SILVER] batch_id=829 escrito correctamente
# [SILVER] Procesando batch_id=830
# [SILVER] batch_id=830 escrito correctamente
# [SILVER] Procesando batch_id=831
# [SILVER] batch_id=831 escrito correctamente
# [SILVER] Procesando batch_id=832
# [SILVER] batch_id=832 escrito correctamente
# [SILVER] Procesando batch_id=833
# [SILVER] batch_id=833 escrito correctamente
# [SILVER] Procesando batch_id=834
# [SILVER] batch_id=834 escrito correctamente
# [SILVER] Procesando batch_id=835
# [SILVER] batch_id=835 escrito correctamente
# [SILVER] Procesando batch_id=836
# [SILVER] batch_id=836 escrito correctamente
# [SILVER] Procesando batch_id=837
# [SILVER] batch_id=837 escrito correctamente
# [SILVER] Procesando batch_id=838
# [SILVER] batch_id=838 escrito correctamente
# [SILVER] Procesando batch_id=839
# [SILVER] batch_id=839 escrito correctamente
# [SILVER] Procesando batch_id=840
# [SILVER] batch_id=840 escrito correctamente
# [SILVER] Procesando batch_id=841
# [SILVER] batch_id=841 escrito correctamente
# [SILVER] Procesando batch_id=842
# [SILVER] batch_id=842 escrito correctamente
# [SILVER] Procesando batch_id=843
# [SILVER] batch_id=843 escrito correctamente
# [SILVER] Procesando batch_id=844
# [SILVER] batch_id=844 escrito correctamente
# [SILVER] Procesando batch_id=845
# [SILVER] batch_id=845 escrito correctamente
# [SILVER] Procesando batch_id=846
# [SILVER] batch_id=846 escrito correctamente
# [SILVER] Procesando batch_id=847
# [SILVER] batch_id=847 escrito correctamente
# [SILVER] Procesando batch_id=848
# [SILVER] batch_id=848 escrito correctamente
# [SILVER] Procesando batch_id=849
# [SILVER] batch_id=849 escrito correctamente
# [SILVER] Procesando batch_id=850
# [SILVER] batch_id=850 escrito correctamente
# [SILVER] Procesando batch_id=851
# [SILVER] batch_id=851 escrito correctamente
# [SILVER] Procesando batch_id=852
# [SILVER] batch_id=852 escrito correctamente
# [SILVER] Procesando batch_id=853
# [SILVER] batch_id=853 escrito correctamente
# [SILVER] Procesando batch_id=854
# [SILVER] batch_id=854 escrito correctamente
# [SILVER] Procesando batch_id=855
# [SILVER] batch_id=855 escrito correctamente
# [SILVER] Procesando batch_id=856
# [SILVER] batch_id=856 escrito correctamente
# [SILVER] Procesando batch_id=857
# [SILVER] batch_id=857 escrito correctamente
# [SILVER] Procesando batch_id=858
# [SILVER] batch_id=858 escrito correctamente
# [SILVER] Procesando batch_id=859
# [SILVER] batch_id=859 escrito correctamente
# [SILVER] Procesando batch_id=860
# [SILVER] batch_id=860 escrito correctamente
# [SILVER] Procesando batch_id=861
# [SILVER] batch_id=861 escrito correctamente
# [SILVER] Procesando batch_id=862
# [SILVER] batch_id=862 escrito correctamente
# [SILVER] Procesando batch_id=863
# [SILVER] batch_id=863 escrito correctamente
# [SILVER] Procesando batch_id=864
# [SILVER] batch_id=864 escrito correctamente
# [SILVER] Procesando batch_id=865
# [SILVER] batch_id=865 escrito correctamente
# [SILVER] Procesando batch_id=866
# [SILVER] batch_id=866 escrito correctamente
# [SILVER] Procesando batch_id=867
# [SILVER] batch_id=867 escrito correctamente
# [SILVER] Procesando batch_id=868
# [SILVER] batch_id=868 escrito correctamente
# [SILVER] Procesando batch_id=869
# [SILVER] batch_id=869 escrito correctamente
# [SILVER] Procesando batch_id=870
# [SILVER] batch_id=870 escrito correctamente
# [SILVER] Procesando batch_id=871
# [SILVER] batch_id=871 escrito correctamente
# [SILVER] Procesando batch_id=872
# [SILVER] batch_id=872 escrito correctamente
# [SILVER] Procesando batch_id=873
# [SILVER] batch_id=873 escrito correctamente
# [SILVER] Procesando batch_id=874
# [SILVER] batch_id=874 escrito correctamente
# [SILVER] Procesando batch_id=875
# [SILVER] batch_id=875 escrito correctamente
# [SILVER] Procesando batch_id=876
# [SILVER] batch_id=876 escrito correctamente
# [SILVER] Procesando batch_id=877
# [SILVER] batch_id=877 escrito correctamente
# [SILVER] Procesando batch_id=878
# [SILVER] batch_id=878 escrito correctamente
# [SILVER] Procesando batch_id=879
# [SILVER] batch_id=879 escrito correctamente
# [SILVER] Procesando batch_id=880
# [SILVER] batch_id=880 escrito correctamente
# [SILVER] Procesando batch_id=881
# [SILVER] batch_id=881 escrito correctamente
# [SILVER] Procesando batch_id=882
# [SILVER] batch_id=882 escrito correctamente
# [SILVER] Procesando batch_id=883
# [SILVER] batch_id=883 escrito correctamente
# [SILVER] Procesando batch_id=884
# [SILVER] batch_id=884 escrito correctamente
# [SILVER] Procesando batch_id=885
# [SILVER] batch_id=885 escrito correctamente
# [SILVER] Procesando batch_id=886
# [SILVER] batch_id=886 escrito correctamente
# [SILVER] Procesando batch_id=887
# [SILVER] batch_id=887 escrito correctamente
# [SILVER] Procesando batch_id=888
# [SILVER] batch_id=888 escrito correctamente
# [SILVER] Procesando batch_id=889
# [SILVER] batch_id=889 escrito correctamente
# [SILVER] Procesando batch_id=890
# [SILVER] batch_id=890 escrito correctamente
# [SILVER] Procesando batch_id=891
# [SILVER] batch_id=891 escrito correctamente
# [SILVER] Procesando batch_id=892
# [SILVER] batch_id=892 escrito correctamente
# [SILVER] Procesando batch_id=893
# [SILVER] batch_id=893 escrito correctamente
# [SILVER] Procesando batch_id=894
# [SILVER] batch_id=894 escrito correctamente
# [SILVER] Procesando batch_id=895
# [SILVER] batch_id=895 escrito correctamente
# [SILVER] Procesando batch_id=896
# [SILVER] batch_id=896 escrito correctamente
# [SILVER] Procesando batch_id=897
# [SILVER] batch_id=897 escrito correctamente
# [SILVER] Procesando batch_id=898
# [SILVER] batch_id=898 escrito correctamente
# [SILVER] Procesando batch_id=899
# [SILVER] batch_id=899 escrito correctamente
# [SILVER] Procesando batch_id=900
# [SILVER] batch_id=900 escrito correctamente
# [SILVER] Procesando batch_id=901
# [SILVER] batch_id=901 escrito correctamente
# [SILVER] Procesando batch_id=902
# [SILVER] batch_id=902 escrito correctamente
# [SILVER] Procesando batch_id=903
# [SILVER] batch_id=903 escrito correctamente
# [SILVER] Procesando batch_id=904
# [SILVER] batch_id=904 escrito correctamente
# [SILVER] Procesando batch_id=905
# [SILVER] batch_id=905 escrito correctamente
# [SILVER] Procesando batch_id=906
# [SILVER] batch_id=906 escrito correctamente
# [SILVER] Procesando batch_id=907
# [SILVER] batch_id=907 escrito correctamente
# [SILVER] Procesando batch_id=908
# [SILVER] batch_id=908 escrito correctamente
# [SILVER] Procesando batch_id=909
# [SILVER] batch_id=909 escrito correctamente
# [SILVER] Procesando batch_id=910
# [SILVER] batch_id=910 escrito correctamente
# [SILVER] Procesando batch_id=911
# [SILVER] batch_id=911 escrito correctamente
# [SILVER] Procesando batch_id=912
# [SILVER] batch_id=912 escrito correctamente
# [SILVER] Procesando batch_id=913
# [SILVER] batch_id=913 escrito correctamente
# [SILVER] Procesando batch_id=914
# [SILVER] batch_id=914 escrito correctamente
# [SILVER] Procesando batch_id=915
# [SILVER] batch_id=915 escrito correctamente
# [SILVER] Procesando batch_id=916
# [SILVER] batch_id=916 escrito correctamente
# [SILVER] Procesando batch_id=917
# [SILVER] batch_id=917 escrito correctamente
# [SILVER] Procesando batch_id=918
# [SILVER] batch_id=918 escrito correctamente
# [SILVER] Procesando batch_id=919
# [SILVER] batch_id=919 escrito correctamente
# [SILVER] Procesando batch_id=920
# [SILVER] batch_id=920 escrito correctamente
# [SILVER] Procesando batch_id=921
# [SILVER] batch_id=921 escrito correctamente
# [SILVER] Procesando batch_id=922
# [SILVER] batch_id=922 escrito correctamente
# [SILVER] Procesando batch_id=923
# [SILVER] batch_id=923 escrito correctamente
# [SILVER] Procesando batch_id=924
# [SILVER] batch_id=924 escrito correctamente
# [SILVER] Procesando batch_id=925
# [SILVER] batch_id=925 escrito correctamente
# [SILVER] Procesando batch_id=926
# [SILVER] batch_id=926 escrito correctamente
# [SILVER] Procesando batch_id=927
# [SILVER] batch_id=927 escrito correctamente
# [SILVER] Procesando batch_id=928
# [SILVER] batch_id=928 escrito correctamente
# [SILVER] Procesando batch_id=929
# [SILVER] batch_id=929 escrito correctamente
# [SILVER] Procesando batch_id=930
# [SILVER] batch_id=930 escrito correctamente
# [SILVER] Procesando batch_id=931
# [SILVER] batch_id=931 escrito correctamente
# [SILVER] Procesando batch_id=932
# [SILVER] batch_id=932 escrito correctamente
# [SILVER] Procesando batch_id=933
# [SILVER] batch_id=933 escrito correctamente
# [SILVER] Procesando batch_id=934
# [SILVER] batch_id=934 escrito correctamente
# [SILVER] Procesando batch_id=935
# [SILVER] batch_id=935 escrito correctamente
# [SILVER] Procesando batch_id=936
# [SILVER] batch_id=936 escrito correctamente
# [SILVER] Procesando batch_id=937
# [SILVER] batch_id=937 escrito correctamente
# [SILVER] Procesando batch_id=938
# [SILVER] batch_id=938 escrito correctamente
# [SILVER] Procesando batch_id=939
# [SILVER] batch_id=939 escrito correctamente
# [SILVER] Procesando batch_id=940
# [SILVER] batch_id=940 escrito correctamente
# [SILVER] Procesando batch_id=941
# [SILVER] batch_id=941 escrito correctamente
# [SILVER] Procesando batch_id=942
# [SILVER] batch_id=942 escrito correctamente
# [SILVER] Procesando batch_id=943
# [SILVER] batch_id=943 escrito correctamente
# [SILVER] Procesando batch_id=944
# [SILVER] batch_id=944 escrito correctamente
# [SILVER] Procesando batch_id=945
# [SILVER] batch_id=945 escrito correctamente
# [SILVER] Procesando batch_id=946
# [SILVER] batch_id=946 escrito correctamente
# [SILVER] Procesando batch_id=947
# [SILVER] batch_id=947 escrito correctamente
# [SILVER] Procesando batch_id=948
# [SILVER] batch_id=948 escrito correctamente
# [SILVER] Procesando batch_id=949
# [SILVER] batch_id=949 escrito correctamente
# [SILVER] Procesando batch_id=950
# [SILVER] batch_id=950 escrito correctamente
# [SILVER] Procesando batch_id=951
# [SILVER] batch_id=951 escrito correctamente
# [SILVER] Procesando batch_id=952
# [SILVER] batch_id=952 escrito correctamente
# [SILVER] Procesando batch_id=953
# [SILVER] batch_id=953 escrito correctamente
# [SILVER] Procesando batch_id=954
# [SILVER] batch_id=954 escrito correctamente
# [SILVER] Procesando batch_id=955
# [SILVER] batch_id=955 escrito correctamente
# [SILVER] Procesando batch_id=956
# [SILVER] batch_id=956 escrito correctamente
# [SILVER] Procesando batch_id=957
# [SILVER] batch_id=957 escrito correctamente
# [SILVER] Procesando batch_id=958
# [SILVER] batch_id=958 escrito correctamente
# [SILVER] Procesando batch_id=959
# [SILVER] batch_id=959 escrito correctamente
# [SILVER] Procesando batch_id=960
# [SILVER] batch_id=960 escrito correctamente
# [SILVER] Procesando batch_id=961
# [SILVER] batch_id=961 escrito correctamente
# [SILVER] Procesando batch_id=962
# [SILVER] batch_id=962 escrito correctamente
# [SILVER] Procesando batch_id=963
# [SILVER] batch_id=963 escrito correctamente
# [SILVER] Procesando batch_id=964
# [SILVER] batch_id=964 escrito correctamente
# [SILVER] Procesando batch_id=965
# [SILVER] batch_id=965 escrito correctamente
# [SILVER] Procesando batch_id=966
# [SILVER] batch_id=966 escrito correctamente
# [SILVER] Procesando batch_id=967
# [SILVER] batch_id=967 escrito correctamente
# [SILVER] Procesando batch_id=968
# [SILVER] batch_id=968 escrito correctamente
# [SILVER] Procesando batch_id=969
# [SILVER] batch_id=969 escrito correctamente
# [SILVER] Procesando batch_id=970
# [SILVER] batch_id=970 escrito correctamente
# [SILVER] Procesando batch_id=971
# [SILVER] batch_id=971 escrito correctamente
# [SILVER] Procesando batch_id=972
# [SILVER] batch_id=972 escrito correctamente
# [SILVER] Procesando batch_id=973
# [SILVER] batch_id=973 escrito correctamente
# [SILVER] Procesando batch_id=974
# [SILVER] batch_id=974 escrito correctamente
# [SILVER] Procesando batch_id=975
# [SILVER] batch_id=975 escrito correctamente
# [SILVER] Procesando batch_id=976
# [SILVER] batch_id=976 escrito correctamente
# [SILVER] Procesando batch_id=977
# [SILVER] batch_id=977 escrito correctamente
# [SILVER] Procesando batch_id=978
# [SILVER] batch_id=978 escrito correctamente
# [SILVER] Procesando batch_id=979
# [SILVER] batch_id=979 escrito correctamente
# [SILVER] Procesando batch_id=980
# [SILVER] batch_id=980 escrito correctamente
# [SILVER] Procesando batch_id=981
# [SILVER] batch_id=981 escrito correctamente
# [SILVER] Procesando batch_id=982
# [SILVER] batch_id=982 escrito correctamente
# [SILVER] Procesando batch_id=983
# [SILVER] batch_id=983 escrito correctamente
# [SILVER] Procesando batch_id=984
# [SILVER] batch_id=984 escrito correctamente
# [SILVER] Procesando batch_id=985
# [SILVER] batch_id=985 escrito correctamente
# [SILVER] Procesando batch_id=986
# [SILVER] batch_id=986 escrito correctamente
# [SILVER] Procesando batch_id=987
# [SILVER] batch_id=987 escrito correctamente
# [SILVER] Procesando batch_id=988
# [SILVER] batch_id=988 escrito correctamente
# [SILVER] Procesando batch_id=989
# [SILVER] batch_id=989 escrito correctamente
# [SILVER] Procesando batch_id=990
# [SILVER] batch_id=990 escrito correctamente
# [SILVER] Procesando batch_id=991
# [SILVER] batch_id=991 escrito correctamente
# [SILVER] Procesando batch_id=992
# [SILVER] batch_id=992 escrito correctamente
# [SILVER] Procesando batch_id=993
# [SILVER] batch_id=993 escrito correctamente
# [SILVER] Procesando batch_id=994
# [SILVER] batch_id=994 escrito correctamente
# [SILVER] Procesando batch_id=995
# [SILVER] batch_id=995 escrito correctamente
# [SILVER] Procesando batch_id=996
# [SILVER] batch_id=996 escrito correctamente
# [SILVER] Procesando batch_id=997
# [SILVER] batch_id=997 escrito correctamente
# [SILVER] Procesando batch_id=998
# [SILVER] batch_id=998 escrito correctamente
# [SILVER] Procesando batch_id=999
# [SILVER] batch_id=999 escrito correctamente
# [SILVER] Procesando batch_id=1000
# [SILVER] batch_id=1000 escrito correctamente
# [SILVER] Procesando batch_id=1001
# [SILVER] batch_id=1001 escrito correctamente
# [SILVER] Procesando batch_id=1002
# [SILVER] batch_id=1002 escrito correctamente
# [SILVER] Procesando batch_id=1003
# [SILVER] batch_id=1003 escrito correctamente
# [SILVER] Procesando batch_id=1004
# [SILVER] batch_id=1004 escrito correctamente
# [SILVER] Procesando batch_id=1005
# [SILVER] batch_id=1005 escrito correctamente
# [SILVER] Procesando batch_id=1006
# [SILVER] batch_id=1006 escrito correctamente
# [SILVER] Procesando batch_id=1007
# [SILVER] batch_id=1007 escrito correctamente
# [SILVER] Procesando batch_id=1008
# [SILVER] batch_id=1008 escrito correctamente
# [SILVER] Procesando batch_id=1009
# [SILVER] batch_id=1009 escrito correctamente
# [SILVER] Procesando batch_id=1010
# [SILVER] batch_id=1010 escrito correctamente
# [SILVER] Procesando batch_id=1011
# [SILVER] batch_id=1011 escrito correctamente
# [SILVER] Procesando batch_id=1012
# [SILVER] batch_id=1012 escrito correctamente
# [SILVER] Procesando batch_id=1013
# [SILVER] batch_id=1013 escrito correctamente
# [SILVER] Procesando batch_id=1014
# [SILVER] batch_id=1014 escrito correctamente
# [SILVER] Procesando batch_id=1015
# [SILVER] batch_id=1015 escrito correctamente
# [SILVER] Procesando batch_id=1016
# [SILVER] batch_id=1016 escrito correctamente
# [SILVER] Procesando batch_id=1017
# [SILVER] batch_id=1017 escrito correctamente
# [SILVER] Procesando batch_id=1018
# [SILVER] batch_id=1018 escrito correctamente
# [SILVER] Procesando batch_id=1019
# [SILVER] batch_id=1019 escrito correctamente
# [SILVER] Procesando batch_id=1020
# [SILVER] batch_id=1020 escrito correctamente
# [SILVER] Procesando batch_id=1021
# [SILVER] batch_id=1021 escrito correctamente
# [SILVER] Procesando batch_id=1022
# [SILVER] batch_id=1022 escrito correctamente
# [SILVER] Procesando batch_id=1023
# [SILVER] batch_id=1023 escrito correctamente
# [SILVER] Procesando batch_id=1024
# [SILVER] batch_id=1024 escrito correctamente
# [SILVER] Procesando batch_id=1025
# [SILVER] batch_id=1025 escrito correctamente
# [SILVER] Procesando batch_id=1026
# [SILVER] batch_id=1026 escrito correctamente
# [SILVER] Procesando batch_id=1027
# [SILVER] batch_id=1027 escrito correctamente
# [SILVER] Procesando batch_id=1028
# [SILVER] batch_id=1028 escrito correctamente
# [SILVER] Procesando batch_id=1029
# [SILVER] batch_id=1029 escrito correctamente
# [SILVER] Procesando batch_id=1030
# [SILVER] batch_id=1030 escrito correctamente
# [SILVER] Procesando batch_id=1031
# [SILVER] batch_id=1031 escrito correctamente
# [SILVER] Procesando batch_id=1032
# [SILVER] batch_id=1032 escrito correctamente
# [SILVER] Procesando batch_id=1033
# [SILVER] batch_id=1033 escrito correctamente
# [SILVER] Procesando batch_id=1034
# [SILVER] batch_id=1034 escrito correctamente
# [SILVER] Procesando batch_id=1035
# [SILVER] batch_id=1035 escrito correctamente
# [SILVER] Procesando batch_id=1036
# [SILVER] batch_id=1036 escrito correctamente
# [SILVER] Procesando batch_id=1037
# [SILVER] batch_id=1037 escrito correctamente
# [SILVER] Procesando batch_id=1038
# [SILVER] batch_id=1038 escrito correctamente
# [SILVER] Procesando batch_id=1039
# [SILVER] batch_id=1039 escrito correctamente
# [SILVER] Procesando batch_id=1040
# [SILVER] batch_id=1040 escrito correctamente
# [SILVER] Procesando batch_id=1041
# [SILVER] batch_id=1041 escrito correctamente
# [SILVER] Procesando batch_id=1042
# [SILVER] batch_id=1042 escrito correctamente
# [SILVER] Procesando batch_id=1043
# [SILVER] batch_id=1043 escrito correctamente
# [SILVER] Procesando batch_id=1044
# [SILVER] batch_id=1044 escrito correctamente
# [SILVER] Procesando batch_id=1045
# [SILVER] batch_id=1045 escrito correctamente
# [SILVER] Procesando batch_id=1046
# [SILVER] batch_id=1046 escrito correctamente
# [SILVER] Procesando batch_id=1047
# [SILVER] batch_id=1047 escrito correctamente
# [SILVER] Procesando batch_id=1048
# [SILVER] batch_id=1048 escrito correctamente
# [SILVER] Procesando batch_id=1049
# [SILVER] batch_id=1049 escrito correctamente
# [SILVER] Procesando batch_id=1050
# [SILVER] batch_id=1050 escrito correctamente
# [SILVER] Procesando batch_id=1051
# [SILVER] batch_id=1051 escrito correctamente
# [SILVER] Procesando batch_id=1052
# [SILVER] batch_id=1052 escrito correctamente
# [SILVER] Procesando batch_id=1053
# [SILVER] batch_id=1053 escrito correctamente
# [SILVER] Procesando batch_id=1054
# [SILVER] batch_id=1054 escrito correctamente
# [SILVER] Procesando batch_id=1055
# [SILVER] batch_id=1055 escrito correctamente
# [SILVER] Procesando batch_id=1056
# [SILVER] batch_id=1056 escrito correctamente
# [SILVER] Procesando batch_id=1057
# [SILVER] batch_id=1057 escrito correctamente
# [SILVER] Procesando batch_id=1058
# [SILVER] batch_id=1058 escrito correctamente
# [SILVER] Procesando batch_id=1059
# [SILVER] batch_id=1059 escrito correctamente
# [SILVER] Procesando batch_id=1060
# [SILVER] batch_id=1060 escrito correctamente
# [SILVER] Procesando batch_id=1061
# [SILVER] batch_id=1061 escrito correctamente
# [SILVER] Procesando batch_id=1062
# [SILVER] batch_id=1062 escrito correctamente
# [SILVER] Procesando batch_id=1063
# [SILVER] batch_id=1063 escrito correctamente
# [SILVER] Procesando batch_id=1064
# [SILVER] batch_id=1064 escrito correctamente
# [SILVER] Procesando batch_id=1065
# [SILVER] batch_id=1065 escrito correctamente
# [SILVER] Procesando batch_id=1066
# [SILVER] batch_id=1066 escrito correctamente
# [SILVER] Procesando batch_id=1067
# [SILVER] batch_id=1067 escrito correctamente
# [SILVER] Procesando batch_id=1068
# [SILVER] batch_id=1068 escrito correctamente
# [SILVER] Procesando batch_id=1069
# [SILVER] batch_id=1069 escrito correctamente
# [SILVER] Procesando batch_id=1070
# [SILVER] batch_id=1070 escrito correctamente
# [SILVER] Procesando batch_id=1071
# [SILVER] batch_id=1071 escrito correctamente
# [SILVER] Procesando batch_id=1072
# [SILVER] batch_id=1072 escrito correctamente
# [SILVER] Procesando batch_id=1073
# [SILVER] batch_id=1073 escrito correctamente
# [SILVER] Procesando batch_id=1074
# [SILVER] batch_id=1074 escrito correctamente
# [SILVER] Procesando batch_id=1075
# [SILVER] batch_id=1075 escrito correctamente
# [SILVER] Procesando batch_id=1076
# [SILVER] batch_id=1076 escrito correctamente
# [SILVER] Procesando batch_id=1077
# [SILVER] batch_id=1077 escrito correctamente
# [SILVER] Procesando batch_id=1078
# [SILVER] batch_id=1078 escrito correctamente
# [SILVER] Procesando batch_id=1079
# [SILVER] batch_id=1079 escrito correctamente
# [SILVER] Procesando batch_id=1080
# [SILVER] batch_id=1080 escrito correctamente
# [SILVER] Procesando batch_id=1081
# [SILVER] batch_id=1081 escrito correctamente
# [SILVER] Procesando batch_id=1082
# [SILVER] batch_id=1082 escrito correctamente
# [SILVER] Procesando batch_id=1083
# [SILVER] batch_id=1083 escrito correctamente
# [SILVER] Procesando batch_id=1084
# [SILVER] batch_id=1084 escrito correctamente
# [SILVER] Procesando batch_id=1085
# [SILVER] batch_id=1085 escrito correctamente
# [SILVER] Procesando batch_id=1086
# [SILVER] batch_id=1086 escrito correctamente
# [SILVER] Procesando batch_id=1087
# [SILVER] batch_id=1087 escrito correctamente
# [SILVER] Procesando batch_id=1088
# [SILVER] batch_id=1088 escrito correctamente
# [SILVER] Procesando batch_id=1089
# [SILVER] batch_id=1089 escrito correctamente
# [SILVER] Procesando batch_id=1090
# [SILVER] batch_id=1090 escrito correctamente
# [SILVER] Procesando batch_id=1091
# [SILVER] batch_id=1091 escrito correctamente
# [SILVER] Procesando batch_id=1092
# [SILVER] batch_id=1092 escrito correctamente
# [SILVER] Procesando batch_id=1093
# [SILVER] batch_id=1093 escrito correctamente
# [SILVER] Procesando batch_id=1094
# [SILVER] batch_id=1094 escrito correctamente
# [SILVER] Procesando batch_id=1095
# [SILVER] batch_id=1095 escrito correctamente
# [SILVER] Procesando batch_id=1096
# [SILVER] batch_id=1096 escrito correctamente
# [SILVER] Procesando batch_id=1097
# [SILVER] batch_id=1097 escrito correctamente
# [SILVER] Procesando batch_id=1098
# [SILVER] batch_id=1098 escrito correctamente
# [SILVER] Procesando batch_id=1099
# [SILVER] batch_id=1099 escrito correctamente
# [SILVER] Procesando batch_id=1100
# [SILVER] batch_id=1100 escrito correctamente
# [SILVER] Procesando batch_id=1101
# [SILVER] batch_id=1101 escrito correctamente
# [SILVER] Procesando batch_id=1102
# [SILVER] batch_id=1102 escrito correctamente
# [SILVER] Procesando batch_id=1103
# [SILVER] batch_id=1103 escrito correctamente
# [SILVER] Procesando batch_id=1104
# [SILVER] batch_id=1104 escrito correctamente
# [SILVER] Procesando batch_id=1105
# [SILVER] batch_id=1105 escrito correctamente
# [SILVER] Procesando batch_id=1106
# [SILVER] batch_id=1106 escrito correctamente
# [SILVER] Procesando batch_id=1107
# [SILVER] batch_id=1107 escrito correctamente
# [SILVER] Procesando batch_id=1108
# [SILVER] batch_id=1108 escrito correctamente
# [SILVER] Procesando batch_id=1109
# [SILVER] batch_id=1109 escrito correctamente
# [SILVER] Procesando batch_id=1110
# [SILVER] batch_id=1110 escrito correctamente
# [SILVER] Procesando batch_id=1111
# [SILVER] batch_id=1111 escrito correctamente
# [SILVER] Procesando batch_id=1112
# [SILVER] batch_id=1112 escrito correctamente
# [SILVER] Procesando batch_id=1113
# [SILVER] batch_id=1113 escrito correctamente
# [SILVER] Procesando batch_id=1114
# [SILVER] batch_id=1114 escrito correctamente
# [SILVER] Procesando batch_id=1115
# [SILVER] batch_id=1115 escrito correctamente
# [SILVER] Procesando batch_id=1116
# [SILVER] batch_id=1116 escrito correctamente
# [SILVER] Procesando batch_id=1117
# [SILVER] batch_id=1117 escrito correctamente
# [SILVER] Procesando batch_id=1118
# [SILVER] batch_id=1118 escrito correctamente
# [SILVER] Procesando batch_id=1119
# [SILVER] batch_id=1119 escrito correctamente
# [SILVER] Procesando batch_id=1120
# [SILVER] batch_id=1120 escrito correctamente
# [SILVER] Procesando batch_id=1121
# [SILVER] batch_id=1121 escrito correctamente
# [SILVER] Procesando batch_id=1122
# [SILVER] batch_id=1122 escrito correctamente
# [SILVER] Procesando batch_id=1123
# [SILVER] batch_id=1123 escrito correctamente
# [SILVER] Procesando batch_id=1124
# [SILVER] batch_id=1124 escrito correctamente
# [SILVER] Procesando batch_id=1125
# [SILVER] batch_id=1125 escrito correctamente
# [SILVER] Procesando batch_id=1126
# [SILVER] batch_id=1126 escrito correctamente
# [SILVER] Procesando batch_id=1127
# [SILVER] batch_id=1127 escrito correctamente
# [SILVER] Procesando batch_id=1128
# [SILVER] batch_id=1128 escrito correctamente
# [SILVER] Procesando batch_id=1129
# [SILVER] batch_id=1129 escrito correctamente
# [SILVER] Procesando batch_id=1130
# [SILVER] batch_id=1130 escrito correctamente
# [SILVER] Procesando batch_id=1131
# [SILVER] batch_id=1131 escrito correctamente
# [SILVER] Procesando batch_id=1132
# [SILVER] batch_id=1132 escrito correctamente
# [SILVER] Procesando batch_id=1133
# [SILVER] batch_id=1133 escrito correctamente
# [SILVER] Procesando batch_id=1134
# [SILVER] batch_id=1134 escrito correctamente
# [SILVER] Procesando batch_id=1135
# [SILVER] batch_id=1135 escrito correctamente
# [SILVER] Procesando batch_id=1136
# [SILVER] batch_id=1136 escrito correctamente
# [SILVER] Procesando batch_id=1137
# [SILVER] batch_id=1137 escrito correctamente
# [SILVER] Procesando batch_id=1138
# [SILVER] batch_id=1138 escrito correctamente
# [SILVER] Procesando batch_id=1139
# [SILVER] batch_id=1139 escrito correctamente
# [SILVER] Procesando batch_id=1140
# [SILVER] batch_id=1140 escrito correctamente
# [SILVER] Procesando batch_id=1141
# [SILVER] batch_id=1141 escrito correctamente
# [SILVER] Procesando batch_id=1142
# [SILVER] batch_id=1142 escrito correctamente
# [SILVER] Procesando batch_id=1143
# [SILVER] batch_id=1143 escrito correctamente
# [SILVER] Procesando batch_id=1144
# [SILVER] batch_id=1144 escrito correctamente
# [SILVER] Procesando batch_id=1145
# [SILVER] batch_id=1145 escrito correctamente
# [SILVER] Procesando batch_id=1146
# [SILVER] batch_id=1146 escrito correctamente
# [SILVER] Procesando batch_id=1147
# [SILVER] batch_id=1147 escrito correctamente
# [SILVER] Procesando batch_id=1148
# [SILVER] batch_id=1148 escrito correctamente
# [SILVER] Procesando batch_id=1149
# [SILVER] batch_id=1149 escrito correctamente
# [SILVER] Procesando batch_id=1150
# [SILVER] batch_id=1150 escrito correctamente
# [SILVER] Procesando batch_id=1151
# [SILVER] batch_id=1151 escrito correctamente
# [SILVER] Procesando batch_id=1152
# [SILVER] batch_id=1152 escrito correctamente
# [SILVER] Procesando batch_id=1153
# [SILVER] batch_id=1153 escrito correctamente
# [SILVER] Procesando batch_id=1154
# [SILVER] batch_id=1154 escrito correctamente
# [SILVER] Procesando batch_id=1155
# [SILVER] batch_id=1155 escrito correctamente
# [SILVER] Procesando batch_id=1156
# [SILVER] batch_id=1156 escrito correctamente
# [SILVER] Procesando batch_id=1157
# [SILVER] batch_id=1157 escrito correctamente
# [SILVER] Procesando batch_id=1158
# [SILVER] batch_id=1158 escrito correctamente
# [SILVER] Procesando batch_id=1159
# [SILVER] batch_id=1159 escrito correctamente
# [SILVER] Procesando batch_id=1160
# [SILVER] batch_id=1160 escrito correctamente
# [SILVER] Procesando batch_id=1161
# [SILVER] batch_id=1161 escrito correctamente
# [SILVER] Procesando batch_id=1162
# [SILVER] batch_id=1162 escrito correctamente
# [SILVER] Procesando batch_id=1163
# [SILVER] batch_id=1163 escrito correctamente
# [SILVER] Procesando batch_id=1164
# [SILVER] batch_id=1164 escrito correctamente
# [SILVER] Procesando batch_id=1165
# [SILVER] batch_id=1165 escrito correctamente
# [SILVER] Procesando batch_id=1166
# [SILVER] batch_id=1166 escrito correctamente
# [SILVER] Procesando batch_id=1167
# [SILVER] batch_id=1167 escrito correctamente
# [SILVER] Procesando batch_id=1168
# [SILVER] batch_id=1168 escrito correctamente
# [SILVER] Procesando batch_id=1169
# [SILVER] batch_id=1169 escrito correctamente
# [SILVER] Procesando batch_id=1170
# [SILVER] batch_id=1170 escrito correctamente
# [SILVER] Procesando batch_id=1171
# [SILVER] batch_id=1171 escrito correctamente
# [SILVER] Procesando batch_id=1172
# [SILVER] batch_id=1172 escrito correctamente
# [SILVER] Procesando batch_id=1173
# [SILVER] batch_id=1173 escrito correctamente
# [SILVER] Procesando batch_id=1174
# [SILVER] batch_id=1174 escrito correctamente
# [SILVER] Procesando batch_id=1175
# [SILVER] batch_id=1175 escrito correctamente
# [SILVER] Procesando batch_id=1176
# [SILVER] batch_id=1176 escrito correctamente
# [SILVER] Procesando batch_id=1177
# [SILVER] batch_id=1177 escrito correctamente
# [SILVER] Procesando batch_id=1178
# [SILVER] batch_id=1178 escrito correctamente
# [SILVER] Procesando batch_id=1179
# [SILVER] batch_id=1179 escrito correctamente
# [SILVER] Procesando batch_id=1180
# [SILVER] batch_id=1180 escrito correctamente
# [SILVER] Procesando batch_id=1181
# [SILVER] batch_id=1181 escrito correctamente
# [SILVER] Procesando batch_id=1182
# [SILVER] batch_id=1182 escrito correctamente
# [SILVER] Procesando batch_id=1183
# [SILVER] batch_id=1183 escrito correctamente
# [SILVER] Procesando batch_id=1184
# [SILVER] batch_id=1184 escrito correctamente
# [SILVER] Procesando batch_id=1185
# [SILVER] batch_id=1185 escrito correctamente
# [SILVER] Procesando batch_id=1186
# [SILVER] batch_id=1186 escrito correctamente
# [SILVER] Procesando batch_id=1187
# [SILVER] batch_id=1187 escrito correctamente
# [SILVER] Procesando batch_id=1188
# [SILVER] batch_id=1188 escrito correctamente
# [SILVER] Procesando batch_id=1189
# [SILVER] batch_id=1189 escrito correctamente
# [SILVER] Procesando batch_id=1190
# [SILVER] batch_id=1190 escrito correctamente
# [SILVER] Procesando batch_id=1191
# [SILVER] batch_id=1191 escrito correctamente
# [SILVER] Procesando batch_id=1192
# [SILVER] batch_id=1192 escrito correctamente
# [SILVER] Procesando batch_id=1193
# [SILVER] batch_id=1193 escrito correctamente
# [SILVER] Procesando batch_id=1194
# [SILVER] batch_id=1194 escrito correctamente
# [SILVER] Procesando batch_id=1195
# [SILVER] batch_id=1195 escrito correctamente
# [SILVER] Procesando batch_id=1196
# [SILVER] batch_id=1196 escrito correctamente
# [SILVER] Procesando batch_id=1197
# [SILVER] batch_id=1197 escrito correctamente
# [SILVER] Procesando batch_id=1198
# [SILVER] batch_id=1198 escrito correctamente
# [SILVER] Procesando batch_id=1199
# [SILVER] batch_id=1199 escrito correctamente
# [SILVER] Procesando batch_id=1200
# [SILVER] batch_id=1200 escrito correctamente
# [SILVER] Procesando batch_id=1201
# [SILVER] batch_id=1201 escrito correctamente
# [SILVER] Procesando batch_id=1202
# [SILVER] batch_id=1202 escrito correctamente
# [SILVER] Procesando batch_id=1203
# [SILVER] batch_id=1203 escrito correctamente
# [SILVER] Procesando batch_id=1204
# [SILVER] batch_id=1204 escrito correctamente
# [SILVER] Procesando batch_id=1205
# [SILVER] batch_id=1205 escrito correctamente
# [SILVER] Procesando batch_id=1206
# [SILVER] batch_id=1206 escrito correctamente
# [SILVER] Procesando batch_id=1207
# [SILVER] batch_id=1207 escrito correctamente
# [SILVER] Procesando batch_id=1208
# [SILVER] batch_id=1208 escrito correctamente
# [SILVER] Procesando batch_id=1209
# [SILVER] batch_id=1209 escrito correctamente
# [SILVER] Procesando batch_id=1210
# [SILVER] batch_id=1210 escrito correctamente
# [SILVER] Procesando batch_id=1211
# [SILVER] batch_id=1211 escrito correctamente
# [SILVER] Procesando batch_id=1212
# [SILVER] batch_id=1212 escrito correctamente
# [SILVER] Procesando batch_id=1213
# [SILVER] batch_id=1213 escrito correctamente
# [SILVER] Procesando batch_id=1214
# [SILVER] batch_id=1214 escrito correctamente
# [SILVER] Procesando batch_id=1215
# [SILVER] batch_id=1215 escrito correctamente
# [SILVER] Procesando batch_id=1216
# [SILVER] batch_id=1216 escrito correctamente
# [SILVER] Procesando batch_id=1217
# [SILVER] batch_id=1217 escrito correctamente
# [SILVER] Procesando batch_id=1218
# [SILVER] batch_id=1218 escrito correctamente
# [SILVER] Procesando batch_id=1219
# [SILVER] batch_id=1219 escrito correctamente
# [SILVER] Procesando batch_id=1220
# [SILVER] batch_id=1220 escrito correctamente
# [SILVER] Procesando batch_id=1221
# [SILVER] batch_id=1221 escrito correctamente
# [SILVER] Procesando batch_id=1222
# [SILVER] batch_id=1222 escrito correctamente
# [SILVER] Procesando batch_id=1223
# [SILVER] batch_id=1223 escrito correctamente
# [SILVER] Procesando batch_id=1224
# [SILVER] batch_id=1224 escrito correctamente
# [SILVER] Procesando batch_id=1225
# [SILVER] batch_id=1225 escrito correctamente
# [SILVER] Procesando batch_id=1226
# [SILVER] batch_id=1226 escrito correctamente
# [SILVER] Procesando batch_id=1227
# [SILVER] batch_id=1227 escrito correctamente
# [SILVER] Procesando batch_id=1228
# [SILVER] batch_id=1228 escrito correctamente
# [SILVER] Procesando batch_id=1229
# [SILVER] batch_id=1229 escrito correctamente
# [SILVER] Procesando batch_id=1230
# [SILVER] batch_id=1230 escrito correctamente
# [SILVER] Procesando batch_id=1231
# [SILVER] batch_id=1231 escrito correctamente
# [SILVER] Procesando batch_id=1232
# [SILVER] batch_id=1232 escrito correctamente
# [SILVER] Procesando batch_id=1233
# [SILVER] batch_id=1233 escrito correctamente
# [SILVER] Procesando batch_id=1234
# [SILVER] batch_id=1234 escrito correctamente
# [SILVER] Procesando batch_id=1235
# [SILVER] batch_id=1235 escrito correctamente
# [SILVER] Procesando batch_id=1236
# [SILVER] batch_id=1236 escrito correctamente
# [SILVER] Procesando batch_id=1237
# [SILVER] batch_id=1237 escrito correctamente
# [SILVER] Procesando batch_id=1238
# [SILVER] batch_id=1238 escrito correctamente
# [SILVER] Procesando batch_id=1239
# [SILVER] batch_id=1239 escrito correctamente
# [SILVER] Procesando batch_id=1240
# [SILVER] batch_id=1240 escrito correctamente
# [SILVER] Procesando batch_id=1241
# [SILVER] batch_id=1241 escrito correctamente
# [SILVER] Procesando batch_id=1242
# [SILVER] batch_id=1242 escrito correctamente
# [SILVER] Procesando batch_id=1243
# [SILVER] batch_id=1243 escrito correctamente
# [SILVER] Procesando batch_id=1244
# [SILVER] batch_id=1244 escrito correctamente
# [SILVER] Procesando batch_id=1245
# [SILVER] batch_id=1245 escrito correctamente
# [SILVER] Procesando batch_id=1246
# [SILVER] batch_id=1246 escrito correctamente
# [SILVER] Procesando batch_id=1247
# [SILVER] batch_id=1247 escrito correctamente
# [SILVER] Procesando batch_id=1248
# [SILVER] batch_id=1248 escrito correctamente
# [SILVER] Procesando batch_id=1249
# [SILVER] batch_id=1249 escrito correctamente
# [SILVER] Procesando batch_id=1250
# [SILVER] batch_id=1250 escrito correctamente
# [SILVER] Procesando batch_id=1251
# [SILVER] batch_id=1251 escrito correctamente
# [SILVER] Procesando batch_id=1252
# [SILVER] batch_id=1252 escrito correctamente
# [SILVER] Procesando batch_id=1253
# [SILVER] batch_id=1253 escrito correctamente
# [SILVER] Procesando batch_id=1254
# [SILVER] batch_id=1254 escrito correctamente
# [SILVER] Procesando batch_id=1255
# [SILVER] batch_id=1255 escrito correctamente
# [SILVER] Procesando batch_id=1256
# [SILVER] batch_id=1256 escrito correctamente
# [SILVER] Procesando batch_id=1257
# [SILVER] batch_id=1257 escrito correctamente
# [SILVER] Procesando batch_id=1258
# [SILVER] batch_id=1258 escrito correctamente
# [SILVER] Procesando batch_id=1259
# [SILVER] batch_id=1259 escrito correctamente
# [SILVER] Procesando batch_id=1260
# [SILVER] batch_id=1260 escrito correctamente
# [SILVER] Procesando batch_id=1261
# [SILVER] batch_id=1261 escrito correctamente
# [SILVER] Procesando batch_id=1262
# [SILVER] batch_id=1262 escrito correctamente
# [SILVER] Procesando batch_id=1263
# [SILVER] batch_id=1263 escrito correctamente
# [SILVER] Procesando batch_id=1264
# [SILVER] batch_id=1264 escrito correctamente
# [SILVER] Procesando batch_id=1265
# [SILVER] batch_id=1265 escrito correctamente
# [SILVER] Procesando batch_id=1266
# [SILVER] batch_id=1266 escrito correctamente
# [SILVER] Procesando batch_id=1267
# [SILVER] batch_id=1267 escrito correctamente
# [SILVER] Procesando batch_id=1268
# [SILVER] batch_id=1268 escrito correctamente
# [SILVER] Procesando batch_id=1269
# [SILVER] batch_id=1269 escrito correctamente
# [SILVER] Procesando batch_id=1270
# [SILVER] batch_id=1270 escrito correctamente
# [SILVER] Procesando batch_id=1271
# [SILVER] batch_id=1271 escrito correctamente
# [SILVER] Procesando batch_id=1272
# [SILVER] batch_id=1272 escrito correctamente
# [SILVER] Procesando batch_id=1273
# [SILVER] batch_id=1273 escrito correctamente
# [SILVER] Procesando batch_id=1274
# [SILVER] batch_id=1274 escrito correctamente
# [SILVER] Procesando batch_id=1275
# [SILVER] batch_id=1275 escrito correctamente
# [SILVER] Procesando batch_id=1276
# [SILVER] batch_id=1276 escrito correctamente
# [SILVER] Procesando batch_id=1277
# [SILVER] batch_id=1277 escrito correctamente
# [SILVER] Procesando batch_id=1278
# [SILVER] batch_id=1278 escrito correctamente
# [SILVER] Procesando batch_id=1279
# [SILVER] batch_id=1279 escrito correctamente
# [SILVER] Procesando batch_id=1280
# [SILVER] batch_id=1280 escrito correctamente
# [SILVER] Procesando batch_id=1281
# [SILVER] batch_id=1281 escrito correctamente
# [SILVER] Procesando batch_id=1282
# [SILVER] batch_id=1282 escrito correctamente
# [SILVER] Procesando batch_id=1283
# [SILVER] batch_id=1283 escrito correctamente
# [SILVER] Procesando batch_id=1284
# [SILVER] batch_id=1284 escrito correctamente
# [SILVER] Procesando batch_id=1285
# [SILVER] batch_id=1285 escrito correctamente
# [SILVER] Procesando batch_id=1286
# [SILVER] batch_id=1286 escrito correctamente
# [SILVER] Procesando batch_id=1287
# [SILVER] batch_id=1287 escrito correctamente
# [SILVER] Procesando batch_id=1288
# [SILVER] batch_id=1288 escrito correctamente
# [SILVER] Procesando batch_id=1289
# [SILVER] batch_id=1289 escrito correctamente
# [SILVER] Procesando batch_id=1290
# [SILVER] batch_id=1290 escrito correctamente
# [SILVER] Procesando batch_id=1291
# [SILVER] batch_id=1291 escrito correctamente
# [SILVER] Procesando batch_id=1292
# [SILVER] batch_id=1292 escrito correctamente
# [SILVER] Procesando batch_id=1293
# [SILVER] batch_id=1293 escrito correctamente
# [SILVER] Procesando batch_id=1294
# [SILVER] batch_id=1294 escrito correctamente
# [SILVER] Procesando batch_id=1295
# [SILVER] batch_id=1295 escrito correctamente
# [SILVER] Procesando batch_id=1296
# [SILVER] batch_id=1296 escrito correctamente
# [SILVER] Procesando batch_id=1297
# [SILVER] batch_id=1297 escrito correctamente
# [SILVER] Procesando batch_id=1298
# [SILVER] batch_id=1298 escrito correctamente
# [SILVER] Procesando batch_id=1299
# [SILVER] batch_id=1299 escrito correctamente
# [SILVER] Procesando batch_id=1300
# [SILVER] batch_id=1300 escrito correctamente
# [SILVER] Procesando batch_id=1301
# [SILVER] batch_id=1301 escrito correctamente
# [SILVER] Procesando batch_id=1302
# [SILVER] batch_id=1302 escrito correctamente
# [SILVER] Procesando batch_id=1303
# [SILVER] batch_id=1303 escrito correctamente
# [SILVER] Procesando batch_id=1304
# [SILVER] batch_id=1304 escrito correctamente
# [SILVER] Procesando batch_id=1305
# [SILVER] batch_id=1305 escrito correctamente
# [SILVER] Procesando batch_id=1306
# [SILVER] batch_id=1306 escrito correctamente
# [SILVER] Procesando batch_id=1307
# [SILVER] batch_id=1307 escrito correctamente
# [SILVER] Procesando batch_id=1308
# [SILVER] batch_id=1308 escrito correctamente
# [SILVER] Procesando batch_id=1309
# [SILVER] batch_id=1309 escrito correctamente
# [SILVER] Procesando batch_id=1310
# [SILVER] batch_id=1310 escrito correctamente
# [SILVER] Procesando batch_id=1311
# [SILVER] batch_id=1311 escrito correctamente
# [SILVER] Procesando batch_id=1312
# [SILVER] batch_id=1312 escrito correctamente
# [SILVER] Procesando batch_id=1313
# [SILVER] batch_id=1313 escrito correctamente
# [SILVER] Procesando batch_id=1314
# [SILVER] batch_id=1314 escrito correctamente
# [SILVER] Procesando batch_id=1315
# [SILVER] batch_id=1315 escrito correctamente
# [SILVER] Procesando batch_id=1316
# [SILVER] batch_id=1316 escrito correctamente
# [SILVER] Procesando batch_id=1317
# [SILVER] batch_id=1317 escrito correctamente
# [SILVER] Procesando batch_id=1318
# [SILVER] batch_id=1318 escrito correctamente
# [SILVER] Procesando batch_id=1319
# [SILVER] batch_id=1319 escrito correctamente
# [SILVER] Procesando batch_id=1320
# [SILVER] batch_id=1320 escrito correctamente
# [SILVER] Procesando batch_id=1321
# [SILVER] batch_id=1321 escrito correctamente
# [SILVER] Procesando batch_id=1322
# [SILVER] batch_id=1322 escrito correctamente
# [SILVER] Procesando batch_id=1323
# [SILVER] batch_id=1323 escrito correctamente
# [SILVER] Procesando batch_id=1324
# [SILVER] batch_id=1324 escrito correctamente
# [SILVER] Procesando batch_id=1325
# [SILVER] batch_id=1325 escrito correctamente
# [SILVER] Procesando batch_id=1326
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# silver_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/silver/activos"
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# df_silver = spark.read.format("delta").load(silver_path)
# #df_silver.show(20, truncate=False)
# display(df_silver)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# spark.sql(f"""
# ALTER TABLE delta.`{silver_path}`
# ADD COLUMNS (coste_opera_h DOUBLE)
# """)

# spark.sql(f"""
# UPDATE delta.`{silver_path}`
# SET coste_opera_h =
#   CASE
#     WHEN asset_class = 'Acciones' THEN 0.01
#     WHEN asset_class = 'Fondos' THEN 0.0001
#     WHEN asset_class = 'Forex' THEN 0.0002
#     WHEN asset_class = 'Cripto' THEN 0.01
#     WHEN asset_class = 'Commodities' THEN 0.01
#     ELSE NULL
#   END
# WHERE coste_opera_h IS NULL
# """)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# spark.read.format("delta") \
#     .load(silver_path) \
#     .select("asset_class", "coste_opera_h") \
#     .groupBy("asset_class", "coste_opera_h") \
#     .count() \
#     .display()
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# display(df_silver.select("asset_class").distinct())
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# from pyspark.sql.functions import col

# df_null_names = (
#     df_silver
#     .filter(col("asset_class").isNull())
# )

# df_null_names.show(truncate=False)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# dbutils.fs.rm(silver_path, recurse=True)
# dbutils.fs.rm(checkpoint_path, recurse=True)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# from delta.tables import DeltaTable
# from pyspark.sql.functions import col

# silver_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/silver/activos"

# silver_table = DeltaTable.forPath(spark, silver_path)

# silver_table.update(
#     condition=col("symbol") == "LTC-USD",
#     set={
#         "asset_class": "'Cripto'",
#         "asset_name": "'Litecoin'"
#     }
# )
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# from delta.tables import DeltaTable

# delta_table = DeltaTable.forPath(
#     spark,
#     "abfss://datos@mastertfm001sta.dfs.core.windows.net/silver/activos"
# )

# delta_table.delete("year = '2026'")
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# df_silver.columns
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)
