# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, broadcast

# %%
gold_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/gold/activos"

# Pon tu csv aquí. Recomendado guardarlo en ADLS también:
# por ejemplo: abfss://datos@.../gold/config/estrategias_optimas.csv
estrategias_csv_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/gold/config/estrategias_optimas_vf.csv"

alerts_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/gold/alerts"
checkpoint_path = alerts_path + "/_checkpoint_inference"

# %%
spark = (
    SparkSession.builder
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

spark.conf.set("spark.sql.session.timeZone", "Europe/Madrid")

# %%
estrategias_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(estrategias_csv_path)
)

# Opción A, filtrar por pasa_filtro si existe
if "pasa_filtro" in estrategias_df.columns:
    estrategias_apto = estrategias_df.filter(col("pasa_filtro") == True)
else:
    # Opción B, filtrar por clasificacion
    estrategias_apto = estrategias_df.filter(col("clasificacion").isin(["APTO FUERTE 🚀", "APTO MEDIO ✅", "APTO DÉBIL ⚠️"]))

estrategias_apto = estrategias_apto.select(
    "asset_name", "best_x", "best_k", "best_n", "best_j"
)

display(estrategias_apto)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>asset_name</th><th>best_x</th><th>best_k</th><th>best_n</th><th>best_j</th></tr></thead><tbody><tr><td>PLTR</td><td>37</td><td>3</td><td>16</td><td>4.0E-4</td></tr><tr><td>SPCE</td><td>47</td><td>2</td><td>19</td><td>0.002</td></tr><tr><td>ZM</td><td>33</td><td>3</td><td>18</td><td>0.0015</td></tr><tr><td>SOXX</td><td>51</td><td>2</td><td>19</td><td>2.0E-4</td></tr><tr><td>LCID</td><td>53</td><td>6</td><td>16</td><td>0.0</td></tr><tr><td>ARKK</td><td>29</td><td>2</td><td>19</td><td>2.0E-4</td></tr><tr><td>COIN</td><td>36</td><td>3</td><td>19</td><td>0.002</td></tr><tr><td>ADA-USD</td><td>47</td><td>7</td><td>9</td><td>0.0015</td></tr><tr><td>DOGE-USD</td><td>32</td><td>2</td><td>18</td><td>0.002</td></tr><tr><td>AMD</td><td>46</td><td>3</td><td>16</td><td>0.002</td></tr><tr><td>QQQ</td><td>35</td><td>2</td><td>12</td><td>0.001</td></tr><tr><td>RIVN</td><td>48</td><td>5</td><td>19</td><td>6.0E-4</td></tr><tr><td>SHOP</td><td>32</td><td>8</td><td>11</td><td>0.001</td></tr><tr><td>SPY</td><td>40</td><td>3</td><td>18</td><td>0.0</td></tr><tr><td>VUG</td><td>44</td><td>2</td><td>14</td><td>4.0E-4</td></tr><tr><td>VNQ</td><td>57</td><td>2</td><td>14</td><td>6.0E-4</td></tr><tr><td>VGK</td><td>58</td><td>3</td><td>19</td><td>0.0</td></tr><tr><td>EEM</td><td>44</td><td>2</td><td>19</td><td>0.0</td></tr><tr><td>NVDA</td><td>52</td><td>4</td><td>11</td><td>0.002</td></tr><tr><td>SCHD</td><td>16</td><td>2</td><td>14</td><td>0.0</td></tr></tbody></table></div>

# %%
gold_stream = (
    spark.readStream
    .format("delta")
    .load(gold_path)
)

# gold tiene: timestamp, symbol, asset_class, asset_name, coste_opera_h, close
stream_joined = (
    gold_stream
    .select("timestamp", "symbol", "asset_name", "close")
    .join(broadcast(estrategias_apto), on="asset_name", how="inner")
)

# %%
from collections import deque, defaultdict
import pandas as pd
import numpy as np

# Buffers y control de spam en DRIVER
BUFFERS = defaultdict(lambda: deque(maxlen=10_000))
LAST_ALERT_BIN = {}

# Convertir estrategias_apto (Spark DF) a dict en driver
# Asumimos pocos activos (decenas)
STRATEGIES = {
    r["asset_name"]: {
        "best_x": int(r["best_x"]),
        "best_k": int(r["best_k"]),
        "best_n": int(r["best_n"]),
        "best_j": float(r["best_j"])
    }
    for r in estrategias_apto.collect()
}

print(f"✅ Estrategias cargadas: {len(STRATEGIES)} activos")
# Out:
# ✅ Estrategias cargadas: 20 activos

# %%
# ============================
# WARM-UP HISTÓRICO DESDE GOLD
# ============================

from datetime import timedelta
from pyspark.sql.functions import col, max as spark_max

print("🔥 Iniciando warm-up histórico desde GOLD")

# 1️⃣ Calcular minutos necesarios (peor estrategia)
estrategias_pdf = estrategias_apto.toPandas()
estrategias_pdf["min_needed"] = (
    (estrategias_pdf["best_k"] + estrategias_pdf["best_n"] + 5)
    * estrategias_pdf["best_x"]
)

max_minutes_needed = int(estrategias_pdf["min_needed"].max())
print(f"⏱️ Ventana histórica necesaria: {max_minutes_needed} minutos")

# 2️⃣ Leer GOLD histórico
gold_hist = (
    spark.read
    .format("delta")
    .load(gold_path)
    .filter(col("asset_name").isin(estrategias_pdf["asset_name"].tolist()))
)

# 3️⃣ Determinar ventana temporal
max_ts = gold_hist.select(spark_max("timestamp")).collect()[0][0]
min_ts = max_ts - timedelta(minutes=max_minutes_needed)

gold_hist = gold_hist.filter(col("timestamp") >= min_ts)

# 4️⃣ Pasar a pandas y cargar buffers
pdf_hist = (
    gold_hist
    .select("timestamp", "asset_name", "close")
    .orderBy("asset_name", "timestamp")
    .toPandas()
)

for asset, g in pdf_hist.groupby("asset_name"):
    row = estrategias_pdf[estrategias_pdf["asset_name"] == asset].iloc[0]

    min_raw_needed = int(
        (row["best_k"] + row["best_n"] + 5) * row["best_x"]
    )

    BUFFERS[asset] = deque(maxlen=min_raw_needed * 2)

    for _, r in g.iterrows():
        BUFFERS[asset].append((r["timestamp"], float(r["close"])))

    print(f"✅ Warm-up {asset}: {len(BUFFERS[asset])} puntos cargados")

print("🔥 Warm-up completado")
# Out:
# 🔥 Iniciando warm-up histórico desde GOLD
# ⏱️ Ventana histórica necesaria: 1566 minutos
# ✅ Warm-up AMD: 968 puntos cargados
# 🔥 Warm-up completado

# %%
import traceback
from pyspark.sql.functions import col
from pyspark.sql import Row

def process_inference_batch(batch_df, batch_id: int):
    try:
        nrows = batch_df.count()
        print(f"[INFERENCE] batch_id={batch_id} rows={nrows}")

        if batch_df.rdd.isEmpty():
            print(f"[INFERENCE] batch_id={batch_id} vacío")
            return

        # 1) Filtrar SOLO activos aptos (presentes en STRATEGIES)
        sdf = (
            batch_df
            .select("timestamp", "asset_name", "symbol", "close")
            .filter(col("asset_name").isin(list(STRATEGIES.keys())))
        )

        if sdf.rdd.isEmpty():
            print(f"[INFERENCE] batch_id={batch_id} sin activos con estrategia")
            return

        # 2) A pandas lo mínimo, ya filtrado
        pdf = sdf.toPandas()
        pdf["timestamp"] = pd.to_datetime(pdf["timestamp"])
        pdf = pdf.sort_values(["asset_name", "timestamp"])

        alerts_out = []

        # 3) Loop por activo
        for asset, g in pdf.groupby("asset_name"):

            if asset not in STRATEGIES:
                continue

            params = STRATEGIES[asset]
            best_x = int(params["best_x"])
            best_k = int(params["best_k"])
            best_n = int(params["best_n"])
            best_j = float(params["best_j"])

            symbol = g["symbol"].iloc[0]

            # Necesidad mínima de datos brutos
            min_raw_needed = (best_k + best_n + 5) * best_x

            # Inicializar / ajustar buffer
            if asset not in BUFFERS:
                BUFFERS[asset] = deque(maxlen=min_raw_needed * 2)

            if BUFFERS[asset].maxlen < min_raw_needed * 2:
                BUFFERS[asset] = deque(BUFFERS[asset], maxlen=min_raw_needed * 2)

            # Añadir al buffer
            for _, row in g.iterrows():
                BUFFERS[asset].append((row["timestamp"], float(row["close"])))

            if len(BUFFERS[asset]) < min_raw_needed:
                continue

            # Serie y resample
            buf = list(BUFFERS[asset])
            s = pd.Series(
                data=[x[1] for x in buf],
                index=pd.DatetimeIndex([x[0] for x in buf])
            ).sort_index()

            rs = s.resample(f"{best_x}min").last().dropna()

            if len(rs) < (best_k + best_n + 2):
                continue

            prices = rs.values.astype(float)

            # Bin actual para anti spam
            bin_start = rs.index[-1].to_pydatetime()
            if LAST_ALERT_BIN.get(asset) == bin_start:
                continue

            # 4) Señal
            # IMPORTANTE: esta función debe existir en tu notebook
            signal, _ = compute_signal_from_resampled(prices, best_k, best_n, best_j)

            if signal is None:
                continue

            LAST_ALERT_BIN[asset] = bin_start

            alerts_out.append(Row(
                timestamp_alert=rs.index[-1].to_pydatetime(),
                asset_name=asset,
                symbol=symbol,
                best_x=best_x,
                best_k=best_k,
                best_n=best_n,
                best_j=best_j,
                signal=signal,
                price=float(prices[-1]),
                bin_start=bin_start
            ))

        # 5) Write alerts
        if not alerts_out:
            print(f"[INFERENCE] batch_id={batch_id} sin alertas")
            return

        alerts_sdf = spark.createDataFrame(alerts_out, schema=alert_schema)

        (
            alerts_sdf.write
            .format("delta")
            .mode("append")
            .save(alerts_path)
        )

        print(f"[INFERENCE] batch_id={batch_id} ALERTAS={len(alerts_out)}")
        alerts_sdf.show(truncate=False)

    except Exception as e:
        print("🔥 ERROR REAL EN INFERENCE FOREACH BATCH 🔥")
        traceback.print_exc()
        raise

# %%
query = (
    stream_joined.writeStream
    .foreachBatch(process_inference_batch)
    .option("checkpointLocation", checkpoint_path)
    .start()
)

query.awaitTermination()
# Out:
# [INFERENCE] batch_id=259 rows=0
# [INFERENCE] batch_id=259 vacío
# [INFERENCE] batch_id=260 rows=0
# [INFERENCE] batch_id=260 vacío
# [INFERENCE] batch_id=261 rows=0
# [INFERENCE] batch_id=261 vacío
# [INFERENCE] batch_id=262 rows=188
# [INFERENCE] batch_id=262 sin alertas
# [INFERENCE] batch_id=263 rows=0
# [INFERENCE] batch_id=263 vacío
# [INFERENCE] batch_id=264 rows=0
# [INFERENCE] batch_id=264 vacío
# [INFERENCE] batch_id=265 rows=0
# [INFERENCE] batch_id=265 vacío
# [INFERENCE] batch_id=266 rows=0
# [INFERENCE] batch_id=266 vacío
# [INFERENCE] batch_id=267 rows=0
# [INFERENCE] batch_id=267 vacío
# [INFERENCE] batch_id=268 rows=0
# [INFERENCE] batch_id=268 vacío
# [INFERENCE] batch_id=269 rows=0
# [INFERENCE] batch_id=269 vacío
# [INFERENCE] batch_id=270 rows=0
# [INFERENCE] batch_id=270 vacío
# [INFERENCE] batch_id=271 rows=0
# [INFERENCE] batch_id=271 vacío
# [INFERENCE] batch_id=272 rows=0
# [INFERENCE] batch_id=272 vacío
# [INFERENCE] batch_id=273 rows=0
# [INFERENCE] batch_id=273 vacío
# [INFERENCE] batch_id=274 rows=0
# [INFERENCE] batch_id=274 vacío
# [INFERENCE] batch_id=275 rows=0
# [INFERENCE] batch_id=275 vacío
# [INFERENCE] batch_id=276 rows=0
# [INFERENCE] batch_id=276 vacío
# [INFERENCE] batch_id=277 rows=0
# [INFERENCE] batch_id=277 vacío
# [INFERENCE] batch_id=278 rows=0
# [INFERENCE] batch_id=278 vacío
# [INFERENCE] batch_id=279 rows=0
# [INFERENCE] batch_id=279 vacío
# [INFERENCE] batch_id=280 rows=0
# [INFERENCE] batch_id=280 vacío
# [INFERENCE] batch_id=281 rows=0
# [INFERENCE] batch_id=281 vacío
# [INFERENCE] batch_id=282 rows=0
# [INFERENCE] batch_id=282 vacío
# [INFERENCE] batch_id=283 rows=0
# [INFERENCE] batch_id=283 vacío
# [INFERENCE] batch_id=284 rows=0
# [INFERENCE] batch_id=284 vacío
# [INFERENCE] batch_id=285 rows=0
# [INFERENCE] batch_id=285 vacío
# [INFERENCE] batch_id=286 rows=0
# [INFERENCE] batch_id=286 vacío
# [INFERENCE] batch_id=287 rows=0
# [INFERENCE] batch_id=287 vacío
# [INFERENCE] batch_id=288 rows=1
# [INFERENCE] batch_id=288 sin alertas
# [INFERENCE] batch_id=289 rows=0
# [INFERENCE] batch_id=289 vacío
# [INFERENCE] batch_id=290 rows=0
# [INFERENCE] batch_id=290 vacío
# [INFERENCE] batch_id=291 rows=0
# [INFERENCE] batch_id=291 vacío
# [INFERENCE] batch_id=292 rows=0
# [INFERENCE] batch_id=292 vacío
# [INFERENCE] batch_id=293 rows=0
# [INFERENCE] batch_id=293 vacío
# [INFERENCE] batch_id=294 rows=0
# [INFERENCE] batch_id=294 vacío
# [INFERENCE] batch_id=295 rows=0
# [INFERENCE] batch_id=295 vacío
# [INFERENCE] batch_id=296 rows=0
# [INFERENCE] batch_id=296 vacío
# [INFERENCE] batch_id=297 rows=0
# [INFERENCE] batch_id=297 vacío
# [INFERENCE] batch_id=298 rows=0
# [INFERENCE] batch_id=298 vacío
# [INFERENCE] batch_id=299 rows=0
# [INFERENCE] batch_id=299 vacío
# [INFERENCE] batch_id=300 rows=0
# [INFERENCE] batch_id=300 vacío
# [INFERENCE] batch_id=301 rows=0
# [INFERENCE] batch_id=301 vacío
# [INFERENCE] batch_id=302 rows=0
# [INFERENCE] batch_id=302 vacío
# [INFERENCE] batch_id=303 rows=0
# [INFERENCE] batch_id=303 vacío
# [INFERENCE] batch_id=304 rows=0
# [INFERENCE] batch_id=304 vacío
# [INFERENCE] batch_id=305 rows=0
# [INFERENCE] batch_id=305 vacío
# [INFERENCE] batch_id=306 rows=0
# [INFERENCE] batch_id=306 vacío
# [INFERENCE] batch_id=307 rows=0
# [INFERENCE] batch_id=307 vacío
# [INFERENCE] batch_id=308 rows=0
# [INFERENCE] batch_id=308 vacío
# [INFERENCE] batch_id=309 rows=0
# [INFERENCE] batch_id=309 vacío
# [INFERENCE] batch_id=310 rows=0
# [INFERENCE] batch_id=310 vacío
# [INFERENCE] batch_id=311 rows=0
# [INFERENCE] batch_id=311 vacío
# [INFERENCE] batch_id=312 rows=0
# [INFERENCE] batch_id=312 vacío
# [INFERENCE] batch_id=313 rows=0
# [INFERENCE] batch_id=313 vacío
# [INFERENCE] batch_id=314 rows=0
# [INFERENCE] batch_id=314 vacío
# [INFERENCE] batch_id=315 rows=2
# [INFERENCE] batch_id=315 sin alertas
# [INFERENCE] batch_id=316 rows=0
# [INFERENCE] batch_id=316 vacío
# [INFERENCE] batch_id=317 rows=0
# [INFERENCE] batch_id=317 vacío
# [INFERENCE] batch_id=318 rows=0
# [INFERENCE] batch_id=318 vacío
# [INFERENCE] batch_id=319 rows=0
# [INFERENCE] batch_id=319 vacío
# [INFERENCE] batch_id=320 rows=0
# [INFERENCE] batch_id=320 vacío
# [INFERENCE] batch_id=321 rows=0
# [INFERENCE] batch_id=321 vacío
# [INFERENCE] batch_id=322 rows=0
# [INFERENCE] batch_id=322 vacío
# [INFERENCE] batch_id=323 rows=0
# [INFERENCE] batch_id=323 vacío
# [INFERENCE] batch_id=324 rows=0
# [INFERENCE] batch_id=324 vacío
# [INFERENCE] batch_id=325 rows=0
# [INFERENCE] batch_id=325 vacío
# [INFERENCE] batch_id=326 rows=0
# [INFERENCE] batch_id=326 vacío
# [INFERENCE] batch_id=327 rows=0
# [INFERENCE] batch_id=327 vacío
# [INFERENCE] batch_id=328 rows=0
# [INFERENCE] batch_id=328 vacío
# [INFERENCE] batch_id=329 rows=0
# [INFERENCE] batch_id=329 vacío
# [INFERENCE] batch_id=330 rows=0
# [INFERENCE] batch_id=330 vacío
# [INFERENCE] batch_id=331 rows=0
# [INFERENCE] batch_id=331 vacío
# [INFERENCE] batch_id=332 rows=0
# [INFERENCE] batch_id=332 vacío
# [INFERENCE] batch_id=333 rows=0
# [INFERENCE] batch_id=333 vacío
# [INFERENCE] batch_id=334 rows=0
# [INFERENCE] batch_id=334 vacío
# [INFERENCE] batch_id=335 rows=0
# [INFERENCE] batch_id=335 vacío
# [INFERENCE] batch_id=336 rows=0
# [INFERENCE] batch_id=336 vacío
# [INFERENCE] batch_id=337 rows=0
# [INFERENCE] batch_id=337 vacío
# [INFERENCE] batch_id=338 rows=1
# [INFERENCE] batch_id=338 sin alertas
# [INFERENCE] batch_id=339 rows=0
# [INFERENCE] batch_id=339 vacío
# [INFERENCE] batch_id=340 rows=0
# [INFERENCE] batch_id=340 vacío
# [INFERENCE] batch_id=341 rows=0
# [INFERENCE] batch_id=341 vacío
# [INFERENCE] batch_id=342 rows=0
# [INFERENCE] batch_id=342 vacío
# [INFERENCE] batch_id=343 rows=0
# [INFERENCE] batch_id=343 vacío
# [INFERENCE] batch_id=344 rows=0
# [INFERENCE] batch_id=344 vacío
# [INFERENCE] batch_id=345 rows=0
# [INFERENCE] batch_id=345 vacío
# [INFERENCE] batch_id=346 rows=0
# [INFERENCE] batch_id=346 vacío
# [INFERENCE] batch_id=347 rows=0
# [INFERENCE] batch_id=347 vacío
# [INFERENCE] batch_id=348 rows=0
# [INFERENCE] batch_id=348 vacío
# [INFERENCE] batch_id=349 rows=0
# [INFERENCE] batch_id=349 vacío
# [INFERENCE] batch_id=350 rows=0
# [INFERENCE] batch_id=350 vacío
# [INFERENCE] batch_id=351 rows=0
# [INFERENCE] batch_id=351 vacío
# [INFERENCE] batch_id=352 rows=0
# [INFERENCE] batch_id=352 vacío
# [INFERENCE] batch_id=353 rows=0
# [INFERENCE] batch_id=353 vacío
# [INFERENCE] batch_id=354 rows=0
# [INFERENCE] batch_id=354 vacío
# [INFERENCE] batch_id=355 rows=0
# [INFERENCE] batch_id=355 vacío
# [INFERENCE] batch_id=356 rows=0
# [INFERENCE] batch_id=356 vacío
# [INFERENCE] batch_id=357 rows=0
# [INFERENCE] batch_id=357 vacío
# [INFERENCE] batch_id=358 rows=0
# [INFERENCE] batch_id=358 vacío
# [INFERENCE] batch_id=359 rows=0
# [INFERENCE] batch_id=359 vacío
# [INFERENCE] batch_id=360 rows=0
# [INFERENCE] batch_id=360 vacío
# [INFERENCE] batch_id=361 rows=0
# [INFERENCE] batch_id=361 vacío
# [INFERENCE] batch_id=362 rows=0
# [INFERENCE] batch_id=362 vacío
# [INFERENCE] batch_id=363 rows=2
# [INFERENCE] batch_id=363 sin alertas
# [INFERENCE] batch_id=364 rows=0
# [INFERENCE] batch_id=364 vacío
# [INFERENCE] batch_id=365 rows=0
# [INFERENCE] batch_id=365 vacío
# [INFERENCE] batch_id=366 rows=0
# [INFERENCE] batch_id=366 vacío
# [INFERENCE] batch_id=367 rows=0
# [INFERENCE] batch_id=367 vacío
# [INFERENCE] batch_id=368 rows=0
# [INFERENCE] batch_id=368 vacío
# [INFERENCE] batch_id=369 rows=0
# [INFERENCE] batch_id=369 vacío
# [INFERENCE] batch_id=370 rows=0
# [INFERENCE] batch_id=370 vacío
# [INFERENCE] batch_id=371 rows=0
# [INFERENCE] batch_id=371 vacío
# [INFERENCE] batch_id=372 rows=0
# [INFERENCE] batch_id=372 vacío
# [INFERENCE] batch_id=373 rows=0
# [INFERENCE] batch_id=373 vacío
# [INFERENCE] batch_id=374 rows=0
# [INFERENCE] batch_id=374 vacío
# [INFERENCE] batch_id=375 rows=0
# [INFERENCE] batch_id=375 vacío
# [INFERENCE] batch_id=376 rows=0
# [INFERENCE] batch_id=376 vacío
# [INFERENCE] batch_id=377 rows=0
# [INFERENCE] batch_id=377 vacío
# [INFERENCE] batch_id=378 rows=0
# [INFERENCE] batch_id=378 vacío
# [INFERENCE] batch_id=379 rows=0
# [INFERENCE] batch_id=379 vacío
# [INFERENCE] batch_id=380 rows=0
# [INFERENCE] batch_id=380 vacío
# [INFERENCE] batch_id=381 rows=0
# [INFERENCE] batch_id=381 vacío
# [INFERENCE] batch_id=382 rows=0
# [INFERENCE] batch_id=382 vacío
# [INFERENCE] batch_id=383 rows=0
# [INFERENCE] batch_id=383 vacío
# [INFERENCE] batch_id=384 rows=1
# [INFERENCE] batch_id=384 sin alertas
# [INFERENCE] batch_id=385 rows=0
# [INFERENCE] batch_id=385 vacío
# [INFERENCE] batch_id=386 rows=0
# [INFERENCE] batch_id=386 vacío
# [INFERENCE] batch_id=387 rows=0
# [INFERENCE] batch_id=387 vacío
# [INFERENCE] batch_id=388 rows=0
# [INFERENCE] batch_id=388 vacío
# [INFERENCE] batch_id=389 rows=0
# [INFERENCE] batch_id=389 vacío
# [INFERENCE] batch_id=390 rows=0
# [INFERENCE] batch_id=390 vacío
# [INFERENCE] batch_id=391 rows=0
# [INFERENCE] batch_id=391 vacío
# [INFERENCE] batch_id=392 rows=0
# [INFERENCE] batch_id=392 vacío
# [INFERENCE] batch_id=393 rows=0
# [INFERENCE] batch_id=393 vacío
# [INFERENCE] batch_id=394 rows=0
# [INFERENCE] batch_id=394 vacío
# [INFERENCE] batch_id=395 rows=0
# [INFERENCE] batch_id=395 vacío
# [INFERENCE] batch_id=396 rows=0
# [INFERENCE] batch_id=396 vacío
# [INFERENCE] batch_id=397 rows=0
# [INFERENCE] batch_id=397 vacío
# [INFERENCE] batch_id=398 rows=0
# [INFERENCE] batch_id=398 vacío
# [INFERENCE] batch_id=399 rows=0
# [INFERENCE] batch_id=399 vacío
# [INFERENCE] batch_id=400 rows=0
# [INFERENCE] batch_id=400 vacío
# [INFERENCE] batch_id=401 rows=0
# [INFERENCE] batch_id=401 vacío
# [INFERENCE] batch_id=402 rows=0
# [INFERENCE] batch_id=402 vacío
# [INFERENCE] batch_id=403 rows=0
# [INFERENCE] batch_id=403 vacío
# [INFERENCE] batch_id=404 rows=0
# [INFERENCE] batch_id=404 vacío
# [INFERENCE] batch_id=405 rows=0
# [INFERENCE] batch_id=405 vacío
# [INFERENCE] batch_id=406 rows=0
# [INFERENCE] batch_id=406 vacío
# [INFERENCE] batch_id=407 rows=0
# [INFERENCE] batch_id=407 vacío
# [INFERENCE] batch_id=408 rows=0
# [INFERENCE] batch_id=408 vacío
# [INFERENCE] batch_id=409 rows=1
# [INFERENCE] batch_id=409 sin alertas
# [INFERENCE] batch_id=410 rows=0
# [INFERENCE] batch_id=410 vacío
# [INFERENCE] batch_id=411 rows=0
# [INFERENCE] batch_id=411 vacío
# [INFERENCE] batch_id=412 rows=0
# [INFERENCE] batch_id=412 vacío
# [INFERENCE] batch_id=413 rows=0
# [INFERENCE] batch_id=413 vacío
# [INFERENCE] batch_id=414 rows=0
# [INFERENCE] batch_id=414 vacío
# [INFERENCE] batch_id=415 rows=0
# [INFERENCE] batch_id=415 vacío
# [INFERENCE] batch_id=416 rows=0
# [INFERENCE] batch_id=416 vacío
# [INFERENCE] batch_id=417 rows=0
# [INFERENCE] batch_id=417 vacío
# [INFERENCE] batch_id=418 rows=0
# [INFERENCE] batch_id=418 vacío
# [INFERENCE] batch_id=419 rows=0
# [INFERENCE] batch_id=419 vacío
# [INFERENCE] batch_id=420 rows=0
# [INFERENCE] batch_id=420 vacío
# [INFERENCE] batch_id=421 rows=0
# [INFERENCE] batch_id=421 vacío
# [INFERENCE] batch_id=422 rows=0
# [INFERENCE] batch_id=422 vacío
# [INFERENCE] batch_id=423 rows=0
# [INFERENCE] batch_id=423 vacío
# [INFERENCE] batch_id=424 rows=0
# [INFERENCE] batch_id=424 vacío
# [INFERENCE] batch_id=425 rows=0
# [INFERENCE] batch_id=425 vacío
# [INFERENCE] batch_id=426 rows=0
# [INFERENCE] batch_id=426 vacío
# [INFERENCE] batch_id=427 rows=0
# [INFERENCE] batch_id=427 vacío
# [INFERENCE] batch_id=428 rows=0
# [INFERENCE] batch_id=428 vacío
# [INFERENCE] batch_id=429 rows=0
# [INFERENCE] batch_id=429 vacío
# [INFERENCE] batch_id=430 rows=0
# [INFERENCE] batch_id=430 vacío
# [INFERENCE] batch_id=431 rows=1
# [INFERENCE] batch_id=431 sin alertas
# [INFERENCE] batch_id=432 rows=0
# [INFERENCE] batch_id=432 vacío
# [INFERENCE] batch_id=433 rows=0
# [INFERENCE] batch_id=433 vacío
# [INFERENCE] batch_id=434 rows=0
# [INFERENCE] batch_id=434 vacío
# [INFERENCE] batch_id=435 rows=0
# [INFERENCE] batch_id=435 vacío
# [INFERENCE] batch_id=436 rows=0
# [INFERENCE] batch_id=436 vacío
# [INFERENCE] batch_id=437 rows=0
# [INFERENCE] batch_id=437 vacío
# [INFERENCE] batch_id=438 rows=0
# [INFERENCE] batch_id=438 vacío
# [INFERENCE] batch_id=439 rows=0
# [INFERENCE] batch_id=439 vacío
# [INFERENCE] batch_id=440 rows=0
# [INFERENCE] batch_id=440 vacío
# [INFERENCE] batch_id=441 rows=0
# [INFERENCE] batch_id=441 vacío
# [INFERENCE] batch_id=442 rows=0
# [INFERENCE] batch_id=442 vacío
# [INFERENCE] batch_id=443 rows=0
# [INFERENCE] batch_id=443 vacío
# [INFERENCE] batch_id=444 rows=0
# [INFERENCE] batch_id=444 vacío
# [INFERENCE] batch_id=445 rows=0
# [INFERENCE] batch_id=445 vacío
# [INFERENCE] batch_id=446 rows=0
# [INFERENCE] batch_id=446 vacío
# [INFERENCE] batch_id=447 rows=0
# [INFERENCE] batch_id=447 vacío
# [INFERENCE] batch_id=448 rows=0
# [INFERENCE] batch_id=448 vacío
# [INFERENCE] batch_id=449 rows=0
# [INFERENCE] batch_id=449 vacío
# [INFERENCE] batch_id=450 rows=0
# [INFERENCE] batch_id=450 vacío
# [INFERENCE] batch_id=451 rows=0
# [INFERENCE] batch_id=451 vacío
# [INFERENCE] batch_id=452 rows=0
# [INFERENCE] batch_id=452 vacío
# [INFERENCE] batch_id=453 rows=0
# [INFERENCE] batch_id=453 vacío
# [INFERENCE] batch_id=454 rows=0
# [INFERENCE] batch_id=454 vacío
# [INFERENCE] batch_id=455 rows=0
# [INFERENCE] batch_id=455 vacío
# [INFERENCE] batch_id=456 rows=0
# [INFERENCE] batch_id=456 vacío
# [INFERENCE] batch_id=457 rows=1
# [INFERENCE] batch_id=457 sin alertas
# [INFERENCE] batch_id=458 rows=0
# [INFERENCE] batch_id=458 vacío
# [INFERENCE] batch_id=459 rows=0
# [INFERENCE] batch_id=459 vacío
# [INFERENCE] batch_id=460 rows=0
# [INFERENCE] batch_id=460 vacío
# [INFERENCE] batch_id=461 rows=0
# [INFERENCE] batch_id=461 vacío
# [INFERENCE] batch_id=462 rows=0
# [INFERENCE] batch_id=462 vacío
# [INFERENCE] batch_id=463 rows=0
# [INFERENCE] batch_id=463 vacío
# [INFERENCE] batch_id=464 rows=0
# [INFERENCE] batch_id=464 vacío
# [INFERENCE] batch_id=465 rows=0
# [INFERENCE] batch_id=465 vacío
# [INFERENCE] batch_id=466 rows=0
# [INFERENCE] batch_id=466 vacío
# [INFERENCE] batch_id=467 rows=0
# [INFERENCE] batch_id=467 vacío
# [INFERENCE] batch_id=468 rows=0
# [INFERENCE] batch_id=468 vacío
# [INFERENCE] batch_id=469 rows=0
# [INFERENCE] batch_id=469 vacío
# [INFERENCE] batch_id=470 rows=0
# [INFERENCE] batch_id=470 vacío
# [INFERENCE] batch_id=471 rows=0
# [INFERENCE] batch_id=471 vacío
# [INFERENCE] batch_id=472 rows=0
# [INFERENCE] batch_id=472 vacío
# [INFERENCE] batch_id=473 rows=0
# [INFERENCE] batch_id=473 vacío
# [INFERENCE] batch_id=474 rows=0
# [INFERENCE] batch_id=474 vacío
# [INFERENCE] batch_id=475 rows=0
# [INFERENCE] batch_id=475 vacío
# [INFERENCE] batch_id=476 rows=0
# [INFERENCE] batch_id=476 vacío
# [INFERENCE] batch_id=477 rows=0
# [INFERENCE] batch_id=477 vacío
# [INFERENCE] batch_id=478 rows=0
# [INFERENCE] batch_id=478 vacío
# [INFERENCE] batch_id=479 rows=0
# [INFERENCE] batch_id=479 vacío
# [INFERENCE] batch_id=480 rows=0
# [INFERENCE] batch_id=480 vacío
# [INFERENCE] batch_id=481 rows=1
# [INFERENCE] batch_id=481 sin alertas
# [INFERENCE] batch_id=482 rows=0
# [INFERENCE] batch_id=482 vacío
# [INFERENCE] batch_id=483 rows=0
# [INFERENCE] batch_id=483 vacío
# [INFERENCE] batch_id=484 rows=0
# [INFERENCE] batch_id=484 vacío
# [INFERENCE] batch_id=485 rows=0
# [INFERENCE] batch_id=485 vacío
# [INFERENCE] batch_id=486 rows=0
# [INFERENCE] batch_id=486 vacío
# [INFERENCE] batch_id=487 rows=0
# [INFERENCE] batch_id=487 vacío
# [INFERENCE] batch_id=488 rows=0
# [INFERENCE] batch_id=488 vacío
# [INFERENCE] batch_id=489 rows=0
# [INFERENCE] batch_id=489 vacío
# [INFERENCE] batch_id=490 rows=0
# [INFERENCE] batch_id=490 vacío
# [INFERENCE] batch_id=491 rows=0
# [INFERENCE] batch_id=491 vacío
# [INFERENCE] batch_id=492 rows=0
# [INFERENCE] batch_id=492 vacío
# [INFERENCE] batch_id=493 rows=0
# [INFERENCE] batch_id=493 vacío
# [INFERENCE] batch_id=494 rows=0
# [INFERENCE] batch_id=494 vacío
# [INFERENCE] batch_id=495 rows=0
# [INFERENCE] batch_id=495 vacío
# [INFERENCE] batch_id=496 rows=0
# [INFERENCE] batch_id=496 vacío
# [INFERENCE] batch_id=497 rows=0
# [INFERENCE] batch_id=497 vacío
# [INFERENCE] batch_id=498 rows=0
# [INFERENCE] batch_id=498 vacío
# [INFERENCE] batch_id=499 rows=0
# [INFERENCE] batch_id=499 vacío
# [INFERENCE] batch_id=500 rows=0
# [INFERENCE] batch_id=500 vacío
# [INFERENCE] batch_id=501 rows=0
# [INFERENCE] batch_id=501 vacío
# [INFERENCE] batch_id=502 rows=0
# [INFERENCE] batch_id=502 vacío
# [INFERENCE] batch_id=503 rows=0
# [INFERENCE] batch_id=503 vacío
# [INFERENCE] batch_id=504 rows=0
# [INFERENCE] batch_id=504 vacío
# [INFERENCE] batch_id=505 rows=0
# [INFERENCE] batch_id=505 vacío
# [INFERENCE] batch_id=506 rows=2
# [INFERENCE] batch_id=506 sin alertas
# [INFERENCE] batch_id=507 rows=0
# [INFERENCE] batch_id=507 vacío
# [INFERENCE] batch_id=508 rows=0
# [INFERENCE] batch_id=508 vacío
# [INFERENCE] batch_id=509 rows=0
# [INFERENCE] batch_id=509 vacío
# [INFERENCE] batch_id=510 rows=0
# [INFERENCE] batch_id=510 vacío
# [INFERENCE] batch_id=511 rows=0
# [INFERENCE] batch_id=511 vacío
# [INFERENCE] batch_id=512 rows=0
# [INFERENCE] batch_id=512 vacío
# [INFERENCE] batch_id=513 rows=0
# [INFERENCE] batch_id=513 vacío
# [INFERENCE] batch_id=514 rows=0
# [INFERENCE] batch_id=514 vacío
# [INFERENCE] batch_id=515 rows=0
# [INFERENCE] batch_id=515 vacío
# [INFERENCE] batch_id=516 rows=0
# [INFERENCE] batch_id=516 vacío
# [INFERENCE] batch_id=517 rows=0
# [INFERENCE] batch_id=517 vacío
# [INFERENCE] batch_id=518 rows=0
# [INFERENCE] batch_id=518 vacío
# [INFERENCE] batch_id=519 rows=0
# [INFERENCE] batch_id=519 vacío
# [INFERENCE] batch_id=520 rows=0
# [INFERENCE] batch_id=520 vacío
# [INFERENCE] batch_id=521 rows=0
# [INFERENCE] batch_id=521 vacío
# [INFERENCE] batch_id=522 rows=0
# [INFERENCE] batch_id=522 vacío
# [INFERENCE] batch_id=523 rows=0
# [INFERENCE] batch_id=523 vacío
# [INFERENCE] batch_id=524 rows=0
# [INFERENCE] batch_id=524 vacío
# [INFERENCE] batch_id=525 rows=0
# [INFERENCE] batch_id=525 vacío
# [INFERENCE] batch_id=526 rows=0
# [INFERENCE] batch_id=526 vacío
# [INFERENCE] batch_id=527 rows=0
# [INFERENCE] batch_id=527 vacío
# [INFERENCE] batch_id=528 rows=0
# [INFERENCE] batch_id=528 vacío
# [INFERENCE] batch_id=529 rows=1
# [INFERENCE] batch_id=529 sin alertas
# [INFERENCE] batch_id=530 rows=0
# [INFERENCE] batch_id=530 vacío
# [INFERENCE] batch_id=531 rows=0
# [INFERENCE] batch_id=531 vacío
# [INFERENCE] batch_id=532 rows=0
# [INFERENCE] batch_id=532 vacío
# [INFERENCE] batch_id=533 rows=0
# [INFERENCE] batch_id=533 vacío
# [INFERENCE] batch_id=534 rows=0
# [INFERENCE] batch_id=534 vacío
# [INFERENCE] batch_id=535 rows=0
# [INFERENCE] batch_id=535 vacío
# [INFERENCE] batch_id=536 rows=0
# [INFERENCE] batch_id=536 vacío
# [INFERENCE] batch_id=537 rows=0
# [INFERENCE] batch_id=537 vacío
# [INFERENCE] batch_id=538 rows=0
# [INFERENCE] batch_id=538 vacío
# [INFERENCE] batch_id=539 rows=0
# [INFERENCE] batch_id=539 vacío
# [INFERENCE] batch_id=540 rows=0
# [INFERENCE] batch_id=540 vacío
# [INFERENCE] batch_id=541 rows=0
# [INFERENCE] batch_id=541 vacío
# [INFERENCE] batch_id=542 rows=0
# [INFERENCE] batch_id=542 vacío
# [INFERENCE] batch_id=543 rows=0
# [INFERENCE] batch_id=543 vacío
# [INFERENCE] batch_id=544 rows=0
# [INFERENCE] batch_id=544 vacío
# [INFERENCE] batch_id=545 rows=0
# [INFERENCE] batch_id=545 vacío
# [INFERENCE] batch_id=546 rows=0
# [INFERENCE] batch_id=546 vacío
# [INFERENCE] batch_id=547 rows=0
# [INFERENCE] batch_id=547 vacío
# [INFERENCE] batch_id=548 rows=0
# [INFERENCE] batch_id=548 vacío
# [INFERENCE] batch_id=549 rows=0
# [INFERENCE] batch_id=549 vacío
# [INFERENCE] batch_id=550 rows=0
# [INFERENCE] batch_id=550 vacío
# [INFERENCE] batch_id=551 rows=1
# [INFERENCE] batch_id=551 sin alertas
# [INFERENCE] batch_id=552 rows=0
# [INFERENCE] batch_id=552 vacío
# [INFERENCE] batch_id=553 rows=0
# [INFERENCE] batch_id=553 vacío
# [INFERENCE] batch_id=554 rows=0
# [INFERENCE] batch_id=554 vacío
# [INFERENCE] batch_id=555 rows=0
# [INFERENCE] batch_id=555 vacío
# [INFERENCE] batch_id=556 rows=0
# [INFERENCE] batch_id=556 vacío
# [INFERENCE] batch_id=557 rows=0
# [INFERENCE] batch_id=557 vacío
# [INFERENCE] batch_id=558 rows=0
# [INFERENCE] batch_id=558 vacío
# [INFERENCE] batch_id=559 rows=0
# [INFERENCE] batch_id=559 vacío
# [INFERENCE] batch_id=560 rows=0
# [INFERENCE] batch_id=560 vacío
# [INFERENCE] batch_id=561 rows=0
# [INFERENCE] batch_id=561 vacío
# [INFERENCE] batch_id=562 rows=0
# [INFERENCE] batch_id=562 vacío
# [INFERENCE] batch_id=563 rows=0
# [INFERENCE] batch_id=563 vacío
# [INFERENCE] batch_id=564 rows=0
# [INFERENCE] batch_id=564 vacío
# [INFERENCE] batch_id=565 rows=0
# [INFERENCE] batch_id=565 vacío
# [INFERENCE] batch_id=566 rows=0
# [INFERENCE] batch_id=566 vacío
# [INFERENCE] batch_id=567 rows=0
# [INFERENCE] batch_id=567 vacío
# [INFERENCE] batch_id=568 rows=0
# [INFERENCE] batch_id=568 vacío
# [INFERENCE] batch_id=569 rows=0
# [INFERENCE] batch_id=569 vacío
# [INFERENCE] batch_id=570 rows=0
# [INFERENCE] batch_id=570 vacío
# [INFERENCE] batch_id=571 rows=0
# [INFERENCE] batch_id=571 vacío
# [INFERENCE] batch_id=572 rows=0
# [INFERENCE] batch_id=572 vacío
# [INFERENCE] batch_id=573 rows=0
# [INFERENCE] batch_id=573 vacío
# [INFERENCE] batch_id=574 rows=1
# [INFERENCE] batch_id=574 sin alertas
# [INFERENCE] batch_id=575 rows=0
# [INFERENCE] batch_id=575 vacío
# [INFERENCE] batch_id=576 rows=0
# [INFERENCE] batch_id=576 vacío
# [INFERENCE] batch_id=577 rows=0
# [INFERENCE] batch_id=577 vacío
# [INFERENCE] batch_id=578 rows=0
# [INFERENCE] batch_id=578 vacío
# [INFERENCE] batch_id=579 rows=0
# [INFERENCE] batch_id=579 vacío
# [INFERENCE] batch_id=580 rows=0
# [INFERENCE] batch_id=580 vacío
# [INFERENCE] batch_id=581 rows=0
# [INFERENCE] batch_id=581 vacío
# [INFERENCE] batch_id=582 rows=0
# [INFERENCE] batch_id=582 vacío
# [INFERENCE] batch_id=583 rows=0
# [INFERENCE] batch_id=583 vacío
# [INFERENCE] batch_id=584 rows=0
# [INFERENCE] batch_id=584 vacío
# [INFERENCE] batch_id=585 rows=0
# [INFERENCE] batch_id=585 vacío
# [INFERENCE] batch_id=586 rows=0
# [INFERENCE] batch_id=586 vacío
# [INFERENCE] batch_id=587 rows=0
# [INFERENCE] batch_id=587 vacío
# [INFERENCE] batch_id=588 rows=0
# [INFERENCE] batch_id=588 vacío
# [INFERENCE] batch_id=589 rows=0
# [INFERENCE] batch_id=589 vacío
# [INFERENCE] batch_id=590 rows=0
# [INFERENCE] batch_id=590 vacío
# [INFERENCE] batch_id=591 rows=0
# [INFERENCE] batch_id=591 vacío
# [INFERENCE] batch_id=592 rows=0
# [INFERENCE] batch_id=592 vacío
# [INFERENCE] batch_id=593 rows=0
# [INFERENCE] batch_id=593 vacío
# [INFERENCE] batch_id=594 rows=0
# [INFERENCE] batch_id=594 vacío
# [INFERENCE] batch_id=595 rows=0
# [INFERENCE] batch_id=595 vacío
# [INFERENCE] batch_id=596 rows=0
# [INFERENCE] batch_id=596 vacío
# [INFERENCE] batch_id=597 rows=0
# [INFERENCE] batch_id=597 vacío
# [INFERENCE] batch_id=598 rows=1
# [INFERENCE] batch_id=598 sin alertas
# [INFERENCE] batch_id=599 rows=0
# [INFERENCE] batch_id=599 vacío
# [INFERENCE] batch_id=600 rows=0
# [INFERENCE] batch_id=600 vacío
# [INFERENCE] batch_id=601 rows=0
# [INFERENCE] batch_id=601 vacío
# [INFERENCE] batch_id=602 rows=0
# [INFERENCE] batch_id=602 vacío
# [INFERENCE] batch_id=603 rows=0
# [INFERENCE] batch_id=603 vacío
# [INFERENCE] batch_id=604 rows=0
# [INFERENCE] batch_id=604 vacío
# [INFERENCE] batch_id=605 rows=0
# [INFERENCE] batch_id=605 vacío
# [INFERENCE] batch_id=606 rows=0
# [INFERENCE] batch_id=606 vacío
# [INFERENCE] batch_id=607 rows=0
# [INFERENCE] batch_id=607 vacío
# [INFERENCE] batch_id=608 rows=0
# [INFERENCE] batch_id=608 vacío
# [INFERENCE] batch_id=609 rows=0
# [INFERENCE] batch_id=609 vacío
# [INFERENCE] batch_id=610 rows=0
# [INFERENCE] batch_id=610 vacío
# [INFERENCE] batch_id=611 rows=0
# [INFERENCE] batch_id=611 vacío
# [INFERENCE] batch_id=612 rows=0
# [INFERENCE] batch_id=612 vacío
# [INFERENCE] batch_id=613 rows=0
# [INFERENCE] batch_id=613 vacío
# [INFERENCE] batch_id=614 rows=0
# [INFERENCE] batch_id=614 vacío
# [INFERENCE] batch_id=615 rows=0
# [INFERENCE] batch_id=615 vacío
# [INFERENCE] batch_id=616 rows=0
# [INFERENCE] batch_id=616 vacío
# [INFERENCE] batch_id=617 rows=0
# [INFERENCE] batch_id=617 vacío
# [INFERENCE] batch_id=618 rows=0
# [INFERENCE] batch_id=618 vacío
# [INFERENCE] batch_id=619 rows=0
# [INFERENCE] batch_id=619 vacío
# [INFERENCE] batch_id=620 rows=0
# [INFERENCE] batch_id=620 vacío
# [INFERENCE] batch_id=621 rows=2
# [INFERENCE] batch_id=621 sin alertas
# [INFERENCE] batch_id=622 rows=0
# [INFERENCE] batch_id=622 vacío
# [INFERENCE] batch_id=623 rows=0
# [INFERENCE] batch_id=623 vacío
# [INFERENCE] batch_id=624 rows=0
# [INFERENCE] batch_id=624 vacío
# [INFERENCE] batch_id=625 rows=0
# [INFERENCE] batch_id=625 vacío
# [INFERENCE] batch_id=626 rows=0
# [INFERENCE] batch_id=626 vacío
# [INFERENCE] batch_id=627 rows=0
# [INFERENCE] batch_id=627 vacío
# [INFERENCE] batch_id=628 rows=0
# [INFERENCE] batch_id=628 vacío
# [INFERENCE] batch_id=629 rows=0
# [INFERENCE] batch_id=629 vacío
# [INFERENCE] batch_id=630 rows=0
# [INFERENCE] batch_id=630 vacío
# [INFERENCE] batch_id=631 rows=0
# [INFERENCE] batch_id=631 vacío
# [INFERENCE] batch_id=632 rows=0
# [INFERENCE] batch_id=632 vacío
# [INFERENCE] batch_id=633 rows=0
# [INFERENCE] batch_id=633 vacío
# [INFERENCE] batch_id=634 rows=0
# [INFERENCE] batch_id=634 vacío
# [INFERENCE] batch_id=635 rows=0
# [INFERENCE] batch_id=635 vacío
# [INFERENCE] batch_id=636 rows=0
# [INFERENCE] batch_id=636 vacío
# [INFERENCE] batch_id=637 rows=0
# [INFERENCE] batch_id=637 vacío
# [INFERENCE] batch_id=638 rows=0
# [INFERENCE] batch_id=638 vacío
# [INFERENCE] batch_id=639 rows=0
# [INFERENCE] batch_id=639 vacío
# [INFERENCE] batch_id=640 rows=0
# [INFERENCE] batch_id=640 vacío
# [INFERENCE] batch_id=641 rows=0
# [INFERENCE] batch_id=641 vacío
# [INFERENCE] batch_id=642 rows=0
# [INFERENCE] batch_id=642 vacío
# [INFERENCE] batch_id=643 rows=0
# [INFERENCE] batch_id=643 vacío
# [INFERENCE] batch_id=644 rows=0
# [INFERENCE] batch_id=644 vacío
# [INFERENCE] batch_id=645 rows=0
# [INFERENCE] batch_id=645 vacío
# [INFERENCE] batch_id=646 rows=0
# [INFERENCE] batch_id=646 vacío
# [INFERENCE] batch_id=647 rows=1
# [INFERENCE] batch_id=647 sin alertas
# [INFERENCE] batch_id=648 rows=0
# [INFERENCE] batch_id=648 vacío
# [INFERENCE] batch_id=649 rows=0
# [INFERENCE] batch_id=649 vacío
# [INFERENCE] batch_id=650 rows=0
# [INFERENCE] batch_id=650 vacío
# [INFERENCE] batch_id=651 rows=0
# [INFERENCE] batch_id=651 vacío
# [INFERENCE] batch_id=652 rows=0
# [INFERENCE] batch_id=652 vacío
# [INFERENCE] batch_id=653 rows=0
# [INFERENCE] batch_id=653 vacío
# [INFERENCE] batch_id=654 rows=0
# [INFERENCE] batch_id=654 vacío
# [INFERENCE] batch_id=655 rows=0
# [INFERENCE] batch_id=655 vacío
# [INFERENCE] batch_id=656 rows=0
# [INFERENCE] batch_id=656 vacío
# [INFERENCE] batch_id=657 rows=0
# [INFERENCE] batch_id=657 vacío
# [INFERENCE] batch_id=658 rows=0
# [INFERENCE] batch_id=658 vacío
# [INFERENCE] batch_id=659 rows=0
# [INFERENCE] batch_id=659 vacío
# [INFERENCE] batch_id=660 rows=0
# [INFERENCE] batch_id=660 vacío
# [INFERENCE] batch_id=661 rows=0
# [INFERENCE] batch_id=661 vacío
# [INFERENCE] batch_id=662 rows=0
# [INFERENCE] batch_id=662 vacío
# [INFERENCE] batch_id=663 rows=0
# [INFERENCE] batch_id=663 vacío
# [INFERENCE] batch_id=664 rows=0
# [INFERENCE] batch_id=664 vacío
# [INFERENCE] batch_id=665 rows=0
# [INFERENCE] batch_id=665 vacío
# [INFERENCE] batch_id=666 rows=0
# [INFERENCE] batch_id=666 vacío
# [INFERENCE] batch_id=667 rows=0
# [INFERENCE] batch_id=667 vacío
# [INFERENCE] batch_id=668 rows=0
# [INFERENCE] batch_id=668 vacío
# [INFERENCE] batch_id=669 rows=0
# [INFERENCE] batch_id=669 vacío
# [INFERENCE] batch_id=670 rows=0
# [INFERENCE] batch_id=670 vacío
# [INFERENCE] batch_id=671 rows=0
# [INFERENCE] batch_id=671 vacío
# [INFERENCE] batch_id=672 rows=1
# [INFERENCE] batch_id=672 sin alertas
# [INFERENCE] batch_id=673 rows=0
# [INFERENCE] batch_id=673 vacío
# [INFERENCE] batch_id=674 rows=0
# [INFERENCE] batch_id=674 vacío
# [INFERENCE] batch_id=675 rows=0
# [INFERENCE] batch_id=675 vacío
# [INFERENCE] batch_id=676 rows=0
# [INFERENCE] batch_id=676 vacío
# [INFERENCE] batch_id=677 rows=0
# [INFERENCE] batch_id=677 vacío
# [INFERENCE] batch_id=678 rows=0
# [INFERENCE] batch_id=678 vacío
# [INFERENCE] batch_id=679 rows=0
# [INFERENCE] batch_id=679 vacío
# [INFERENCE] batch_id=680 rows=0
# [INFERENCE] batch_id=680 vacío
# [INFERENCE] batch_id=681 rows=0
# [INFERENCE] batch_id=681 vacío
# [INFERENCE] batch_id=682 rows=0
# [INFERENCE] batch_id=682 vacío
# [INFERENCE] batch_id=683 rows=0
# [INFERENCE] batch_id=683 vacío
# [INFERENCE] batch_id=684 rows=0
# [INFERENCE] batch_id=684 vacío
# [INFERENCE] batch_id=685 rows=0
# [INFERENCE] batch_id=685 vacío
# [INFERENCE] batch_id=686 rows=0
# [INFERENCE] batch_id=686 vacío
# [INFERENCE] batch_id=687 rows=0
# [INFERENCE] batch_id=687 vacío
# [INFERENCE] batch_id=688 rows=0
# [INFERENCE] batch_id=688 vacío
# [INFERENCE] batch_id=689 rows=0
# [INFERENCE] batch_id=689 vacío
# [INFERENCE] batch_id=690 rows=0
# [INFERENCE] batch_id=690 vacío
# [INFERENCE] batch_id=691 rows=0
# [INFERENCE] batch_id=691 vacío
# [INFERENCE] batch_id=692 rows=0
# [INFERENCE] batch_id=692 vacío
# [INFERENCE] batch_id=693 rows=1
# [INFERENCE] batch_id=693 sin alertas
# [INFERENCE] batch_id=694 rows=0
# [INFERENCE] batch_id=694 vacío
# [INFERENCE] batch_id=695 rows=0
# [INFERENCE] batch_id=695 vacío
# [INFERENCE] batch_id=696 rows=0
# [INFERENCE] batch_id=696 vacío
# [INFERENCE] batch_id=697 rows=0
# [INFERENCE] batch_id=697 vacío
# [INFERENCE] batch_id=698 rows=0
# [INFERENCE] batch_id=698 vacío
# [INFERENCE] batch_id=699 rows=0
# [INFERENCE] batch_id=699 vacío
# [INFERENCE] batch_id=700 rows=0
# [INFERENCE] batch_id=700 vacío
# [INFERENCE] batch_id=701 rows=0
# [INFERENCE] batch_id=701 vacío
# [INFERENCE] batch_id=702 rows=0
# [INFERENCE] batch_id=702 vacío
# [INFERENCE] batch_id=703 rows=0
# [INFERENCE] batch_id=703 vacío
# [INFERENCE] batch_id=704 rows=0
# [INFERENCE] batch_id=704 vacío
# [INFERENCE] batch_id=705 rows=0
# [INFERENCE] batch_id=705 vacío
# [INFERENCE] batch_id=706 rows=0
# [INFERENCE] batch_id=706 vacío
# [INFERENCE] batch_id=707 rows=0
# [INFERENCE] batch_id=707 vacío
# [INFERENCE] batch_id=708 rows=0
# [INFERENCE] batch_id=708 vacío
# [INFERENCE] batch_id=709 rows=0
# [INFERENCE] batch_id=709 vacío
# [INFERENCE] batch_id=710 rows=0
# [INFERENCE] batch_id=710 vacío
# [INFERENCE] batch_id=711 rows=0
# [INFERENCE] batch_id=711 vacío
# [INFERENCE] batch_id=712 rows=0
# [INFERENCE] batch_id=712 vacío
# [INFERENCE] batch_id=713 rows=0
# [INFERENCE] batch_id=713 vacío
# [INFERENCE] batch_id=714 rows=0
# [INFERENCE] batch_id=714 vacío
# [INFERENCE] batch_id=715 rows=0
# [INFERENCE] batch_id=715 vacío
# [INFERENCE] batch_id=716 rows=1
# [INFERENCE] batch_id=716 sin alertas
# [INFERENCE] batch_id=717 rows=0
# [INFERENCE] batch_id=717 vacío
# [INFERENCE] batch_id=718 rows=0
# [INFERENCE] batch_id=718 vacío
# [INFERENCE] batch_id=719 rows=0
# [INFERENCE] batch_id=719 vacío
# [INFERENCE] batch_id=720 rows=0
# [INFERENCE] batch_id=720 vacío
# [INFERENCE] batch_id=721 rows=0
# [INFERENCE] batch_id=721 vacío
# [INFERENCE] batch_id=722 rows=0
# [INFERENCE] batch_id=722 vacío
# [INFERENCE] batch_id=723 rows=0
# [INFERENCE] batch_id=723 vacío
# [INFERENCE] batch_id=724 rows=0
# [INFERENCE] batch_id=724 vacío
# [INFERENCE] batch_id=725 rows=0
# [INFERENCE] batch_id=725 vacío
# [INFERENCE] batch_id=726 rows=0
# [INFERENCE] batch_id=726 vacío
# [INFERENCE] batch_id=727 rows=0
# [INFERENCE] batch_id=727 vacío
# [INFERENCE] batch_id=728 rows=0
# [INFERENCE] batch_id=728 vacío
# [INFERENCE] batch_id=729 rows=0
# [INFERENCE] batch_id=729 vacío
# [INFERENCE] batch_id=730 rows=0
# [INFERENCE] batch_id=730 vacío
# [INFERENCE] batch_id=731 rows=0
# [INFERENCE] batch_id=731 vacío
# [INFERENCE] batch_id=732 rows=0
# [INFERENCE] batch_id=732 vacío
# [INFERENCE] batch_id=733 rows=0
# [INFERENCE] batch_id=733 vacío
# [INFERENCE] batch_id=734 rows=0
# [INFERENCE] batch_id=734 vacío
# [INFERENCE] batch_id=735 rows=0
# [INFERENCE] batch_id=735 vacío
# [INFERENCE] batch_id=736 rows=0
# [INFERENCE] batch_id=736 vacío
# [INFERENCE] batch_id=737 rows=0
# [INFERENCE] batch_id=737 vacío
# [INFERENCE] batch_id=738 rows=0
# [INFERENCE] batch_id=738 vacío
# [INFERENCE] batch_id=739 rows=0
# [INFERENCE] batch_id=739 vacío
# [INFERENCE] batch_id=740 rows=0
# [INFERENCE] batch_id=740 vacío
# [INFERENCE] batch_id=741 rows=2
# [INFERENCE] batch_id=741 sin alertas
# [INFERENCE] batch_id=742 rows=0
# [INFERENCE] batch_id=742 vacío
# [INFERENCE] batch_id=743 rows=0
# [INFERENCE] batch_id=743 vacío
# [INFERENCE] batch_id=744 rows=0
# [INFERENCE] batch_id=744 vacío
# [INFERENCE] batch_id=745 rows=0
# [INFERENCE] batch_id=745 vacío
# [INFERENCE] batch_id=746 rows=0
# [INFERENCE] batch_id=746 vacío
# [INFERENCE] batch_id=747 rows=0
# [INFERENCE] batch_id=747 vacío
# [INFERENCE] batch_id=748 rows=0
# [INFERENCE] batch_id=748 vacío
# [INFERENCE] batch_id=749 rows=0
# [INFERENCE] batch_id=749 vacío
# [INFERENCE] batch_id=750 rows=0
# [INFERENCE] batch_id=750 vacío
# [INFERENCE] batch_id=751 rows=0
# [INFERENCE] batch_id=751 vacío
# [INFERENCE] batch_id=752 rows=0
# [INFERENCE] batch_id=752 vacío
# [INFERENCE] batch_id=753 rows=0
# [INFERENCE] batch_id=753 vacío
# [INFERENCE] batch_id=754 rows=0
# [INFERENCE] batch_id=754 vacío
# [INFERENCE] batch_id=755 rows=0
# [INFERENCE] batch_id=755 vacío
# [INFERENCE] batch_id=756 rows=0
# [INFERENCE] batch_id=756 vacío
# [INFERENCE] batch_id=757 rows=0
# [INFERENCE] batch_id=757 vacío
# [INFERENCE] batch_id=758 rows=0
# [INFERENCE] batch_id=758 vacío
# [INFERENCE] batch_id=759 rows=0
# [INFERENCE] batch_id=759 vacío
# [INFERENCE] batch_id=760 rows=0
# [INFERENCE] batch_id=760 vacío
# [INFERENCE] batch_id=761 rows=1
# [INFERENCE] batch_id=761 sin alertas
# [INFERENCE] batch_id=762 rows=0
# [INFERENCE] batch_id=762 vacío
# [INFERENCE] batch_id=763 rows=0
# [INFERENCE] batch_id=763 vacío
# [INFERENCE] batch_id=764 rows=0
# [INFERENCE] batch_id=764 vacío
# [INFERENCE] batch_id=765 rows=0
# [INFERENCE] batch_id=765 vacío
# [INFERENCE] batch_id=766 rows=0
# [INFERENCE] batch_id=766 vacío
# [INFERENCE] batch_id=767 rows=0
# [INFERENCE] batch_id=767 vacío
# [INFERENCE] batch_id=768 rows=0
# [INFERENCE] batch_id=768 vacío
# [INFERENCE] batch_id=769 rows=0
# [INFERENCE] batch_id=769 vacío
# [INFERENCE] batch_id=770 rows=0
# [INFERENCE] batch_id=770 vacío
# [INFERENCE] batch_id=771 rows=0
# [INFERENCE] batch_id=771 vacío
# [INFERENCE] batch_id=772 rows=0
# [INFERENCE] batch_id=772 vacío
# [INFERENCE] batch_id=773 rows=0
# [INFERENCE] batch_id=773 vacío
# [INFERENCE] batch_id=774 rows=0
# [INFERENCE] batch_id=774 vacío
# [INFERENCE] batch_id=775 rows=0
# [INFERENCE] batch_id=775 vacío
# [INFERENCE] batch_id=776 rows=0
# [INFERENCE] batch_id=776 vacío
# [INFERENCE] batch_id=777 rows=0
# [INFERENCE] batch_id=777 vacío
# [INFERENCE] batch_id=778 rows=0
# [INFERENCE] batch_id=778 vacío
# [INFERENCE] batch_id=779 rows=0
# [INFERENCE] batch_id=779 vacío
# [INFERENCE] batch_id=780 rows=0
# [INFERENCE] batch_id=780 vacío
# [INFERENCE] batch_id=781 rows=0
# [INFERENCE] batch_id=781 vacío
# [INFERENCE] batch_id=782 rows=0
# [INFERENCE] batch_id=782 vacío
# [INFERENCE] batch_id=783 rows=0
# [INFERENCE] batch_id=783 vacío
# [INFERENCE] batch_id=784 rows=0
# [INFERENCE] batch_id=784 vacío
# [INFERENCE] batch_id=785 rows=0
# [INFERENCE] batch_id=785 vacío
# [INFERENCE] batch_id=786 rows=1
# [INFERENCE] batch_id=786 sin alertas
# [INFERENCE] batch_id=787 rows=0
# [INFERENCE] batch_id=787 vacío
# [INFERENCE] batch_id=788 rows=0
# [INFERENCE] batch_id=788 vacío
# [INFERENCE] batch_id=789 rows=0
# [INFERENCE] batch_id=789 vacío
# [INFERENCE] batch_id=790 rows=0
# [INFERENCE] batch_id=790 vacío
# [INFERENCE] batch_id=791 rows=0
# [INFERENCE] batch_id=791 vacío
# [INFERENCE] batch_id=792 rows=0
# [INFERENCE] batch_id=792 vacío
# [INFERENCE] batch_id=793 rows=0
# [INFERENCE] batch_id=793 vacío
# [INFERENCE] batch_id=794 rows=0
# [INFERENCE] batch_id=794 vacío
# [INFERENCE] batch_id=795 rows=0
# [INFERENCE] batch_id=795 vacío
# [INFERENCE] batch_id=796 rows=0
# [INFERENCE] batch_id=796 vacío
# [INFERENCE] batch_id=797 rows=0
# [INFERENCE] batch_id=797 vacío
# [INFERENCE] batch_id=798 rows=0
# [INFERENCE] batch_id=798 vacío
# [INFERENCE] batch_id=799 rows=0
# [INFERENCE] batch_id=799 vacío
# [INFERENCE] batch_id=800 rows=0
# [INFERENCE] batch_id=800 vacío
# [INFERENCE] batch_id=801 rows=0
# [INFERENCE] batch_id=801 vacío
# [INFERENCE] batch_id=802 rows=0
# [INFERENCE] batch_id=802 vacío
# [INFERENCE] batch_id=803 rows=0
# [INFERENCE] batch_id=803 vacío
# [INFERENCE] batch_id=804 rows=0
# [INFERENCE] batch_id=804 vacío
# [INFERENCE] batch_id=805 rows=0
# [INFERENCE] batch_id=805 vacío
# [INFERENCE] batch_id=806 rows=0
# [INFERENCE] batch_id=806 vacío
# [INFERENCE] batch_id=807 rows=0
# [INFERENCE] batch_id=807 vacío
# [INFERENCE] batch_id=808 rows=0
# [INFERENCE] batch_id=808 vacío
# [INFERENCE] batch_id=809 rows=0
# [INFERENCE] batch_id=809 vacío
# [INFERENCE] batch_id=810 rows=1
# [INFERENCE] batch_id=810 sin alertas
# [INFERENCE] batch_id=811 rows=0
# [INFERENCE] batch_id=811 vacío
# [INFERENCE] batch_id=812 rows=0
# [INFERENCE] batch_id=812 vacío
# [INFERENCE] batch_id=813 rows=0
# [INFERENCE] batch_id=813 vacío
# [INFERENCE] batch_id=814 rows=0
# [INFERENCE] batch_id=814 vacío
# [INFERENCE] batch_id=815 rows=0
# [INFERENCE] batch_id=815 vacío
# [INFERENCE] batch_id=816 rows=0
# [INFERENCE] batch_id=816 vacío
# [INFERENCE] batch_id=817 rows=0
# [INFERENCE] batch_id=817 vacío
# [INFERENCE] batch_id=818 rows=0
# [INFERENCE] batch_id=818 vacío
# [INFERENCE] batch_id=819 rows=0
# [INFERENCE] batch_id=819 vacío
# [INFERENCE] batch_id=820 rows=0
# [INFERENCE] batch_id=820 vacío
# [INFERENCE] batch_id=821 rows=0
# [INFERENCE] batch_id=821 vacío
# [INFERENCE] batch_id=822 rows=0
# [INFERENCE] batch_id=822 vacío
# [INFERENCE] batch_id=823 rows=0
# [INFERENCE] batch_id=823 vacío
# [INFERENCE] batch_id=824 rows=0
# [INFERENCE] batch_id=824 vacío
# [INFERENCE] batch_id=825 rows=0
# [INFERENCE] batch_id=825 vacío
# [INFERENCE] batch_id=826 rows=0
# [INFERENCE] batch_id=826 vacío
# [INFERENCE] batch_id=827 rows=0
# [INFERENCE] batch_id=827 vacío
# [INFERENCE] batch_id=828 rows=0
# [INFERENCE] batch_id=828 vacío
# [INFERENCE] batch_id=829 rows=0
# [INFERENCE] batch_id=829 vacío
# [INFERENCE] batch_id=830 rows=0
# [INFERENCE] batch_id=830 vacío
# [INFERENCE] batch_id=831 rows=0
# [INFERENCE] batch_id=831 vacío
# [INFERENCE] batch_id=832 rows=0
# [INFERENCE] batch_id=832 vacío
# [INFERENCE] batch_id=833 rows=1
# [INFERENCE] batch_id=833 sin alertas
# [INFERENCE] batch_id=834 rows=0
# [INFERENCE] batch_id=834 vacío
# [INFERENCE] batch_id=835 rows=0
# [INFERENCE] batch_id=835 vacío
# [INFERENCE] batch_id=836 rows=0
# [INFERENCE] batch_id=836 vacío
# [INFERENCE] batch_id=837 rows=0
# [INFERENCE] batch_id=837 vacío
# [INFERENCE] batch_id=838 rows=0
# [INFERENCE] batch_id=838 vacío
# [INFERENCE] batch_id=839 rows=0
# [INFERENCE] batch_id=839 vacío
# [INFERENCE] batch_id=840 rows=0
# [INFERENCE] batch_id=840 vacío
# [INFERENCE] batch_id=841 rows=0
# [INFERENCE] batch_id=841 vacío
# [INFERENCE] batch_id=842 rows=0
# [INFERENCE] batch_id=842 vacío
# [INFERENCE] batch_id=843 rows=0
# [INFERENCE] batch_id=843 vacío
# [INFERENCE] batch_id=844 rows=0
# [INFERENCE] batch_id=844 vacío
# [INFERENCE] batch_id=845 rows=0
# [INFERENCE] batch_id=845 vacío
# [INFERENCE] batch_id=846 rows=0
# [INFERENCE] batch_id=846 vacío
# [INFERENCE] batch_id=847 rows=0
# [INFERENCE] batch_id=847 vacío
# [INFERENCE] batch_id=848 rows=0
# [INFERENCE] batch_id=848 vacío
# [INFERENCE] batch_id=849 rows=0
# [INFERENCE] batch_id=849 vacío
# [INFERENCE] batch_id=850 rows=0
# [INFERENCE] batch_id=850 vacío
# [INFERENCE] batch_id=851 rows=0
# [INFERENCE] batch_id=851 vacío
# [INFERENCE] batch_id=852 rows=0
# [INFERENCE] batch_id=852 vacío
# [INFERENCE] batch_id=853 rows=0
# [INFERENCE] batch_id=853 vacío
# [INFERENCE] batch_id=854 rows=0
# [INFERENCE] batch_id=854 vacío
# [INFERENCE] batch_id=855 rows=0
# [INFERENCE] batch_id=855 vacío
# [INFERENCE] batch_id=856 rows=0
# [INFERENCE] batch_id=856 vacío
# [INFERENCE] batch_id=857 rows=0
# [INFERENCE] batch_id=857 vacío
# [INFERENCE] batch_id=858 rows=0
# [INFERENCE] batch_id=858 vacío
# [INFERENCE] batch_id=859 rows=1
# [INFERENCE] batch_id=859 sin alertas
# [INFERENCE] batch_id=860 rows=0
# [INFERENCE] batch_id=860 vacío
# [INFERENCE] batch_id=861 rows=0
# [INFERENCE] batch_id=861 vacío
# [INFERENCE] batch_id=862 rows=0
# [INFERENCE] batch_id=862 vacío
# [INFERENCE] batch_id=863 rows=0
# [INFERENCE] batch_id=863 vacío
# [INFERENCE] batch_id=864 rows=0
# [INFERENCE] batch_id=864 vacío
# [INFERENCE] batch_id=865 rows=0
# [INFERENCE] batch_id=865 vacío
# [INFERENCE] batch_id=866 rows=0
# [INFERENCE] batch_id=866 vacío
# [INFERENCE] batch_id=867 rows=0
# [INFERENCE] batch_id=867 vacío
# [INFERENCE] batch_id=868 rows=0
# [INFERENCE] batch_id=868 vacío
# [INFERENCE] batch_id=869 rows=0
# [INFERENCE] batch_id=869 vacío
# [INFERENCE] batch_id=870 rows=0
# [INFERENCE] batch_id=870 vacío
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# from pyspark.sql.types import *

# alerts_schema = StructType([
#     StructField("timestamp_alert", TimestampType(), False),
#     StructField("asset_name", StringType(), False),
#     StructField("symbol", StringType(), False),
#     StructField("best_x", IntegerType(), False),
#     StructField("best_k", IntegerType(), False),
#     StructField("best_n", IntegerType(), False),
#     StructField("best_j", DoubleType(), False),
#     StructField("signal", StringType(), False),
#     StructField("price", DoubleType(), False),
#     StructField("bin_start", TimestampType(), False),
# ])

# alerts_path = "abfss://datos@mastertfm001sta.dfs.core.windows.net/gold/alerts"

# # Crear tabla Delta vacía si no existe
# (
#     spark.createDataFrame([], alerts_schema)
#     .write
#     .format("delta")
#     .mode("overwrite")
#     .save(alerts_path)
# )

# print("✅ Tabla Delta GOLD/alerts inicializada")
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:134)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:190)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:465)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequest$1(Chauffeur.scala:954)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.$anonfun$applyOrElse$3(Chauffeur.scala:980)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:979)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:1034)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$com$databricks$spark$chauffeur$Chauffeur$$nestedInanon$$receiveInternal$1.applyOrElse(Chauffeur.scala:834)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:825)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:189)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:215)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:186)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$5(ServerBackend.scala:175)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:23)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:127)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:108)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:23)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:23)
# 	at com.databricks.rpc.ServerBackend.executeWithLogging$1(ServerBackend.scala:148)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:997)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:917)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:557)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:522)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$12(ActivityContextFactory.scala:1096)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$2(ActivityContextFactory.scala:1096)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1058)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:1039)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$39(ActivityContextFactory.scala:406)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:63)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:406)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:522)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:417)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:80)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:348)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:344)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:78)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:75)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:111)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:46)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:93)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)
