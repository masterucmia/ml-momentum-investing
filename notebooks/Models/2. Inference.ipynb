# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, broadcast
from datetime import timedelta

# %%
spark.conf.set("spark.sql.session.timeZone", "UTC")

# %%
alerts_path = "abfss://datos@mastertfm002sta.dfs.core.windows.net/gold/alerts"

# spark.sql(f"""
#     DELETE FROM delta.`{alerts_path}`
# """)

news_path = "abfss://datos@mastertfm002sta.dfs.core.windows.net/gold/config/news"


NEWS_LOOKBACK_MINUTES = 1440

# %%
##### BLOQUE 1 #####

gold_path = "abfss://datos@mastertfm002sta.dfs.core.windows.net/gold/activos"
estrategias_csv_path = "abfss://datos@mastertfm002sta.dfs.core.windows.net/gold/config/estrategias_optimas.csv"
alerts_path = "abfss://datos@mastertfm002sta.dfs.core.windows.net/gold/alerts"
checkpoint_path = alerts_path + "/_checkpoint_inference"

# %%
##### BLOQUE 2 #####


spark = (
    SparkSession.builder
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

# %%
##### BLOQUE 3 #####

estrategias_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(estrategias_csv_path)
)

# # Opción A, filtrar por pasa_filtro si existe
# if "pasa_filtro" in estrategias_df.columns:
#     estrategias_apto = estrategias_df.filter(col("pasa_filtro") == True)
# else:
#     # Opción B, filtrar por clasificacion
# estrategias_apto = estrategias_df.filter(col("clasificacion").isin(["APTO FUERTE 🚀"]))

estrategias_apto = estrategias_df.filter(col("clasificacion").isin(["APTO FUERTE 🚀"])).select(
    "symbol",
    "tipo_estrategia",   # 👈 NUEVO
    "best_x",
    "best_k",
    "best_n",
    "best_j"
)

display(estrategias_apto)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>symbol</th><th>tipo_estrategia</th><th>best_x</th><th>best_k</th><th>best_n</th><th>best_j</th></tr></thead><tbody><tr><td>SPCE</td><td>Rebote</td><td>47</td><td>2</td><td>19</td><td>0.002</td></tr><tr><td>SOXX</td><td>Inercia</td><td>51</td><td>2</td><td>19</td><td>2.0E-4</td></tr><tr><td>ARKK</td><td>Rebote</td><td>29</td><td>2</td><td>19</td><td>2.0E-4</td></tr><tr><td>PLTR</td><td>Rebote</td><td>37</td><td>3</td><td>16</td><td>4.0E-4</td></tr><tr><td>LCID</td><td>Inercia</td><td>53</td><td>6</td><td>16</td><td>0.0</td></tr><tr><td>COIN</td><td>Rebote</td><td>36</td><td>3</td><td>19</td><td>0.002</td></tr><tr><td>VUG</td><td>Rebote</td><td>44</td><td>2</td><td>14</td><td>4.0E-4</td></tr><tr><td>SPY</td><td>Rebote</td><td>40</td><td>3</td><td>18</td><td>0.0</td></tr><tr><td>QQQ</td><td>Inercia</td><td>35</td><td>2</td><td>12</td><td>0.001</td></tr></tbody></table></div>

# %%
##### BLOQUE 4 #####

gold_replay = (
    spark.read
    .format("delta")
    .load(gold_path)
    .filter(col("timestamp") >= "2026-02-01")
    .filter(col("timestamp") < "2026-02-16")
    .orderBy("timestamp")
)

# gold tiene: timestamp, symbol, asset_class, asset_name, coste_opera_h, close
stream_joined = (
    gold_replay
    .select("timestamp", "symbol", "asset_name", "close")
    .join(
        broadcast(estrategias_apto),
        on="symbol",
        how="inner"
    )
)

stream_joined.select("symbol", "best_x").distinct().show(50, False)
# Out:
# +------+------+
# |symbol|best_x|
# +------+------+
# |SOXX  |51    |
# |VUG   |44    |
# |ARKK  |29    |
# |LCID  |53    |
# |QQQ   |35    |
# |SPY   |40    |
# |SPCE  |47    |
# |PLTR  |37    |
# |COIN  |36    |
# +------+------+

# %%
##### BLOQUE 5 #####

from collections import deque, defaultdict
import pandas as pd
import numpy as np
import uuid

# Buffers y control de spam en DRIVER
BUFFERS = defaultdict(lambda: deque(maxlen=10_000))
LAST_ALERT_BIN = {}

# Convertir estrategias_apto (Spark DF) a dict en driver
# Asumimos pocos activos (decenas)
STRATEGIES = {
    r["symbol"]: {
        "tipo_estrategia": r["tipo_estrategia"],  # 👈 NUEVO
        "best_x": int(r["best_x"]),
        "best_k": int(r["best_k"]),
        "best_n": int(r["best_n"]),
        "best_j": float(r["best_j"])
    }
    for r in estrategias_apto.collect()
}


print(f"✅ Estrategias cargadas: {len(STRATEGIES)} activos")


# ============================
# ESTADO DE POSICIONES EN DRIVER
# ============================

# Una posición por activo
# guardamos: entry_price, entry_time, peak_price (para trailing), last_bin (anti spam ya lo tienes aparte)
POSITIONS = {}

# Si quieres que el trailing sea un porcentaje fijo, define esto:
# TRAIL_PCT_DEFAULT = 0.002  # 0.2%

# Si quieres usar best_j como trailing, lo haremos dentro del bloque 9 usando best_j
# Out:
# ✅ Estrategias cargadas: 9 activos

# %%
##### BLOQUE 6 #####

# ============================
# WARM-UP HISTÓRICO DESDE GOLD
# ============================

from datetime import timedelta
from pyspark.sql.functions import col
from pyspark.sql import functions as F
import pandas as pd

print("🔥 Iniciando warm-up histórico desde GOLD")

# ✅ Corte absoluto: desde aquí NO se usa nada hacia atrás
CUTOFF_TS = pd.Timestamp("2026-02-01 00:00:00")

# 1️⃣ Calcular minutos necesarios (peor estrategia)
estrategias_pdf = estrategias_apto.toPandas()
estrategias_pdf["min_needed"] = (
    (estrategias_pdf["best_k"] + estrategias_pdf["best_n"] + 5)
    * estrategias_pdf["best_x"]
)
max_minutes_needed = int(estrategias_pdf["min_needed"].max())
print(f"⏱️ Ventana teórica necesaria: {max_minutes_needed} minutos (pero SIN usar datos < {CUTOFF_TS})")

# 2️⃣ Timestamp de inicio del replay (primer dato >= cutoff)
replay_start_epoch = (
    spark.read
    .format("delta")
    .load(gold_path)
    .filter(col("timestamp") >= F.lit(str(CUTOFF_TS)))
    .select(F.min(col("timestamp").cast("long")).alias("ts"))
    .collect()[0]["ts"]
)

replay_start_ts = pd.to_datetime(replay_start_epoch, unit="s", utc=True).tz_convert("UTC").tz_localize(None)
print(f"🕒 Inicio del replay: {replay_start_ts}")

# 3️⃣ Leer GOLD histórico SOLO desde cutoff (sin periodo hacia atrás)
symbols_estrategia = estrategias_pdf["symbol"].tolist()

gold_hist = (
    spark.read
    .format("delta")
    .load(gold_path)
    .filter(col("symbol").isin(symbols_estrategia))
    .filter(col("timestamp") >= F.lit(str(CUTOFF_TS)))
    .filter(col("timestamp") <= F.lit(str(replay_start_ts)))
)

# 4️⃣ Pasar a pandas y cargar buffers (puede quedar corto al principio, es intencional)
pdf_hist = (
    gold_hist
    .select("timestamp", "symbol", "close")
    .orderBy("symbol", "timestamp")
    .toPandas()
)

for symbol, g in pdf_hist.groupby("symbol"):
    row = estrategias_pdf[estrategias_pdf["symbol"] == symbol].iloc[0]
    min_raw_needed = int((row["best_k"] + row["best_n"] + 5) * row["best_x"])

    BUFFERS[symbol] = deque(maxlen=min_raw_needed * 2)

    # ✅ Clampeo explícito por seguridad
    g = g[g["timestamp"] >= CUTOFF_TS]

    for _, r in g.iterrows():
        BUFFERS[symbol].append((r["timestamp"], float(r["close"])))

    print(f"✅ Warm-up {symbol}: {len(BUFFERS[symbol])} puntos cargados desde {CUTOFF_TS}")
# Out:
# 🔥 Iniciando warm-up histórico desde GOLD
# ⏱️ Ventana teórica necesaria: 1431 minutos (pero SIN usar datos < 2026-02-01 00:00:00)
# 🕒 Inicio del replay: 2026-02-01 00:00:00
# ✅ Warm-up ARKK: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up COIN: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up LCID: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up PLTR: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up QQQ: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up SOXX: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up SPCE: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up SPY: 1 puntos cargados desde 2026-02-01 00:00:00
# ✅ Warm-up VUG: 1 puntos cargados desde 2026-02-01 00:00:00

# %%
##### BLOQUE 7 #####

from pyspark.sql.types import (
    StructType, StructField,
    TimestampType, StringType,
    IntegerType, DoubleType
)

alert_schema = StructType([
    StructField("trade_id", StringType(), False),
    StructField("tipo_estrategia", StringType(), False),  # 👈 NUEVO
    StructField("timestamp_alert", TimestampType(), False),

    StructField("asset_name", StringType(), False),
    StructField("symbol", StringType(), False),

    StructField("best_x", IntegerType(), False),
    StructField("best_k", IntegerType(), False),
    StructField("best_n", IntegerType(), False),
    StructField("best_j", DoubleType(), False),

    StructField("signal", StringType(), False),
    StructField("price", DoubleType(), False),
    StructField("bin_start", TimestampType(), False),

    StructField("entry_price", DoubleType(), True),
    StructField("exit_reason", StringType(), True),
    StructField("pnl_pct", DoubleType(), True),
    StructField("hold_minutes", IntegerType(), True),

    StructField("news_count", IntegerType(), True),
    StructField("news_main_title", StringType(), True),
    StructField("news_main_link", StringType(), True),
    StructField("news_main_published_utc", TimestampType(), True),
    StructField("news_time_diff_minutes", IntegerType(), True),
    StructField("news_main_sentiment_label", StringType(), True),
    StructField("news_main_sentiment_score", DoubleType(), True),

])

# %%
##### BLOQUE 8 #####

import numpy as np
import pandas as pd

def _last_k_returns(prices: np.ndarray) -> np.ndarray:
    """Retornos simples por barra: prices[t]/prices[t-1]-1"""
    if len(prices) < 2:
        return np.array([], dtype=float)
    prev = prices[:-1]
    nxt = prices[1:]
    # evitar divisiones raras
    prev = np.where(prev <= 1e-12, np.nan, prev)
    r = (nxt / prev) - 1.0
    return r

def compute_entry_signal(prices: np.ndarray, k: int, j: float, tipo_estrategia: str):
    """
    Señal de ENTRADA según tu definición.

    - Inercia:
        BUY  si las últimas k barras tienen retorno >= j
        SELL si las últimas k barras tienen retorno <= -j
    - Rebote (contrario):
        BUY  si las últimas k barras tienen retorno <= -j
        SELL si las últimas k barras tienen retorno >= j

    return: "BUY" | "SELL" | None
    """
    tipo = (tipo_estrategia or "").strip().lower()

    r = _last_k_returns(prices)
    if len(r) < k:
        return None

    last = r[-k:]
    if np.any(np.isnan(last)):
        return None

    if tipo == "inercia":
        if np.all(last > j):
            return "BUY"
        if np.all(last < -j):
            return "SELL"
        return None

    if tipo == "rebote":
        if np.all(last < -j):
            return "BUY"
        if np.all(last > j):
            return "SELL"
        return None

    # si viene algo raro, no operamos
    return None

# %%
##### BLOQUE 9 #####

import traceback
from pyspark.sql.functions import col
from pyspark.sql import Row
import uuid
import pandas as pd
from collections import deque

# ⬇️ imports mínimos necesarios para el join con noticias (no cambia nada más)
from pyspark.sql.functions import expr, row_number, unix_timestamp, abs as sql_abs
from pyspark.sql import Window

GOLD_BUFFERS = {}

# ✅ Estado por activo en DRIVER
# position: "LONG" | "SHORT"
# bars_held: número de barras (x minutos) completadas desde la entrada
POSITIONS = {}

# ✅ Para no procesar ni alertar 2 veces el mismo bin
LAST_PROCESSED_BIN_END = {}
LAST_ALERT_BIN_END = {}

# ✅ Corte absoluto
CUTOFF_TS = pd.Timestamp("2026-02-01 00:00:00")

def _pnl_pct(side: str, entry: float, last: float) -> float:
    if entry <= 0 or last <= 0:
        return 0.0
    if side == "LONG":
        return (last / entry) - 1.0
    if side == "SHORT":
        return (entry / last) - 1.0
    return 0.0

def process_inference_batch(batch_df, batch_id: int):
    try:
        sdf = (
            batch_df
            .select("timestamp_epoch", "symbol", "asset_name", "close")
            .filter(col("symbol").isin(list(STRATEGIES.keys())))
        )

        pdf = sdf.toPandas()
        nrows = len(pdf)
        print(f"[INFERENCE] batch_id={batch_id} rows={nrows}")

        # =========================
        # CARGAR NOTICIAS (STATIC)
        # =========================
        news_df = (
            spark.read
            .format("delta")
            .load(news_path)
            .select(
                "asset",
                "title",
                "link",
                col("published_utc").alias("news_published_utc"),
                col("sentiment").alias("sentiment_label"),   # ✅ AQUÍ,
                col("sentiment_score")
            )
        )

        if nrows == 0:
            print(f"[INFERENCE] batch_id={batch_id} vacío")
            return

        pdf["timestamp"] = (
            pd.to_datetime(pdf["timestamp_epoch"], unit="s", utc=True)
            .dt.tz_convert("UTC")
            .dt.tz_localize(None)
        )

        # ✅ Corte absoluto: ignorar cualquier fila < 2026-01-01
        pdf = pdf[pdf["timestamp"] >= CUTOFF_TS]

        if len(pdf) == 0:
            print(f"[INFERENCE] batch_id={batch_id} todo fuera de rango (< {CUTOFF_TS})")
            return

        pdf = pdf.sort_values(["symbol", "timestamp"])

        t_min = pdf["timestamp"].min()
        t_max = pdf["timestamp"].max()
        print(f"[INFERENCE] batch_id={batch_id} data_range={t_min} → {t_max}")

        alerts_out = []

        for symbol, g in pdf.groupby("symbol"):

            params = STRATEGIES.get(symbol)
            if not params:
                continue

            best_x = int(params["best_x"])
            best_k = int(params["best_k"])
            best_n = int(params["best_n"])
            best_j = float(params["best_j"])
            tipo_estrategia = (params.get("tipo_estrategia") or "").lower().strip()

            asset_name = g["asset_name"].iloc[0]

            # tamaño de buffer recomendado
            min_raw_needed = (best_k + best_n + 5) * best_x

            if symbol not in BUFFERS:
                BUFFERS[symbol] = deque(maxlen=min_raw_needed * 2)
            if BUFFERS[symbol].maxlen < min_raw_needed * 2:
                BUFFERS[symbol] = deque(BUFFERS[symbol], maxlen=min_raw_needed * 2)

            # cargar ticks del batch al buffer
            for _, row in g.iterrows():
                ts = row["timestamp"]
                if ts < CUTOFF_TS:
                    continue
                BUFFERS[symbol].append((ts, float(row["close"])))

            # series para resample
            buf = list(BUFFERS[symbol])
            if len(buf) < 2:
                continue

            # =========================
            # USAR GOLD DIRECTAMENTE (CON BUFFER HISTÓRICO)
            # =========================

            if symbol not in GOLD_BUFFERS:
                GOLD_BUFFERS[symbol] = deque(maxlen=5000)

            for _, row in g.iterrows():
                ts = row["timestamp"]
                if ts < CUTOFF_TS:
                    continue
                GOLD_BUFFERS[symbol].append((ts, float(row["close"])))

            gold_df_sym = (
                pd.DataFrame(GOLD_BUFFERS[symbol], columns=["timestamp", "close"])
                .drop_duplicates("timestamp")
                .sort_values("timestamp")
            )

            gold_minute_df = (
                pd.DataFrame(GOLD_BUFFERS[symbol], columns=["timestamp", "close"])
                .drop_duplicates("timestamp")
                .sort_values("timestamp")
            )

            now_ts_data = g["timestamp"].max()

            gold_df_sym = gold_df_sym[gold_df_sym["timestamp"] <= now_ts_data]

            mins_from_cutoff = ((gold_df_sym["timestamp"] - CUTOFF_TS).dt.total_seconds() // 60).astype(int)
            gold_df_sym = gold_df_sym[mins_from_cutoff % best_x == 0]

            if len(gold_df_sym) < best_k + 1:
                continue

            last_bin_end_ts = gold_df_sym["timestamp"].iloc[-1]
            last_bin_end = last_bin_end_ts.to_pydatetime()

            last_bin_start = last_bin_end_ts - pd.Timedelta(minutes=best_x)

            last_price = float(gold_df_sym["close"].iloc[-1])

            prices = gold_df_sym["close"].astype(float).values

            if last_price <= 0:
                continue

            prev_bin = LAST_PROCESSED_BIN_END.get(symbol)
            if prev_bin is not None and prev_bin == last_bin_end:
                continue
            LAST_PROCESSED_BIN_END[symbol] = last_bin_end

            prices = gold_df_sym["close"].astype(float).values

            # =========================
            # 1) Señal de ENTRADA (si no hay posición)
            # =========================
            pos = POSITIONS.get(symbol)

            if pos is None:

                prices_np = np.array(prices, dtype=float)

                # gold_df_sym ya son cierres cerrados y alineados
                prices_closed = prices_np

                if len(prices_closed) < best_k + 1:
                    continue

                entry_signal = compute_entry_signal(
                    prices=prices_closed,
                    k=best_k,
                    j=best_j,
                    tipo_estrategia=tipo_estrategia
                )

                if entry_signal in ("BUY", "SELL"):
                    if LAST_ALERT_BIN_END.get(symbol) == last_bin_end:
                        continue
                    LAST_ALERT_BIN_END[symbol] = last_bin_end

                    bin_close_price = float(prices_closed[-1])

                    trade_id = str(uuid.uuid4())
                    side = "LONG" if entry_signal == "BUY" else "SHORT"

                    POSITIONS[symbol] = {
                        "trade_id": trade_id,
                        "side": side,
                        "entry_price": bin_close_price,
                        "entry_time": last_bin_end,
                        "bars_held": 0,
                        "x_minutes": best_x,
                        "n_bars": best_n,
                        "last_bin_end": last_bin_end,
                    }

                    alerts_out.append(Row(
                        trade_id=trade_id,
                        tipo_estrategia=tipo_estrategia,
                        timestamp_alert=last_bin_end,
                        asset_name=asset_name,
                        symbol=symbol,
                        best_x=best_x,
                        best_k=best_k,
                        best_n=best_n,
                        best_j=best_j,
                        signal=entry_signal,
                        price=bin_close_price,
                        bin_start=last_bin_start.to_pydatetime(),
                        entry_price=bin_close_price,
                        exit_reason=None,
                        pnl_pct=None,
                        hold_minutes=None,
                        news_count=None,
                        news_main_title=None,
                        news_link=None,
                        news_published_utc=None,
                        news_time_diff_minutes=None,
                        sentiment_label=None,
                        sentiment_score=None
                    ))

                continue

            # =========================
            # 2) Gestión de POSICIÓN (salida por tiempo n barras)
            # =========================
            if "last_bin_end" not in pos:
                pos["last_bin_end"] = last_bin_end
                pos["bars_held"] = 0
            elif pos["last_bin_end"] != last_bin_end:
                pos["bars_held"] += 1
                pos["last_bin_end"] = last_bin_end

            bars_held = int(pos["bars_held"])
            n_bars = int(pos["n_bars"])
            side = pos["side"]
            trade_id = pos["trade_id"]

            if bars_held >= n_bars:
                exit_signal = "SELL" if side == "LONG" else "BUY"

                bin_close_price = float(prices[-1])

                pnl = _pnl_pct(side, float(pos["entry_price"]), bin_close_price)
                hold_minutes = bars_held * int(pos["x_minutes"])

                if LAST_ALERT_BIN_END.get(symbol) != last_bin_end:
                    LAST_ALERT_BIN_END[symbol] = last_bin_end

                    alerts_out.append(Row(
                        trade_id=trade_id,
                        tipo_estrategia=tipo_estrategia,
                        timestamp_alert=last_bin_end,
                        asset_name=asset_name,
                        symbol=symbol,
                        best_x=best_x,
                        best_k=best_k,
                        best_n=best_n,
                        best_j=best_j,
                        signal=exit_signal,
                        price=bin_close_price,
                        bin_start=last_bin_start.to_pydatetime(),
                        entry_price=float(pos["entry_price"]),
                        exit_reason="TIME_BASED_EXIT",
                        pnl_pct=round(pnl * 100, 2),
                        hold_minutes=int(hold_minutes),
                        news_count=None,
                        news_main_title=None,
                        news_link=None,
                        news_published_utc=None,
                        news_time_diff_minutes=None,
                        sentiment_label=None,
                        sentiment_score=None

                    ))

                del POSITIONS[symbol]

        if not alerts_out:
            print(f"[INFERENCE] batch_id={batch_id} sin alertas")
            return

        alerts_sdf = spark.createDataFrame(alerts_out, schema=alert_schema)

        # =========================
        # ENRIQUECER ALERTAS CON NOTICIAS
        # =========================

        alerts_with_news = (
            alerts_sdf.alias("a")
            .join(
                news_df.alias("n"),
                on=(
                    (col("a.symbol") == col("n.asset")) &
                    (col("n.news_published_utc") <= col("a.timestamp_alert")) &
                    (col("n.news_published_utc") >= expr(
                        f"a.timestamp_alert - INTERVAL {NEWS_LOOKBACK_MINUTES} MINUTES"
                    ))
                ),
                how="left"
            )
        )

        w_news = (
            Window
            .partitionBy("a.trade_id")
            .orderBy(
                col("n.news_published_utc").desc(),
                sql_abs(col("n.sentiment_score")).desc()
            )
        )

        alerts_ranked = alerts_with_news.withColumn("news_rank", row_number().over(w_news))

        alerts_main_news = (
            alerts_ranked
            .filter(col("news_rank") == 1)
            .withColumn(
                "news_time_diff_minutes",
                (
                    unix_timestamp(col("a.timestamp_alert")) -
                    unix_timestamp(col("n.news_published_utc"))
                ) / 60
            )
        )

        news_counts = (
            alerts_ranked
            .groupBy("a.trade_id")
            .count()
            .withColumnRenamed("count", "news_count_near")
        )


        alerts_enriched = (
            alerts_main_news
            .join(news_counts, on="trade_id", how="left")
            .select(
                col("a.trade_id"),
                col("a.tipo_estrategia"),
                col("a.timestamp_alert"),
                col("a.asset_name"),
                col("a.symbol"),
                col("a.best_x"),
                col("a.best_k"),
                col("a.best_n"),
                col("a.best_j"),
                col("a.signal"),
                col("a.price"),
                col("a.bin_start"),
                col("a.entry_price"),
                col("a.exit_reason"),
                col("a.pnl_pct"),
                col("a.hold_minutes"),

                # 🔹 noticias (ya sin duplicados)
                col("news_count_near").alias("news_count"),
                col("n.title").alias("news_main_title"),
                col("n.link").alias("news_main_link"),
                col("n.news_published_utc").alias("news_main_published_utc"),
                col("news_time_diff_minutes").cast("int"),
                col("n.sentiment_label").alias("news_main_sentiment_label"),
                col("n.sentiment_score").alias("news_main_sentiment_score"),
            )
        )


        (
            alerts_enriched.write
            .format("delta")
            .mode("append")
            .option("mergeSchema", "true")
            .save(alerts_path)
        )

        print(f"[INFERENCE] batch_id={batch_id} ALERTAS={alerts_out.__len__()}")

        alerts_enriched.select(
            "timestamp_alert",
            "symbol",
            "signal",
            "exit_reason",
            "pnl_pct",
            "hold_minutes",
            "news_count",
            "news_main_published_utc",
            "news_main_title",
            "news_main_link",
            "news_main_sentiment_label",
            "news_main_sentiment_score",
            "trade_id"
        ).orderBy("timestamp_alert", "symbol").show(truncate=False)

    except Exception:
        print("🔥 ERROR REAL EN INFERENCE FOREACH BATCH 🔥")
        traceback.print_exc()
        raise

# %%
##### BLOQUE 10 #####

from pyspark.sql import functions as F

replay_batches = (
    gold_replay
    .withColumn("timestamp_epoch", F.col("timestamp").cast("long"))  # segundos epoch UTC
    .groupBy("timestamp_epoch")
    .agg(
        F.collect_list(
            F.struct("timestamp_epoch", "asset_name", "symbol", "close")
        ).alias("rows")
    )
    .orderBy("timestamp_epoch")
    .collect()
)

print(f"🔥 Iniciando replay histórico: {len(replay_batches)} minutos")
# Out:
# 🔥 Iniciando replay histórico: 21600 minutos

# %%
##### BLOQUE 11 #####

batch_id = 0
for b in replay_batches:
    rows = b["rows"]
    if not rows:
        print(f"[REPLAY] batch_id={batch_id} vacío")
        batch_id += 1
        continue

    from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType

    batch_schema = StructType([
        StructField("timestamp_epoch", LongType(), False),
        StructField("asset_name", StringType(), True),
        StructField("symbol", StringType(), True),
        StructField("close", DoubleType(), True),
    ])

    sdf = spark.createDataFrame(rows, schema=batch_schema)

    process_inference_batch(sdf, batch_id)
    batch_id += 1
# Out:
# [INFERENCE] batch_id=0 rows=9
# [INFERENCE] batch_id=0 data_range=2026-02-01 00:00:00 → 2026-02-01 00:00:00
# [INFERENCE] batch_id=0 sin alertas
# [INFERENCE] batch_id=1 rows=9
# [INFERENCE] batch_id=1 data_range=2026-02-01 00:01:00 → 2026-02-01 00:01:00
# [INFERENCE] batch_id=1 sin alertas
# [INFERENCE] batch_id=2 rows=9
# [INFERENCE] batch_id=2 data_range=2026-02-01 00:02:00 → 2026-02-01 00:02:00
# [INFERENCE] batch_id=2 sin alertas
# [INFERENCE] batch_id=3 rows=9
# [INFERENCE] batch_id=3 data_range=2026-02-01 00:03:00 → 2026-02-01 00:03:00
# [INFERENCE] batch_id=3 sin alertas
# [INFERENCE] batch_id=4 rows=9
# [INFERENCE] batch_id=4 data_range=2026-02-01 00:04:00 → 2026-02-01 00:04:00
# [INFERENCE] batch_id=4 sin alertas
# [INFERENCE] batch_id=5 rows=9
# [INFERENCE] batch_id=5 data_range=2026-02-01 00:05:00 → 2026-02-01 00:05:00
# [INFERENCE] batch_id=5 sin alertas
# [INFERENCE] batch_id=6 rows=9
# [INFERENCE] batch_id=6 data_range=2026-02-01 00:06:00 → 2026-02-01 00:06:00
# [INFERENCE] batch_id=6 sin alertas
# [INFERENCE] batch_id=7 rows=9
# [INFERENCE] batch_id=7 data_range=2026-02-01 00:07:00 → 2026-02-01 00:07:00
# [INFERENCE] batch_id=7 sin alertas
# [INFERENCE] batch_id=8 rows=9
# [INFERENCE] batch_id=8 data_range=2026-02-01 00:08:00 → 2026-02-01 00:08:00
# [INFERENCE] batch_id=8 sin alertas
# [INFERENCE] batch_id=9 rows=9
# [INFERENCE] batch_id=9 data_range=2026-02-01 00:09:00 → 2026-02-01 00:09:00
# [INFERENCE] batch_id=9 sin alertas
# [INFERENCE] batch_id=10 rows=9
# [INFERENCE] batch_id=10 data_range=2026-02-01 00:10:00 → 2026-02-01 00:10:00
# [INFERENCE] batch_id=10 sin alertas
# [INFERENCE] batch_id=11 rows=9
# [INFERENCE] batch_id=11 data_range=2026-02-01 00:11:00 → 2026-02-01 00:11:00
# [INFERENCE] batch_id=11 sin alertas
# [INFERENCE] batch_id=12 rows=9
# [INFERENCE] batch_id=12 data_range=2026-02-01 00:12:00 → 2026-02-01 00:12:00
# [INFERENCE] batch_id=12 sin alertas
# [INFERENCE] batch_id=13 rows=9
# [INFERENCE] batch_id=13 data_range=2026-02-01 00:13:00 → 2026-02-01 00:13:00
# [INFERENCE] batch_id=13 sin alertas
# [INFERENCE] batch_id=14 rows=9
# [INFERENCE] batch_id=14 data_range=2026-02-01 00:14:00 → 2026-02-01 00:14:00
# [INFERENCE] batch_id=14 sin alertas
# [INFERENCE] batch_id=15 rows=9
# [INFERENCE] batch_id=15 data_range=2026-02-01 00:15:00 → 2026-02-01 00:15:00
# [INFERENCE] batch_id=15 sin alertas
# [INFERENCE] batch_id=16 rows=9
# [INFERENCE] batch_id=16 data_range=2026-02-01 00:16:00 → 2026-02-01 00:16:00
# [INFERENCE] batch_id=16 sin alertas
# [INFERENCE] batch_id=17 rows=9
# [INFERENCE] batch_id=17 data_range=2026-02-01 00:17:00 → 2026-02-01 00:17:00
# [INFERENCE] batch_id=17 sin alertas
# [INFERENCE] batch_id=18 rows=9
# [INFERENCE] batch_id=18 data_range=2026-02-01 00:18:00 → 2026-02-01 00:18:00
# [INFERENCE] batch_id=18 sin alertas
# [INFERENCE] batch_id=19 rows=9
# [INFERENCE] batch_id=19 data_range=2026-02-01 00:19:00 → 2026-02-01 00:19:00
# [INFERENCE] batch_id=19 sin alertas
# [INFERENCE] batch_id=20 rows=9
# [INFERENCE] batch_id=20 data_range=2026-02-01 00:20:00 → 2026-02-01 00:20:00
# [INFERENCE] batch_id=20 sin alertas
# [INFERENCE] batch_id=21 rows=9
# [INFERENCE] batch_id=21 data_range=2026-02-01 00:21:00 → 2026-02-01 00:21:00
# [INFERENCE] batch_id=21 sin alertas
# [INFERENCE] batch_id=22 rows=9
# [INFERENCE] batch_id=22 data_range=2026-02-01 00:22:00 → 2026-02-01 00:22:00
# [INFERENCE] batch_id=22 sin alertas
# [INFERENCE] batch_id=23 rows=9
# [INFERENCE] batch_id=23 data_range=2026-02-01 00:23:00 → 2026-02-01 00:23:00
# [INFERENCE] batch_id=23 sin alertas
# [INFERENCE] batch_id=24 rows=9
# [INFERENCE] batch_id=24 data_range=2026-02-01 00:24:00 → 2026-02-01 00:24:00
# [INFERENCE] batch_id=24 sin alertas
# [INFERENCE] batch_id=25 rows=9
# [INFERENCE] batch_id=25 data_range=2026-02-01 00:25:00 → 2026-02-01 00:25:00
# [INFERENCE] batch_id=25 sin alertas
# [INFERENCE] batch_id=26 rows=9
# [INFERENCE] batch_id=26 data_range=2026-02-01 00:26:00 → 2026-02-01 00:26:00
# [INFERENCE] batch_id=26 sin alertas
# [INFERENCE] batch_id=27 rows=9
# [INFERENCE] batch_id=27 data_range=2026-02-01 00:27:00 → 2026-02-01 00:27:00
# [INFERENCE] batch_id=27 sin alertas
# [INFERENCE] batch_id=28 rows=9
# [INFERENCE] batch_id=28 data_range=2026-02-01 00:28:00 → 2026-02-01 00:28:00
# [INFERENCE] batch_id=28 sin alertas
# [INFERENCE] batch_id=29 rows=9
# [INFERENCE] batch_id=29 data_range=2026-02-01 00:29:00 → 2026-02-01 00:29:00
# [INFERENCE] batch_id=29 sin alertas
# [INFERENCE] batch_id=30 rows=9
# [INFERENCE] batch_id=30 data_range=2026-02-01 00:30:00 → 2026-02-01 00:30:00
# [INFERENCE] batch_id=30 sin alertas
# [INFERENCE] batch_id=31 rows=9
# [INFERENCE] batch_id=31 data_range=2026-02-01 00:31:00 → 2026-02-01 00:31:00
# [INFERENCE] batch_id=31 sin alertas
# [INFERENCE] batch_id=32 rows=9
# [INFERENCE] batch_id=32 data_range=2026-02-01 00:32:00 → 2026-02-01 00:32:00
# [INFERENCE] batch_id=32 sin alertas
# [INFERENCE] batch_id=33 rows=9
# [INFERENCE] batch_id=33 data_range=2026-02-01 00:33:00 → 2026-02-01 00:33:00
# [INFERENCE] batch_id=33 sin alertas
# [INFERENCE] batch_id=34 rows=9
# [INFERENCE] batch_id=34 data_range=2026-02-01 00:34:00 → 2026-02-01 00:34:00
# [INFERENCE] batch_id=34 sin alertas
# [INFERENCE] batch_id=35 rows=9
# [INFERENCE] batch_id=35 data_range=2026-02-01 00:35:00 → 2026-02-01 00:35:00
# [INFERENCE] batch_id=35 sin alertas
# [INFERENCE] batch_id=36 rows=9
# [INFERENCE] batch_id=36 data_range=2026-02-01 00:36:00 → 2026-02-01 00:36:00
# [INFERENCE] batch_id=36 sin alertas
# [INFERENCE] batch_id=37 rows=9
# [INFERENCE] batch_id=37 data_range=2026-02-01 00:37:00 → 2026-02-01 00:37:00
# [INFERENCE] batch_id=37 sin alertas
# [INFERENCE] batch_id=38 rows=9
# [INFERENCE] batch_id=38 data_range=2026-02-01 00:38:00 → 2026-02-01 00:38:00
# [INFERENCE] batch_id=38 sin alertas
# [INFERENCE] batch_id=39 rows=9
# [INFERENCE] batch_id=39 data_range=2026-02-01 00:39:00 → 2026-02-01 00:39:00
# [INFERENCE] batch_id=39 sin alertas
# [INFERENCE] batch_id=40 rows=9
# [INFERENCE] batch_id=40 data_range=2026-02-01 00:40:00 → 2026-02-01 00:40:00
# [INFERENCE] batch_id=40 sin alertas
# [INFERENCE] batch_id=41 rows=9
# [INFERENCE] batch_id=41 data_range=2026-02-01 00:41:00 → 2026-02-01 00:41:00
# [INFERENCE] batch_id=41 sin alertas
# [INFERENCE] batch_id=42 rows=9
# [INFERENCE] batch_id=42 data_range=2026-02-01 00:42:00 → 2026-02-01 00:42:00
# [INFERENCE] batch_id=42 sin alertas
# [INFERENCE] batch_id=43 rows=9
# [INFERENCE] batch_id=43 data_range=2026-02-01 00:43:00 → 2026-02-01 00:43:00
# [INFERENCE] batch_id=43 sin alertas
# [INFERENCE] batch_id=44 rows=9
# [INFERENCE] batch_id=44 data_range=2026-02-01 00:44:00 → 2026-02-01 00:44:00
# [INFERENCE] batch_id=44 sin alertas
# [INFERENCE] batch_id=45 rows=9
# [INFERENCE] batch_id=45 data_range=2026-02-01 00:45:00 → 2026-02-01 00:45:00
# [INFERENCE] batch_id=45 sin alertas
# [INFERENCE] batch_id=46 rows=9
# [INFERENCE] batch_id=46 data_range=2026-02-01 00:46:00 → 2026-02-01 00:46:00
# [INFERENCE] batch_id=46 sin alertas
# [INFERENCE] batch_id=47 rows=9
# [INFERENCE] batch_id=47 data_range=2026-02-01 00:47:00 → 2026-02-01 00:47:00
# [INFERENCE] batch_id=47 sin alertas
# [INFERENCE] batch_id=48 rows=9
# [INFERENCE] batch_id=48 data_range=2026-02-01 00:48:00 → 2026-02-01 00:48:00
# [INFERENCE] batch_id=48 sin alertas
# [INFERENCE] batch_id=49 rows=9
# [INFERENCE] batch_id=49 data_range=2026-02-01 00:49:00 → 2026-02-01 00:49:00
# [INFERENCE] batch_id=49 sin alertas
# [INFERENCE] batch_id=50 rows=9
# [INFERENCE] batch_id=50 data_range=2026-02-01 00:50:00 → 2026-02-01 00:50:00
# [INFERENCE] batch_id=50 sin alertas
# [INFERENCE] batch_id=51 rows=9
# [INFERENCE] batch_id=51 data_range=2026-02-01 00:51:00 → 2026-02-01 00:51:00
# [INFERENCE] batch_id=51 sin alertas
# [INFERENCE] batch_id=52 rows=9
# [INFERENCE] batch_id=52 data_range=2026-02-01 00:52:00 → 2026-02-01 00:52:00
# [INFERENCE] batch_id=52 sin alertas
# [INFERENCE] batch_id=53 rows=9
# [INFERENCE] batch_id=53 data_range=2026-02-01 00:53:00 → 2026-02-01 00:53:00
# [INFERENCE] batch_id=53 sin alertas
# [INFERENCE] batch_id=54 rows=9
# [INFERENCE] batch_id=54 data_range=2026-02-01 00:54:00 → 2026-02-01 00:54:00
# [INFERENCE] batch_id=54 sin alertas
# [INFERENCE] batch_id=55 rows=9
# [INFERENCE] batch_id=55 data_range=2026-02-01 00:55:00 → 2026-02-01 00:55:00
# [INFERENCE] batch_id=55 sin alertas
# [INFERENCE] batch_id=56 rows=9
# [INFERENCE] batch_id=56 data_range=2026-02-01 00:56:00 → 2026-02-01 00:56:00
# [INFERENCE] batch_id=56 sin alertas
# [INFERENCE] batch_id=57 rows=9
# [INFERENCE] batch_id=57 data_range=2026-02-01 00:57:00 → 2026-02-01 00:57:00
# [INFERENCE] batch_id=57 sin alertas
# [INFERENCE] batch_id=58 rows=9
# [INFERENCE] batch_id=58 data_range=2026-02-01 00:58:00 → 2026-02-01 00:58:00
# [INFERENCE] batch_id=58 sin alertas
# [INFERENCE] batch_id=59 rows=9
# [INFERENCE] batch_id=59 data_range=2026-02-01 00:59:00 → 2026-02-01 00:59:00
# [INFERENCE] batch_id=59 sin alertas
# [INFERENCE] batch_id=60 rows=9
# [INFERENCE] batch_id=60 data_range=2026-02-01 01:00:00 → 2026-02-01 01:00:00
# [INFERENCE] batch_id=60 sin alertas
# [INFERENCE] batch_id=61 rows=9
# [INFERENCE] batch_id=61 data_range=2026-02-01 01:01:00 → 2026-02-01 01:01:00
# [INFERENCE] batch_id=61 sin alertas
# [INFERENCE] batch_id=62 rows=9
# [INFERENCE] batch_id=62 data_range=2026-02-01 01:02:00 → 2026-02-01 01:02:00
# [INFERENCE] batch_id=62 sin alertas
# [INFERENCE] batch_id=63 rows=9
# [INFERENCE] batch_id=63 data_range=2026-02-01 01:03:00 → 2026-02-01 01:03:00
# [INFERENCE] batch_id=63 sin alertas
# [INFERENCE] batch_id=64 rows=9
# [INFERENCE] batch_id=64 data_range=2026-02-01 01:04:00 → 2026-02-01 01:04:00
# [INFERENCE] batch_id=64 sin alertas
# [INFERENCE] batch_id=65 rows=9
# [INFERENCE] batch_id=65 data_range=2026-02-01 01:05:00 → 2026-02-01 01:05:00
# [INFERENCE] batch_id=65 sin alertas
# [INFERENCE] batch_id=66 rows=9
# [INFERENCE] batch_id=66 data_range=2026-02-01 01:06:00 → 2026-02-01 01:06:00
# [INFERENCE] batch_id=66 sin alertas
# [INFERENCE] batch_id=67 rows=9
# [INFERENCE] batch_id=67 data_range=2026-02-01 01:07:00 → 2026-02-01 01:07:00
# [INFERENCE] batch_id=67 sin alertas
# [INFERENCE] batch_id=68 rows=9
# [INFERENCE] batch_id=68 data_range=2026-02-01 01:08:00 → 2026-02-01 01:08:00
# [INFERENCE] batch_id=68 sin alertas
# [INFERENCE] batch_id=69 rows=9
# [INFERENCE] batch_id=69 data_range=2026-02-01 01:09:00 → 2026-02-01 01:09:00
# [INFERENCE] batch_id=69 sin alertas
# [INFERENCE] batch_id=70 rows=9
# [INFERENCE] batch_id=70 data_range=2026-02-01 01:10:00 → 2026-02-01 01:10:00
# [INFERENCE] batch_id=70 sin alertas
# [INFERENCE] batch_id=71 rows=9
# [INFERENCE] batch_id=71 data_range=2026-02-01 01:11:00 → 2026-02-01 01:11:00
# [INFERENCE] batch_id=71 sin alertas
# [INFERENCE] batch_id=72 rows=9
# [INFERENCE] batch_id=72 data_range=2026-02-01 01:12:00 → 2026-02-01 01:12:00
# [INFERENCE] batch_id=72 sin alertas
# [INFERENCE] batch_id=73 rows=9
# [INFERENCE] batch_id=73 data_range=2026-02-01 01:13:00 → 2026-02-01 01:13:00
# [INFERENCE] batch_id=73 sin alertas
# [INFERENCE] batch_id=74 rows=9
# [INFERENCE] batch_id=74 data_range=2026-02-01 01:14:00 → 2026-02-01 01:14:00
# [INFERENCE] batch_id=74 sin alertas
# [INFERENCE] batch_id=75 rows=9
# [INFERENCE] batch_id=75 data_range=2026-02-01 01:15:00 → 2026-02-01 01:15:00
# [INFERENCE] batch_id=75 sin alertas
# [INFERENCE] batch_id=76 rows=9
# [INFERENCE] batch_id=76 data_range=2026-02-01 01:16:00 → 2026-02-01 01:16:00
# [INFERENCE] batch_id=76 sin alertas
# [INFERENCE] batch_id=77 rows=9
# [INFERENCE] batch_id=77 data_range=2026-02-01 01:17:00 → 2026-02-01 01:17:00
# [INFERENCE] batch_id=77 sin alertas
# [INFERENCE] batch_id=78 rows=9
# [INFERENCE] batch_id=78 data_range=2026-02-01 01:18:00 → 2026-02-01 01:18:00
# [INFERENCE] batch_id=78 sin alertas
# [INFERENCE] batch_id=79 rows=9
# [INFERENCE] batch_id=79 data_range=2026-02-01 01:19:00 → 2026-02-01 01:19:00
# [INFERENCE] batch_id=79 sin alertas
# [INFERENCE] batch_id=80 rows=9
# [INFERENCE] batch_id=80 data_range=2026-02-01 01:20:00 → 2026-02-01 01:20:00
# [INFERENCE] batch_id=80 sin alertas
# [INFERENCE] batch_id=81 rows=9
# [INFERENCE] batch_id=81 data_range=2026-02-01 01:21:00 → 2026-02-01 01:21:00
# [INFERENCE] batch_id=81 sin alertas
# [INFERENCE] batch_id=82 rows=9
# [INFERENCE] batch_id=82 data_range=2026-02-01 01:22:00 → 2026-02-01 01:22:00
# [INFERENCE] batch_id=82 sin alertas
# [INFERENCE] batch_id=83 rows=9
# [INFERENCE] batch_id=83 data_range=2026-02-01 01:23:00 → 2026-02-01 01:23:00
# [INFERENCE] batch_id=83 sin alertas
# [INFERENCE] batch_id=84 rows=9
# [INFERENCE] batch_id=84 data_range=2026-02-01 01:24:00 → 2026-02-01 01:24:00
# [INFERENCE] batch_id=84 sin alertas
# [INFERENCE] batch_id=85 rows=9
# [INFERENCE] batch_id=85 data_range=2026-02-01 01:25:00 → 2026-02-01 01:25:00
# [INFERENCE] batch_id=85 sin alertas
# [INFERENCE] batch_id=86 rows=9
# [INFERENCE] batch_id=86 data_range=2026-02-01 01:26:00 → 2026-02-01 01:26:00
# [INFERENCE] batch_id=86 sin alertas
# [INFERENCE] batch_id=87 rows=9
# [INFERENCE] batch_id=87 data_range=2026-02-01 01:27:00 → 2026-02-01 01:27:00
# [INFERENCE] batch_id=87 sin alertas
# [INFERENCE] batch_id=88 rows=9
# [INFERENCE] batch_id=88 data_range=2026-02-01 01:28:00 → 2026-02-01 01:28:00
# [INFERENCE] batch_id=88 sin alertas
# [INFERENCE] batch_id=89 rows=9
# [INFERENCE] batch_id=89 data_range=2026-02-01 01:29:00 → 2026-02-01 01:29:00
# [INFERENCE] batch_id=89 sin alertas
# [INFERENCE] batch_id=90 rows=9
# [INFERENCE] batch_id=90 data_range=2026-02-01 01:30:00 → 2026-02-01 01:30:00
# [INFERENCE] batch_id=90 sin alertas
# [INFERENCE] batch_id=91 rows=9
# [INFERENCE] batch_id=91 data_range=2026-02-01 01:31:00 → 2026-02-01 01:31:00
# [INFERENCE] batch_id=91 sin alertas
# [INFERENCE] batch_id=92 rows=9
# [INFERENCE] batch_id=92 data_range=2026-02-01 01:32:00 → 2026-02-01 01:32:00
# [INFERENCE] batch_id=92 sin alertas
# [INFERENCE] batch_id=93 rows=9
# [INFERENCE] batch_id=93 data_range=2026-02-01 01:33:00 → 2026-02-01 01:33:00
# [INFERENCE] batch_id=93 sin alertas
# [INFERENCE] batch_id=94 rows=9
# [INFERENCE] batch_id=94 data_range=2026-02-01 01:34:00 → 2026-02-01 01:34:00
# [INFERENCE] batch_id=94 sin alertas
# [INFERENCE] batch_id=95 rows=9
# [INFERENCE] batch_id=95 data_range=2026-02-01 01:35:00 → 2026-02-01 01:35:00
# [INFERENCE] batch_id=95 sin alertas
# [INFERENCE] batch_id=96 rows=9
# [INFERENCE] batch_id=96 data_range=2026-02-01 01:36:00 → 2026-02-01 01:36:00
# [INFERENCE] batch_id=96 sin alertas
# [INFERENCE] batch_id=97 rows=9
# [INFERENCE] batch_id=97 data_range=2026-02-01 01:37:00 → 2026-02-01 01:37:00
# [INFERENCE] batch_id=97 sin alertas
# [INFERENCE] batch_id=98 rows=9
# [INFERENCE] batch_id=98 data_range=2026-02-01 01:38:00 → 2026-02-01 01:38:00
# [INFERENCE] batch_id=98 sin alertas
# [INFERENCE] batch_id=99 rows=9
# [INFERENCE] batch_id=99 data_range=2026-02-01 01:39:00 → 2026-02-01 01:39:00
# [INFERENCE] batch_id=99 sin alertas
# [INFERENCE] batch_id=100 rows=9
# [INFERENCE] batch_id=100 data_range=2026-02-01 01:40:00 → 2026-02-01 01:40:00
# [INFERENCE] batch_id=100 sin alertas
# [INFERENCE] batch_id=101 rows=9
# [INFERENCE] batch_id=101 data_range=2026-02-01 01:41:00 → 2026-02-01 01:41:00
# [INFERENCE] batch_id=101 sin alertas
# [INFERENCE] batch_id=102 rows=9
# [INFERENCE] batch_id=102 data_range=2026-02-01 01:42:00 → 2026-02-01 01:42:00
# [INFERENCE] batch_id=102 sin alertas
# [INFERENCE] batch_id=103 rows=9
# [INFERENCE] batch_id=103 data_range=2026-02-01 01:43:00 → 2026-02-01 01:43:00
# [INFERENCE] batch_id=103 sin alertas
# [INFERENCE] batch_id=104 rows=9
# [INFERENCE] batch_id=104 data_range=2026-02-01 01:44:00 → 2026-02-01 01:44:00
# [INFERENCE] batch_id=104 sin alertas
# [INFERENCE] batch_id=105 rows=9
# [INFERENCE] batch_id=105 data_range=2026-02-01 01:45:00 → 2026-02-01 01:45:00
# [INFERENCE] batch_id=105 sin alertas
# [INFERENCE] batch_id=106 rows=9
# [INFERENCE] batch_id=106 data_range=2026-02-01 01:46:00 → 2026-02-01 01:46:00
# [INFERENCE] batch_id=106 sin alertas
# [INFERENCE] batch_id=107 rows=9
# [INFERENCE] batch_id=107 data_range=2026-02-01 01:47:00 → 2026-02-01 01:47:00
# [INFERENCE] batch_id=107 sin alertas
# [INFERENCE] batch_id=108 rows=9
# [INFERENCE] batch_id=108 data_range=2026-02-01 01:48:00 → 2026-02-01 01:48:00
# [INFERENCE] batch_id=108 sin alertas
# [INFERENCE] batch_id=109 rows=9
# [INFERENCE] batch_id=109 data_range=2026-02-01 01:49:00 → 2026-02-01 01:49:00
# [INFERENCE] batch_id=109 sin alertas
# [INFERENCE] batch_id=110 rows=9
# [INFERENCE] batch_id=110 data_range=2026-02-01 01:50:00 → 2026-02-01 01:50:00
# [INFERENCE] batch_id=110 sin alertas
# [INFERENCE] batch_id=111 rows=9
# [INFERENCE] batch_id=111 data_range=2026-02-01 01:51:00 → 2026-02-01 01:51:00
# [INFERENCE] batch_id=111 sin alertas
# [INFERENCE] batch_id=112 rows=9
# [INFERENCE] batch_id=112 data_range=2026-02-01 01:52:00 → 2026-02-01 01:52:00
# [INFERENCE] batch_id=112 sin alertas
# [INFERENCE] batch_id=113 rows=9
# [INFERENCE] batch_id=113 data_range=2026-02-01 01:53:00 → 2026-02-01 01:53:00
# [INFERENCE] batch_id=113 sin alertas
# [INFERENCE] batch_id=114 rows=9
# [INFERENCE] batch_id=114 data_range=2026-02-01 01:54:00 → 2026-02-01 01:54:00
# [INFERENCE] batch_id=114 sin alertas
# [INFERENCE] batch_id=115 rows=9
# [INFERENCE] batch_id=115 data_range=2026-02-01 01:55:00 → 2026-02-01 01:55:00
# [INFERENCE] batch_id=115 sin alertas
# [INFERENCE] batch_id=116 rows=9
# [INFERENCE] batch_id=116 data_range=2026-02-01 01:56:00 → 2026-02-01 01:56:00
# [INFERENCE] batch_id=116 sin alertas
# [INFERENCE] batch_id=117 rows=9
# [INFERENCE] batch_id=117 data_range=2026-02-01 01:57:00 → 2026-02-01 01:57:00
# [INFERENCE] batch_id=117 sin alertas
# [INFERENCE] batch_id=118 rows=9
# [INFERENCE] batch_id=118 data_range=2026-02-01 01:58:00 → 2026-02-01 01:58:00
# [INFERENCE] batch_id=118 sin alertas
# [INFERENCE] batch_id=119 rows=9
# [INFERENCE] batch_id=119 data_range=2026-02-01 01:59:00 → 2026-02-01 01:59:00
# [INFERENCE] batch_id=119 sin alertas
# [INFERENCE] batch_id=120 rows=9
# [INFERENCE] batch_id=120 data_range=2026-02-01 02:00:00 → 2026-02-01 02:00:00
# [INFERENCE] batch_id=120 sin alertas
# [INFERENCE] batch_id=121 rows=9
# [INFERENCE] batch_id=121 data_range=2026-02-01 02:01:00 → 2026-02-01 02:01:00
# [INFERENCE] batch_id=121 sin alertas
# [INFERENCE] batch_id=122 rows=9
# [INFERENCE] batch_id=122 data_range=2026-02-01 02:02:00 → 2026-02-01 02:02:00
# [INFERENCE] batch_id=122 sin alertas
# [INFERENCE] batch_id=123 rows=9
# [INFERENCE] batch_id=123 data_range=2026-02-01 02:03:00 → 2026-02-01 02:03:00
# [INFERENCE] batch_id=123 sin alertas
# [INFERENCE] batch_id=124 rows=9
# [INFERENCE] batch_id=124 data_range=2026-02-01 02:04:00 → 2026-02-01 02:04:00
# [INFERENCE] batch_id=124 sin alertas
# [INFERENCE] batch_id=125 rows=9
# [INFERENCE] batch_id=125 data_range=2026-02-01 02:05:00 → 2026-02-01 02:05:00
# [INFERENCE] batch_id=125 sin alertas
# [INFERENCE] batch_id=126 rows=9
# [INFERENCE] batch_id=126 data_range=2026-02-01 02:06:00 → 2026-02-01 02:06:00
# [INFERENCE] batch_id=126 sin alertas
# [INFERENCE] batch_id=127 rows=9
# [INFERENCE] batch_id=127 data_range=2026-02-01 02:07:00 → 2026-02-01 02:07:00
# [INFERENCE] batch_id=127 sin alertas
# [INFERENCE] batch_id=128 rows=9
# [INFERENCE] batch_id=128 data_range=2026-02-01 02:08:00 → 2026-02-01 02:08:00
# [INFERENCE] batch_id=128 sin alertas
# [INFERENCE] batch_id=129 rows=9
# [INFERENCE] batch_id=129 data_range=2026-02-01 02:09:00 → 2026-02-01 02:09:00
# [INFERENCE] batch_id=129 sin alertas
# [INFERENCE] batch_id=130 rows=9
# [INFERENCE] batch_id=130 data_range=2026-02-01 02:10:00 → 2026-02-01 02:10:00
# [INFERENCE] batch_id=130 sin alertas
# [INFERENCE] batch_id=131 rows=9
# [INFERENCE] batch_id=131 data_range=2026-02-01 02:11:00 → 2026-02-01 02:11:00
# [INFERENCE] batch_id=131 sin alertas
# [INFERENCE] batch_id=132 rows=9
# [INFERENCE] batch_id=132 data_range=2026-02-01 02:12:00 → 2026-02-01 02:12:00
# [INFERENCE] batch_id=132 sin alertas
# [INFERENCE] batch_id=133 rows=9
# [INFERENCE] batch_id=133 data_range=2026-02-01 02:13:00 → 2026-02-01 02:13:00
# [INFERENCE] batch_id=133 sin alertas
# [INFERENCE] batch_id=134 rows=9
# [INFERENCE] batch_id=134 data_range=2026-02-01 02:14:00 → 2026-02-01 02:14:00
# [INFERENCE] batch_id=134 sin alertas
# [INFERENCE] batch_id=135 rows=9
# [INFERENCE] batch_id=135 data_range=2026-02-01 02:15:00 → 2026-02-01 02:15:00
# [INFERENCE] batch_id=135 sin alertas
# [INFERENCE] batch_id=136 rows=9
# [INFERENCE] batch_id=136 data_range=2026-02-01 02:16:00 → 2026-02-01 02:16:00
# [INFERENCE] batch_id=136 sin alertas
# [INFERENCE] batch_id=137 rows=9
# [INFERENCE] batch_id=137 data_range=2026-02-01 02:17:00 → 2026-02-01 02:17:00
# [INFERENCE] batch_id=137 sin alertas
# [INFERENCE] batch_id=138 rows=9
# [INFERENCE] batch_id=138 data_range=2026-02-01 02:18:00 → 2026-02-01 02:18:00
# [INFERENCE] batch_id=138 sin alertas
# [INFERENCE] batch_id=139 rows=9
# [INFERENCE] batch_id=139 data_range=2026-02-01 02:19:00 → 2026-02-01 02:19:00
# [INFERENCE] batch_id=139 sin alertas
# [INFERENCE] batch_id=140 rows=9
# [INFERENCE] batch_id=140 data_range=2026-02-01 02:20:00 → 2026-02-01 02:20:00
# [INFERENCE] batch_id=140 sin alertas
# [INFERENCE] batch_id=141 rows=9
# [INFERENCE] batch_id=141 data_range=2026-02-01 02:21:00 → 2026-02-01 02:21:00
# [INFERENCE] batch_id=141 sin alertas
# [INFERENCE] batch_id=142 rows=9
# [INFERENCE] batch_id=142 data_range=2026-02-01 02:22:00 → 2026-02-01 02:22:00
# [INFERENCE] batch_id=142 sin alertas
# [INFERENCE] batch_id=143 rows=9
# [INFERENCE] batch_id=143 data_range=2026-02-01 02:23:00 → 2026-02-01 02:23:00
# [INFERENCE] batch_id=143 sin alertas
# [INFERENCE] batch_id=144 rows=9
# [INFERENCE] batch_id=144 data_range=2026-02-01 02:24:00 → 2026-02-01 02:24:00
# [INFERENCE] batch_id=144 sin alertas
# [INFERENCE] batch_id=145 rows=9
# [INFERENCE] batch_id=145 data_range=2026-02-01 02:25:00 → 2026-02-01 02:25:00
# [INFERENCE] batch_id=145 sin alertas
# [INFERENCE] batch_id=146 rows=9
# [INFERENCE] batch_id=146 data_range=2026-02-01 02:26:00 → 2026-02-01 02:26:00
# [INFERENCE] batch_id=146 sin alertas
# [INFERENCE] batch_id=147 rows=9
# [INFERENCE] batch_id=147 data_range=2026-02-01 02:27:00 → 2026-02-01 02:27:00
# [INFERENCE] batch_id=147 sin alertas
# [INFERENCE] batch_id=148 rows=9
# [INFERENCE] batch_id=148 data_range=2026-02-01 02:28:00 → 2026-02-01 02:28:00
# [INFERENCE] batch_id=148 sin alertas
# [INFERENCE] batch_id=149 rows=9
# [INFERENCE] batch_id=149 data_range=2026-02-01 02:29:00 → 2026-02-01 02:29:00
# [INFERENCE] batch_id=149 sin alertas
# [INFERENCE] batch_id=150 rows=9
# [INFERENCE] batch_id=150 data_range=2026-02-01 02:30:00 → 2026-02-01 02:30:00
# [INFERENCE] batch_id=150 sin alertas
# [INFERENCE] batch_id=151 rows=9
# [INFERENCE] batch_id=151 data_range=2026-02-01 02:31:00 → 2026-02-01 02:31:00
# [INFERENCE] batch_id=151 sin alertas
# [INFERENCE] batch_id=152 rows=9
# [INFERENCE] batch_id=152 data_range=2026-02-01 02:32:00 → 2026-02-01 02:32:00
# [INFERENCE] batch_id=152 sin alertas
# [INFERENCE] batch_id=153 rows=9
# [INFERENCE] batch_id=153 data_range=2026-02-01 02:33:00 → 2026-02-01 02:33:00
# [INFERENCE] batch_id=153 sin alertas
# [INFERENCE] batch_id=154 rows=9
# [INFERENCE] batch_id=154 data_range=2026-02-01 02:34:00 → 2026-02-01 02:34:00
# [INFERENCE] batch_id=154 sin alertas
# [INFERENCE] batch_id=155 rows=9
# [INFERENCE] batch_id=155 data_range=2026-02-01 02:35:00 → 2026-02-01 02:35:00
# [INFERENCE] batch_id=155 sin alertas
# [INFERENCE] batch_id=156 rows=9
# [INFERENCE] batch_id=156 data_range=2026-02-01 02:36:00 → 2026-02-01 02:36:00
# [INFERENCE] batch_id=156 sin alertas
# [INFERENCE] batch_id=157 rows=9
# [INFERENCE] batch_id=157 data_range=2026-02-01 02:37:00 → 2026-02-01 02:37:00
# [INFERENCE] batch_id=157 sin alertas
# [INFERENCE] batch_id=158 rows=9
# [INFERENCE] batch_id=158 data_range=2026-02-01 02:38:00 → 2026-02-01 02:38:00
# [INFERENCE] batch_id=158 sin alertas
# [INFERENCE] batch_id=159 rows=9
# [INFERENCE] batch_id=159 data_range=2026-02-01 02:39:00 → 2026-02-01 02:39:00
# [INFERENCE] batch_id=159 sin alertas
# [INFERENCE] batch_id=160 rows=9
# [INFERENCE] batch_id=160 data_range=2026-02-01 02:40:00 → 2026-02-01 02:40:00
# [INFERENCE] batch_id=160 sin alertas
# [INFERENCE] batch_id=161 rows=9
# [INFERENCE] batch_id=161 data_range=2026-02-01 02:41:00 → 2026-02-01 02:41:00
# [INFERENCE] batch_id=161 sin alertas
# [INFERENCE] batch_id=162 rows=9
# [INFERENCE] batch_id=162 data_range=2026-02-01 02:42:00 → 2026-02-01 02:42:00
# [INFERENCE] batch_id=162 sin alertas
# [INFERENCE] batch_id=163 rows=9
# [INFERENCE] batch_id=163 data_range=2026-02-01 02:43:00 → 2026-02-01 02:43:00
# [INFERENCE] batch_id=163 sin alertas
# [INFERENCE] batch_id=164 rows=9
# [INFERENCE] batch_id=164 data_range=2026-02-01 02:44:00 → 2026-02-01 02:44:00
# [INFERENCE] batch_id=164 sin alertas
# [INFERENCE] batch_id=165 rows=9
# [INFERENCE] batch_id=165 data_range=2026-02-01 02:45:00 → 2026-02-01 02:45:00
# [INFERENCE] batch_id=165 sin alertas
# [INFERENCE] batch_id=166 rows=9
# [INFERENCE] batch_id=166 data_range=2026-02-01 02:46:00 → 2026-02-01 02:46:00
# [INFERENCE] batch_id=166 sin alertas
# [INFERENCE] batch_id=167 rows=9
# [INFERENCE] batch_id=167 data_range=2026-02-01 02:47:00 → 2026-02-01 02:47:00
# [INFERENCE] batch_id=167 sin alertas
# [INFERENCE] batch_id=168 rows=9
# [INFERENCE] batch_id=168 data_range=2026-02-01 02:48:00 → 2026-02-01 02:48:00
# [INFERENCE] batch_id=168 sin alertas
# [INFERENCE] batch_id=169 rows=9
# [INFERENCE] batch_id=169 data_range=2026-02-01 02:49:00 → 2026-02-01 02:49:00
# [INFERENCE] batch_id=169 sin alertas
# [INFERENCE] batch_id=170 rows=9
# [INFERENCE] batch_id=170 data_range=2026-02-01 02:50:00 → 2026-02-01 02:50:00
# [INFERENCE] batch_id=170 sin alertas
# [INFERENCE] batch_id=171 rows=9
# [INFERENCE] batch_id=171 data_range=2026-02-01 02:51:00 → 2026-02-01 02:51:00
# [INFERENCE] batch_id=171 sin alertas
# [INFERENCE] batch_id=172 rows=9
# [INFERENCE] batch_id=172 data_range=2026-02-01 02:52:00 → 2026-02-01 02:52:00
# [INFERENCE] batch_id=172 sin alertas
# [INFERENCE] batch_id=173 rows=9
# [INFERENCE] batch_id=173 data_range=2026-02-01 02:53:00 → 2026-02-01 02:53:00
# [INFERENCE] batch_id=173 sin alertas
# [INFERENCE] batch_id=174 rows=9
# [INFERENCE] batch_id=174 data_range=2026-02-01 02:54:00 → 2026-02-01 02:54:00
# [INFERENCE] batch_id=174 sin alertas
# [INFERENCE] batch_id=175 rows=9
# [INFERENCE] batch_id=175 data_range=2026-02-01 02:55:00 → 2026-02-01 02:55:00
# [INFERENCE] batch_id=175 sin alertas
# [INFERENCE] batch_id=176 rows=9
# [INFERENCE] batch_id=176 data_range=2026-02-01 02:56:00 → 2026-02-01 02:56:00
# [INFERENCE] batch_id=176 sin alertas
# [INFERENCE] batch_id=177 rows=9
# [INFERENCE] batch_id=177 data_range=2026-02-01 02:57:00 → 2026-02-01 02:57:00
# [INFERENCE] batch_id=177 sin alertas
# [INFERENCE] batch_id=178 rows=9
# [INFERENCE] batch_id=178 data_range=2026-02-01 02:58:00 → 2026-02-01 02:58:00
# [INFERENCE] batch_id=178 sin alertas
# [INFERENCE] batch_id=179 rows=9
# [INFERENCE] batch_id=179 data_range=2026-02-01 02:59:00 → 2026-02-01 02:59:00
# [INFERENCE] batch_id=179 sin alertas
# [INFERENCE] batch_id=180 rows=9
# [INFERENCE] batch_id=180 data_range=2026-02-01 03:00:00 → 2026-02-01 03:00:00
# [INFERENCE] batch_id=180 sin alertas
# [INFERENCE] batch_id=181 rows=9
# [INFERENCE] batch_id=181 data_range=2026-02-01 03:01:00 → 2026-02-01 03:01:00
# [INFERENCE] batch_id=181 sin alertas
# [INFERENCE] batch_id=182 rows=9
# [INFERENCE] batch_id=182 data_range=2026-02-01 03:02:00 → 2026-02-01 03:02:00
# [INFERENCE] batch_id=182 sin alertas
# [INFERENCE] batch_id=183 rows=9
# [INFERENCE] batch_id=183 data_range=2026-02-01 03:03:00 → 2026-02-01 03:03:00
# [INFERENCE] batch_id=183 sin alertas
# [INFERENCE] batch_id=184 rows=9
# [INFERENCE] batch_id=184 data_range=2026-02-01 03:04:00 → 2026-02-01 03:04:00
# [INFERENCE] batch_id=184 sin alertas
# [INFERENCE] batch_id=185 rows=9
# [INFERENCE] batch_id=185 data_range=2026-02-01 03:05:00 → 2026-02-01 03:05:00
# [INFERENCE] batch_id=185 sin alertas
# [INFERENCE] batch_id=186 rows=9
# [INFERENCE] batch_id=186 data_range=2026-02-01 03:06:00 → 2026-02-01 03:06:00
# [INFERENCE] batch_id=186 sin alertas
# [INFERENCE] batch_id=187 rows=9
# [INFERENCE] batch_id=187 data_range=2026-02-01 03:07:00 → 2026-02-01 03:07:00
# [INFERENCE] batch_id=187 sin alertas
# [INFERENCE] batch_id=188 rows=9
# [INFERENCE] batch_id=188 data_range=2026-02-01 03:08:00 → 2026-02-01 03:08:00
# [INFERENCE] batch_id=188 sin alertas
# [INFERENCE] batch_id=189 rows=9
# [INFERENCE] batch_id=189 data_range=2026-02-01 03:09:00 → 2026-02-01 03:09:00
# [INFERENCE] batch_id=189 sin alertas
# [INFERENCE] batch_id=190 rows=9
# [INFERENCE] batch_id=190 data_range=2026-02-01 03:10:00 → 2026-02-01 03:10:00
# [INFERENCE] batch_id=190 sin alertas
# [INFERENCE] batch_id=191 rows=9
# [INFERENCE] batch_id=191 data_range=2026-02-01 03:11:00 → 2026-02-01 03:11:00
# [INFERENCE] batch_id=191 sin alertas
# [INFERENCE] batch_id=192 rows=9
# [INFERENCE] batch_id=192 data_range=2026-02-01 03:12:00 → 2026-02-01 03:12:00
# [INFERENCE] batch_id=192 sin alertas
# [INFERENCE] batch_id=193 rows=9
# [INFERENCE] batch_id=193 data_range=2026-02-01 03:13:00 → 2026-02-01 03:13:00
# [INFERENCE] batch_id=193 sin alertas
# [INFERENCE] batch_id=194 rows=9
# [INFERENCE] batch_id=194 data_range=2026-02-01 03:14:00 → 2026-02-01 03:14:00
# [INFERENCE] batch_id=194 sin alertas
# [INFERENCE] batch_id=195 rows=9
# [INFERENCE] batch_id=195 data_range=2026-02-01 03:15:00 → 2026-02-01 03:15:00
# [INFERENCE] batch_id=195 sin alertas
# [INFERENCE] batch_id=196 rows=9
# [INFERENCE] batch_id=196 data_range=2026-02-01 03:16:00 → 2026-02-01 03:16:00
# [INFERENCE] batch_id=196 sin alertas
# [INFERENCE] batch_id=197 rows=9
# [INFERENCE] batch_id=197 data_range=2026-02-01 03:17:00 → 2026-02-01 03:17:00
# [INFERENCE] batch_id=197 sin alertas
# [INFERENCE] batch_id=198 rows=9
# [INFERENCE] batch_id=198 data_range=2026-02-01 03:18:00 → 2026-02-01 03:18:00
# [INFERENCE] batch_id=198 sin alertas
# [INFERENCE] batch_id=199 rows=9
# [INFERENCE] batch_id=199 data_range=2026-02-01 03:19:00 → 2026-02-01 03:19:00
# [INFERENCE] batch_id=199 sin alertas
# [INFERENCE] batch_id=200 rows=9
# [INFERENCE] batch_id=200 data_range=2026-02-01 03:20:00 → 2026-02-01 03:20:00
# [INFERENCE] batch_id=200 sin alertas
# [INFERENCE] batch_id=201 rows=9
# [INFERENCE] batch_id=201 data_range=2026-02-01 03:21:00 → 2026-02-01 03:21:00
# [INFERENCE] batch_id=201 sin alertas
# [INFERENCE] batch_id=202 rows=9
# [INFERENCE] batch_id=202 data_range=2026-02-01 03:22:00 → 2026-02-01 03:22:00
# [INFERENCE] batch_id=202 sin alertas
# [INFERENCE] batch_id=203 rows=9
# [INFERENCE] batch_id=203 data_range=2026-02-01 03:23:00 → 2026-02-01 03:23:00
# [INFERENCE] batch_id=203 sin alertas
# [INFERENCE] batch_id=204 rows=9
# [INFERENCE] batch_id=204 data_range=2026-02-01 03:24:00 → 2026-02-01 03:24:00
# [INFERENCE] batch_id=204 sin alertas
# [INFERENCE] batch_id=205 rows=9
# [INFERENCE] batch_id=205 data_range=2026-02-01 03:25:00 → 2026-02-01 03:25:00
# [INFERENCE] batch_id=205 sin alertas
# [INFERENCE] batch_id=206 rows=9
# [INFERENCE] batch_id=206 data_range=2026-02-01 03:26:00 → 2026-02-01 03:26:00
# [INFERENCE] batch_id=206 sin alertas
# [INFERENCE] batch_id=207 rows=9
# [INFERENCE] batch_id=207 data_range=2026-02-01 03:27:00 → 2026-02-01 03:27:00
# [INFERENCE] batch_id=207 sin alertas
# [INFERENCE] batch_id=208 rows=9
# [INFERENCE] batch_id=208 data_range=2026-02-01 03:28:00 → 2026-02-01 03:28:00
# [INFERENCE] batch_id=208 sin alertas
# [INFERENCE] batch_id=209 rows=9
# [INFERENCE] batch_id=209 data_range=2026-02-01 03:29:00 → 2026-02-01 03:29:00
# [INFERENCE] batch_id=209 sin alertas
# [INFERENCE] batch_id=210 rows=9
# [INFERENCE] batch_id=210 data_range=2026-02-01 03:30:00 → 2026-02-01 03:30:00
# [INFERENCE] batch_id=210 sin alertas
# [INFERENCE] batch_id=211 rows=9
# [INFERENCE] batch_id=211 data_range=2026-02-01 03:31:00 → 2026-02-01 03:31:00
# [INFERENCE] batch_id=211 sin alertas
# [INFERENCE] batch_id=212 rows=9
# [INFERENCE] batch_id=212 data_range=2026-02-01 03:32:00 → 2026-02-01 03:32:00
# [INFERENCE] batch_id=212 sin alertas
# [INFERENCE] batch_id=213 rows=9
# [INFERENCE] batch_id=213 data_range=2026-02-01 03:33:00 → 2026-02-01 03:33:00
# [INFERENCE] batch_id=213 sin alertas
# [INFERENCE] batch_id=214 rows=9
# [INFERENCE] batch_id=214 data_range=2026-02-01 03:34:00 → 2026-02-01 03:34:00
# [INFERENCE] batch_id=214 sin alertas
# [INFERENCE] batch_id=215 rows=9
# [INFERENCE] batch_id=215 data_range=2026-02-01 03:35:00 → 2026-02-01 03:35:00
# [INFERENCE] batch_id=215 sin alertas
# [INFERENCE] batch_id=216 rows=9
# [INFERENCE] batch_id=216 data_range=2026-02-01 03:36:00 → 2026-02-01 03:36:00
# [INFERENCE] batch_id=216 sin alertas
# [INFERENCE] batch_id=217 rows=9
# [INFERENCE] batch_id=217 data_range=2026-02-01 03:37:00 → 2026-02-01 03:37:00
# [INFERENCE] batch_id=217 sin alertas
# [INFERENCE] batch_id=218 rows=9
# [INFERENCE] batch_id=218 data_range=2026-02-01 03:38:00 → 2026-02-01 03:38:00
# [INFERENCE] batch_id=218 sin alertas
# [INFERENCE] batch_id=219 rows=9
# [INFERENCE] batch_id=219 data_range=2026-02-01 03:39:00 → 2026-02-01 03:39:00
# [INFERENCE] batch_id=219 sin alertas
# [INFERENCE] batch_id=220 rows=9
# [INFERENCE] batch_id=220 data_range=2026-02-01 03:40:00 → 2026-02-01 03:40:00
# [INFERENCE] batch_id=220 sin alertas
# [INFERENCE] batch_id=221 rows=9
# [INFERENCE] batch_id=221 data_range=2026-02-01 03:41:00 → 2026-02-01 03:41:00
# [INFERENCE] batch_id=221 sin alertas
# [INFERENCE] batch_id=222 rows=9
# [INFERENCE] batch_id=222 data_range=2026-02-01 03:42:00 → 2026-02-01 03:42:00
# [INFERENCE] batch_id=222 sin alertas
# [INFERENCE] batch_id=223 rows=9
# [INFERENCE] batch_id=223 data_range=2026-02-01 03:43:00 → 2026-02-01 03:43:00
# [INFERENCE] batch_id=223 sin alertas
# [INFERENCE] batch_id=224 rows=9
# [INFERENCE] batch_id=224 data_range=2026-02-01 03:44:00 → 2026-02-01 03:44:00
# [INFERENCE] batch_id=224 sin alertas
# [INFERENCE] batch_id=225 rows=9
# [INFERENCE] batch_id=225 data_range=2026-02-01 03:45:00 → 2026-02-01 03:45:00
# [INFERENCE] batch_id=225 sin alertas
# [INFERENCE] batch_id=226 rows=9
# [INFERENCE] batch_id=226 data_range=2026-02-01 03:46:00 → 2026-02-01 03:46:00
# [INFERENCE] batch_id=226 sin alertas
# [INFERENCE] batch_id=227 rows=9
# [INFERENCE] batch_id=227 data_range=2026-02-01 03:47:00 → 2026-02-01 03:47:00
# [INFERENCE] batch_id=227 sin alertas
# [INFERENCE] batch_id=228 rows=9
# [INFERENCE] batch_id=228 data_range=2026-02-01 03:48:00 → 2026-02-01 03:48:00
# [INFERENCE] batch_id=228 sin alertas
# [INFERENCE] batch_id=229 rows=9
# [INFERENCE] batch_id=229 data_range=2026-02-01 03:49:00 → 2026-02-01 03:49:00
# [INFERENCE] batch_id=229 sin alertas
# [INFERENCE] batch_id=230 rows=9
# [INFERENCE] batch_id=230 data_range=2026-02-01 03:50:00 → 2026-02-01 03:50:00
# [INFERENCE] batch_id=230 sin alertas
# [INFERENCE] batch_id=231 rows=9
# [INFERENCE] batch_id=231 data_range=2026-02-01 03:51:00 → 2026-02-01 03:51:00
# [INFERENCE] batch_id=231 sin alertas
# [INFERENCE] batch_id=232 rows=9
# [INFERENCE] batch_id=232 data_range=2026-02-01 03:52:00 → 2026-02-01 03:52:00
# [INFERENCE] batch_id=232 sin alertas
# [INFERENCE] batch_id=233 rows=9
# [INFERENCE] batch_id=233 data_range=2026-02-01 03:53:00 → 2026-02-01 03:53:00
# [INFERENCE] batch_id=233 sin alertas
# [INFERENCE] batch_id=234 rows=9
# [INFERENCE] batch_id=234 data_range=2026-02-01 03:54:00 → 2026-02-01 03:54:00
# [INFERENCE] batch_id=234 sin alertas
# [INFERENCE] batch_id=235 rows=9
# [INFERENCE] batch_id=235 data_range=2026-02-01 03:55:00 → 2026-02-01 03:55:00
# [INFERENCE] batch_id=235 sin alertas
# [INFERENCE] batch_id=236 rows=9
# [INFERENCE] batch_id=236 data_range=2026-02-01 03:56:00 → 2026-02-01 03:56:00
# [INFERENCE] batch_id=236 sin alertas
# [INFERENCE] batch_id=237 rows=9
# [INFERENCE] batch_id=237 data_range=2026-02-01 03:57:00 → 2026-02-01 03:57:00
# [INFERENCE] batch_id=237 sin alertas
# [INFERENCE] batch_id=238 rows=9
# [INFERENCE] batch_id=238 data_range=2026-02-01 03:58:00 → 2026-02-01 03:58:00
# [INFERENCE] batch_id=238 sin alertas
# [INFERENCE] batch_id=239 rows=9
# [INFERENCE] batch_id=239 data_range=2026-02-01 03:59:00 → 2026-02-01 03:59:00
# [INFERENCE] batch_id=239 sin alertas
# [INFERENCE] batch_id=240 rows=9
# [INFERENCE] batch_id=240 data_range=2026-02-01 04:00:00 → 2026-02-01 04:00:00
# [INFERENCE] batch_id=240 sin alertas
# [INFERENCE] batch_id=241 rows=9
# [INFERENCE] batch_id=241 data_range=2026-02-01 04:01:00 → 2026-02-01 04:01:00
# [INFERENCE] batch_id=241 sin alertas
# [INFERENCE] batch_id=242 rows=9
# [INFERENCE] batch_id=242 data_range=2026-02-01 04:02:00 → 2026-02-01 04:02:00
# [INFERENCE] batch_id=242 sin alertas
# [INFERENCE] batch_id=243 rows=9
# [INFERENCE] batch_id=243 data_range=2026-02-01 04:03:00 → 2026-02-01 04:03:00
# [INFERENCE] batch_id=243 sin alertas
# [INFERENCE] batch_id=244 rows=9
# [INFERENCE] batch_id=244 data_range=2026-02-01 04:04:00 → 2026-02-01 04:04:00
# [INFERENCE] batch_id=244 sin alertas
# [INFERENCE] batch_id=245 rows=9
# [INFERENCE] batch_id=245 data_range=2026-02-01 04:05:00 → 2026-02-01 04:05:00
# [INFERENCE] batch_id=245 sin alertas
# [INFERENCE] batch_id=246 rows=9
# [INFERENCE] batch_id=246 data_range=2026-02-01 04:06:00 → 2026-02-01 04:06:00
# [INFERENCE] batch_id=246 sin alertas
# [INFERENCE] batch_id=247 rows=9
# [INFERENCE] batch_id=247 data_range=2026-02-01 04:07:00 → 2026-02-01 04:07:00
# [INFERENCE] batch_id=247 sin alertas
# [INFERENCE] batch_id=248 rows=9
# [INFERENCE] batch_id=248 data_range=2026-02-01 04:08:00 → 2026-02-01 04:08:00
# [INFERENCE] batch_id=248 sin alertas
# [INFERENCE] batch_id=249 rows=9
# [INFERENCE] batch_id=249 data_range=2026-02-01 04:09:00 → 2026-02-01 04:09:00
# [INFERENCE] batch_id=249 sin alertas
# [INFERENCE] batch_id=250 rows=9
# [INFERENCE] batch_id=250 data_range=2026-02-01 04:10:00 → 2026-02-01 04:10:00
# [INFERENCE] batch_id=250 sin alertas
# [INFERENCE] batch_id=251 rows=9
# [INFERENCE] batch_id=251 data_range=2026-02-01 04:11:00 → 2026-02-01 04:11:00
# [INFERENCE] batch_id=251 sin alertas
# [INFERENCE] batch_id=252 rows=9
# [INFERENCE] batch_id=252 data_range=2026-02-01 04:12:00 → 2026-02-01 04:12:00
# [INFERENCE] batch_id=252 sin alertas
# [INFERENCE] batch_id=253 rows=9
# [INFERENCE] batch_id=253 data_range=2026-02-01 04:13:00 → 2026-02-01 04:13:00
# [INFERENCE] batch_id=253 sin alertas
# [INFERENCE] batch_id=254 rows=9
# [INFERENCE] batch_id=254 data_range=2026-02-01 04:14:00 → 2026-02-01 04:14:00
# [INFERENCE] batch_id=254 sin alertas
# [INFERENCE] batch_id=255 rows=9
# [INFERENCE] batch_id=255 data_range=2026-02-01 04:15:00 → 2026-02-01 04:15:00
# [INFERENCE] batch_id=255 sin alertas
# [INFERENCE] batch_id=256 rows=9
# [INFERENCE] batch_id=256 data_range=2026-02-01 04:16:00 → 2026-02-01 04:16:00
# [INFERENCE] batch_id=256 sin alertas
# [INFERENCE] batch_id=257 rows=9
# [INFERENCE] batch_id=257 data_range=2026-02-01 04:17:00 → 2026-02-01 04:17:00
# [INFERENCE] batch_id=257 sin alertas
# [INFERENCE] batch_id=258 rows=9
# [INFERENCE] batch_id=258 data_range=2026-02-01 04:18:00 → 2026-02-01 04:18:00
# [INFERENCE] batch_id=258 sin alertas
# [INFERENCE] batch_id=259 rows=9
# [INFERENCE] batch_id=259 data_range=2026-02-01 04:19:00 → 2026-02-01 04:19:00
# [INFERENCE] batch_id=259 sin alertas
# [INFERENCE] batch_id=260 rows=9
# [INFERENCE] batch_id=260 data_range=2026-02-01 04:20:00 → 2026-02-01 04:20:00
# [INFERENCE] batch_id=260 sin alertas
# [INFERENCE] batch_id=261 rows=9
# [INFERENCE] batch_id=261 data_range=2026-02-01 04:21:00 → 2026-02-01 04:21:00
# [INFERENCE] batch_id=261 sin alertas
# [INFERENCE] batch_id=262 rows=9
# [INFERENCE] batch_id=262 data_range=2026-02-01 04:22:00 → 2026-02-01 04:22:00
# [INFERENCE] batch_id=262 sin alertas
# [INFERENCE] batch_id=263 rows=9
# [INFERENCE] batch_id=263 data_range=2026-02-01 04:23:00 → 2026-02-01 04:23:00
# [INFERENCE] batch_id=263 sin alertas
# [INFERENCE] batch_id=264 rows=9
# [INFERENCE] batch_id=264 data_range=2026-02-01 04:24:00 → 2026-02-01 04:24:00
# [INFERENCE] batch_id=264 sin alertas
# [INFERENCE] batch_id=265 rows=9
# [INFERENCE] batch_id=265 data_range=2026-02-01 04:25:00 → 2026-02-01 04:25:00
# [INFERENCE] batch_id=265 sin alertas
# [INFERENCE] batch_id=266 rows=9
# [INFERENCE] batch_id=266 data_range=2026-02-01 04:26:00 → 2026-02-01 04:26:00
# [INFERENCE] batch_id=266 sin alertas
# [INFERENCE] batch_id=267 rows=9
# [INFERENCE] batch_id=267 data_range=2026-02-01 04:27:00 → 2026-02-01 04:27:00
# [INFERENCE] batch_id=267 sin alertas
# [INFERENCE] batch_id=268 rows=9
# [INFERENCE] batch_id=268 data_range=2026-02-01 04:28:00 → 2026-02-01 04:28:00
# [INFERENCE] batch_id=268 sin alertas
# [INFERENCE] batch_id=269 rows=9
# [INFERENCE] batch_id=269 data_range=2026-02-01 04:29:00 → 2026-02-01 04:29:00
# [INFERENCE] batch_id=269 sin alertas
# [INFERENCE] batch_id=270 rows=9
# [INFERENCE] batch_id=270 data_range=2026-02-01 04:30:00 → 2026-02-01 04:30:00
# [INFERENCE] batch_id=270 sin alertas
# [INFERENCE] batch_id=271 rows=9
# [INFERENCE] batch_id=271 data_range=2026-02-01 04:31:00 → 2026-02-01 04:31:00
# [INFERENCE] batch_id=271 sin alertas
# [INFERENCE] batch_id=272 rows=9
# [INFERENCE] batch_id=272 data_range=2026-02-01 04:32:00 → 2026-02-01 04:32:00
# [INFERENCE] batch_id=272 sin alertas
# [INFERENCE] batch_id=273 rows=9
# [INFERENCE] batch_id=273 data_range=2026-02-01 04:33:00 → 2026-02-01 04:33:00
# [INFERENCE] batch_id=273 sin alertas
# [INFERENCE] batch_id=274 rows=9
# [INFERENCE] batch_id=274 data_range=2026-02-01 04:34:00 → 2026-02-01 04:34:00
# [INFERENCE] batch_id=274 sin alertas
# [INFERENCE] batch_id=275 rows=9
# [INFERENCE] batch_id=275 data_range=2026-02-01 04:35:00 → 2026-02-01 04:35:00
# [INFERENCE] batch_id=275 sin alertas
# [INFERENCE] batch_id=276 rows=9
# [INFERENCE] batch_id=276 data_range=2026-02-01 04:36:00 → 2026-02-01 04:36:00
# [INFERENCE] batch_id=276 sin alertas
# [INFERENCE] batch_id=277 rows=9
# [INFERENCE] batch_id=277 data_range=2026-02-01 04:37:00 → 2026-02-01 04:37:00
# [INFERENCE] batch_id=277 sin alertas
# [INFERENCE] batch_id=278 rows=9
# [INFERENCE] batch_id=278 data_range=2026-02-01 04:38:00 → 2026-02-01 04:38:00
# [INFERENCE] batch_id=278 sin alertas
# [INFERENCE] batch_id=279 rows=9
# [INFERENCE] batch_id=279 data_range=2026-02-01 04:39:00 → 2026-02-01 04:39:00
# [INFERENCE] batch_id=279 sin alertas
# [INFERENCE] batch_id=280 rows=9
# [INFERENCE] batch_id=280 data_range=2026-02-01 04:40:00 → 2026-02-01 04:40:00
# [INFERENCE] batch_id=280 sin alertas
# [INFERENCE] batch_id=281 rows=9
# [INFERENCE] batch_id=281 data_range=2026-02-01 04:41:00 → 2026-02-01 04:41:00
# [INFERENCE] batch_id=281 sin alertas
# [INFERENCE] batch_id=282 rows=9
# [INFERENCE] batch_id=282 data_range=2026-02-01 04:42:00 → 2026-02-01 04:42:00
# [INFERENCE] batch_id=282 sin alertas
# [INFERENCE] batch_id=283 rows=9
# [INFERENCE] batch_id=283 data_range=2026-02-01 04:43:00 → 2026-02-01 04:43:00
# [INFERENCE] batch_id=283 sin alertas
# [INFERENCE] batch_id=284 rows=9
# [INFERENCE] batch_id=284 data_range=2026-02-01 04:44:00 → 2026-02-01 04:44:00
# [INFERENCE] batch_id=284 sin alertas
# [INFERENCE] batch_id=285 rows=9
# [INFERENCE] batch_id=285 data_range=2026-02-01 04:45:00 → 2026-02-01 04:45:00
# [INFERENCE] batch_id=285 sin alertas
# [INFERENCE] batch_id=286 rows=9
# [INFERENCE] batch_id=286 data_range=2026-02-01 04:46:00 → 2026-02-01 04:46:00
# [INFERENCE] batch_id=286 sin alertas
# [INFERENCE] batch_id=287 rows=9
# [INFERENCE] batch_id=287 data_range=2026-02-01 04:47:00 → 2026-02-01 04:47:00
# [INFERENCE] batch_id=287 sin alertas
# [INFERENCE] batch_id=288 rows=9
# [INFERENCE] batch_id=288 data_range=2026-02-01 04:48:00 → 2026-02-01 04:48:00
# [INFERENCE] batch_id=288 sin alertas
# [INFERENCE] batch_id=289 rows=9
# [INFERENCE] batch_id=289 data_range=2026-02-01 04:49:00 → 2026-02-01 04:49:00
# [INFERENCE] batch_id=289 sin alertas
# [INFERENCE] batch_id=290 rows=9
# [INFERENCE] batch_id=290 data_range=2026-02-01 04:50:00 → 2026-02-01 04:50:00
# [INFERENCE] batch_id=290 sin alertas
# [INFERENCE] batch_id=291 rows=9
# [INFERENCE] batch_id=291 data_range=2026-02-01 04:51:00 → 2026-02-01 04:51:00
# [INFERENCE] batch_id=291 sin alertas
# [INFERENCE] batch_id=292 rows=9
# [INFERENCE] batch_id=292 data_range=2026-02-01 04:52:00 → 2026-02-01 04:52:00
# [INFERENCE] batch_id=292 sin alertas
# [INFERENCE] batch_id=293 rows=9
# [INFERENCE] batch_id=293 data_range=2026-02-01 04:53:00 → 2026-02-01 04:53:00
# [INFERENCE] batch_id=293 sin alertas
# [INFERENCE] batch_id=294 rows=9
# [INFERENCE] batch_id=294 data_range=2026-02-01 04:54:00 → 2026-02-01 04:54:00
# [INFERENCE] batch_id=294 sin alertas
# [INFERENCE] batch_id=295 rows=9
# [INFERENCE] batch_id=295 data_range=2026-02-01 04:55:00 → 2026-02-01 04:55:00
# [INFERENCE] batch_id=295 sin alertas
# [INFERENCE] batch_id=296 rows=9
# [INFERENCE] batch_id=296 data_range=2026-02-01 04:56:00 → 2026-02-01 04:56:00
# [INFERENCE] batch_id=296 sin alertas
# [INFERENCE] batch_id=297 rows=9
# [INFERENCE] batch_id=297 data_range=2026-02-01 04:57:00 → 2026-02-01 04:57:00
# [INFERENCE] batch_id=297 sin alertas
# [INFERENCE] batch_id=298 rows=9
# [INFERENCE] batch_id=298 data_range=2026-02-01 04:58:00 → 2026-02-01 04:58:00
# [INFERENCE] batch_id=298 sin alertas
# [INFERENCE] batch_id=299 rows=9
# [INFERENCE] batch_id=299 data_range=2026-02-01 04:59:00 → 2026-02-01 04:59:00
# [INFERENCE] batch_id=299 sin alertas
# [INFERENCE] batch_id=300 rows=9
# [INFERENCE] batch_id=300 data_range=2026-02-01 05:00:00 → 2026-02-01 05:00:00
# [INFERENCE] batch_id=300 sin alertas
# [INFERENCE] batch_id=301 rows=9
# [INFERENCE] batch_id=301 data_range=2026-02-01 05:01:00 → 2026-02-01 05:01:00
# [INFERENCE] batch_id=301 sin alertas
# [INFERENCE] batch_id=302 rows=9
# [INFERENCE] batch_id=302 data_range=2026-02-01 05:02:00 → 2026-02-01 05:02:00
# [INFERENCE] batch_id=302 sin alertas
# [INFERENCE] batch_id=303 rows=9
# [INFERENCE] batch_id=303 data_range=2026-02-01 05:03:00 → 2026-02-01 05:03:00
# [INFERENCE] batch_id=303 sin alertas
# [INFERENCE] batch_id=304 rows=9
# [INFERENCE] batch_id=304 data_range=2026-02-01 05:04:00 → 2026-02-01 05:04:00
# [INFERENCE] batch_id=304 sin alertas
# [INFERENCE] batch_id=305 rows=9
# [INFERENCE] batch_id=305 data_range=2026-02-01 05:05:00 → 2026-02-01 05:05:00
# [INFERENCE] batch_id=305 sin alertas
# [INFERENCE] batch_id=306 rows=9
# [INFERENCE] batch_id=306 data_range=2026-02-01 05:06:00 → 2026-02-01 05:06:00
# [INFERENCE] batch_id=306 sin alertas
# [INFERENCE] batch_id=307 rows=9
# [INFERENCE] batch_id=307 data_range=2026-02-01 05:07:00 → 2026-02-01 05:07:00
# [INFERENCE] batch_id=307 sin alertas
# [INFERENCE] batch_id=308 rows=9
# [INFERENCE] batch_id=308 data_range=2026-02-01 05:08:00 → 2026-02-01 05:08:00
# [INFERENCE] batch_id=308 sin alertas
# [INFERENCE] batch_id=309 rows=9
# [INFERENCE] batch_id=309 data_range=2026-02-01 05:09:00 → 2026-02-01 05:09:00
# [INFERENCE] batch_id=309 sin alertas
# [INFERENCE] batch_id=310 rows=9
# [INFERENCE] batch_id=310 data_range=2026-02-01 05:10:00 → 2026-02-01 05:10:00
# [INFERENCE] batch_id=310 sin alertas
# [INFERENCE] batch_id=311 rows=9
# [INFERENCE] batch_id=311 data_range=2026-02-01 05:11:00 → 2026-02-01 05:11:00
# [INFERENCE] batch_id=311 sin alertas
# [INFERENCE] batch_id=312 rows=9
# [INFERENCE] batch_id=312 data_range=2026-02-01 05:12:00 → 2026-02-01 05:12:00
# [INFERENCE] batch_id=312 sin alertas
# [INFERENCE] batch_id=313 rows=9
# [INFERENCE] batch_id=313 data_range=2026-02-01 05:13:00 → 2026-02-01 05:13:00
# [INFERENCE] batch_id=313 sin alertas
# [INFERENCE] batch_id=314 rows=9
# [INFERENCE] batch_id=314 data_range=2026-02-01 05:14:00 → 2026-02-01 05:14:00
# [INFERENCE] batch_id=314 sin alertas
# [INFERENCE] batch_id=315 rows=9
# [INFERENCE] batch_id=315 data_range=2026-02-01 05:15:00 → 2026-02-01 05:15:00
# [INFERENCE] batch_id=315 sin alertas
# [INFERENCE] batch_id=316 rows=9
# [INFERENCE] batch_id=316 data_range=2026-02-01 05:16:00 → 2026-02-01 05:16:00
# [INFERENCE] batch_id=316 sin alertas
# [INFERENCE] batch_id=317 rows=9
# [INFERENCE] batch_id=317 data_range=2026-02-01 05:17:00 → 2026-02-01 05:17:00
# [INFERENCE] batch_id=317 sin alertas
# [INFERENCE] batch_id=318 rows=9
# [INFERENCE] batch_id=318 data_range=2026-02-01 05:18:00 → 2026-02-01 05:18:00
# [INFERENCE] batch_id=318 sin alertas
# [INFERENCE] batch_id=319 rows=9
# [INFERENCE] batch_id=319 data_range=2026-02-01 05:19:00 → 2026-02-01 05:19:00
# [INFERENCE] batch_id=319 sin alertas
# [INFERENCE] batch_id=320 rows=9
# [INFERENCE] batch_id=320 data_range=2026-02-01 05:20:00 → 2026-02-01 05:20:00
# [INFERENCE] batch_id=320 sin alertas
# [INFERENCE] batch_id=321 rows=9
# [INFERENCE] batch_id=321 data_range=2026-02-01 05:21:00 → 2026-02-01 05:21:00
# [INFERENCE] batch_id=321 sin alertas
# [INFERENCE] batch_id=322 rows=9
# [INFERENCE] batch_id=322 data_range=2026-02-01 05:22:00 → 2026-02-01 05:22:00
# [INFERENCE] batch_id=322 sin alertas
# [INFERENCE] batch_id=323 rows=9
# [INFERENCE] batch_id=323 data_range=2026-02-01 05:23:00 → 2026-02-01 05:23:00
# [INFERENCE] batch_id=323 sin alertas
# [INFERENCE] batch_id=324 rows=9
# [INFERENCE] batch_id=324 data_range=2026-02-01 05:24:00 → 2026-02-01 05:24:00
# [INFERENCE] batch_id=324 sin alertas
# [INFERENCE] batch_id=325 rows=9
# [INFERENCE] batch_id=325 data_range=2026-02-01 05:25:00 → 2026-02-01 05:25:00
# [INFERENCE] batch_id=325 sin alertas
# [INFERENCE] batch_id=326 rows=9
# [INFERENCE] batch_id=326 data_range=2026-02-01 05:26:00 → 2026-02-01 05:26:00
# [INFERENCE] batch_id=326 sin alertas
# [INFERENCE] batch_id=327 rows=9
# [INFERENCE] batch_id=327 data_range=2026-02-01 05:27:00 → 2026-02-01 05:27:00
# [INFERENCE] batch_id=327 sin alertas
# [INFERENCE] batch_id=328 rows=9
# [INFERENCE] batch_id=328 data_range=2026-02-01 05:28:00 → 2026-02-01 05:28:00
# ...
# [INFERENCE] batch_id=21361 vacío
# [INFERENCE] batch_id=21362 rows=0
# [INFERENCE] batch_id=21362 vacío
# [INFERENCE] batch_id=21363 rows=0
# [INFERENCE] batch_id=21363 vacío
# [INFERENCE] batch_id=21364 rows=0
# [INFERENCE] batch_id=21364 vacío
# [INFERENCE] batch_id=21365 rows=0
# [INFERENCE] batch_id=21365 vacío
# [INFERENCE] batch_id=21366 rows=0
# [INFERENCE] batch_id=21366 vacío
# [INFERENCE] batch_id=21367 rows=0
# [INFERENCE] batch_id=21367 vacío
# [INFERENCE] batch_id=21368 rows=0
# [INFERENCE] batch_id=21368 vacío
# [INFERENCE] batch_id=21369 rows=0
# [INFERENCE] batch_id=21369 vacío
# [INFERENCE] batch_id=21370 rows=0
# [INFERENCE] batch_id=21370 vacío
# [INFERENCE] batch_id=21371 rows=0
# [INFERENCE] batch_id=21371 vacío
# [INFERENCE] batch_id=21372 rows=0
# [INFERENCE] batch_id=21372 vacío
# [INFERENCE] batch_id=21373 rows=0
# [INFERENCE] batch_id=21373 vacío
# [INFERENCE] batch_id=21374 rows=0
# [INFERENCE] batch_id=21374 vacío
# [INFERENCE] batch_id=21375 rows=0
# [INFERENCE] batch_id=21375 vacío
# [INFERENCE] batch_id=21376 rows=0
# [INFERENCE] batch_id=21376 vacío
# [INFERENCE] batch_id=21377 rows=0
# [INFERENCE] batch_id=21377 vacío
# [INFERENCE] batch_id=21378 rows=0
# [INFERENCE] batch_id=21378 vacío
# [INFERENCE] batch_id=21379 rows=0
# [INFERENCE] batch_id=21379 vacío
# [INFERENCE] batch_id=21380 rows=0
# [INFERENCE] batch_id=21380 vacío
# [INFERENCE] batch_id=21381 rows=0
# [INFERENCE] batch_id=21381 vacío
# [INFERENCE] batch_id=21382 rows=0
# [INFERENCE] batch_id=21382 vacío
# [INFERENCE] batch_id=21383 rows=0
# [INFERENCE] batch_id=21383 vacío
# [INFERENCE] batch_id=21384 rows=0
# [INFERENCE] batch_id=21384 vacío
# [INFERENCE] batch_id=21385 rows=0
# [INFERENCE] batch_id=21385 vacío
# [INFERENCE] batch_id=21386 rows=0
# [INFERENCE] batch_id=21386 vacío
# [INFERENCE] batch_id=21387 rows=0
# [INFERENCE] batch_id=21387 vacío
# [INFERENCE] batch_id=21388 rows=0
# [INFERENCE] batch_id=21388 vacío
# [INFERENCE] batch_id=21389 rows=0
# [INFERENCE] batch_id=21389 vacío
# [INFERENCE] batch_id=21390 rows=0
# [INFERENCE] batch_id=21390 vacío
# [INFERENCE] batch_id=21391 rows=0
# [INFERENCE] batch_id=21391 vacío
# [INFERENCE] batch_id=21392 rows=0
# [INFERENCE] batch_id=21392 vacío
# [INFERENCE] batch_id=21393 rows=0
# [INFERENCE] batch_id=21393 vacío
# [INFERENCE] batch_id=21394 rows=0
# [INFERENCE] batch_id=21394 vacío
# [INFERENCE] batch_id=21395 rows=0
# [INFERENCE] batch_id=21395 vacío
# [INFERENCE] batch_id=21396 rows=0
# [INFERENCE] batch_id=21396 vacío
# [INFERENCE] batch_id=21397 rows=0
# [INFERENCE] batch_id=21397 vacío
# [INFERENCE] batch_id=21398 rows=0
# [INFERENCE] batch_id=21398 vacío
# [INFERENCE] batch_id=21399 rows=0
# [INFERENCE] batch_id=21399 vacío
# [INFERENCE] batch_id=21400 rows=0
# [INFERENCE] batch_id=21400 vacío
# [INFERENCE] batch_id=21401 rows=0
# [INFERENCE] batch_id=21401 vacío
# [INFERENCE] batch_id=21402 rows=0
# [INFERENCE] batch_id=21402 vacío
# [INFERENCE] batch_id=21403 rows=0
# [INFERENCE] batch_id=21403 vacío
# [INFERENCE] batch_id=21404 rows=0
# [INFERENCE] batch_id=21404 vacío
# [INFERENCE] batch_id=21405 rows=0
# [INFERENCE] batch_id=21405 vacío
# [INFERENCE] batch_id=21406 rows=0
# [INFERENCE] batch_id=21406 vacío
# [INFERENCE] batch_id=21407 rows=0
# [INFERENCE] batch_id=21407 vacío
# [INFERENCE] batch_id=21408 rows=0
# [INFERENCE] batch_id=21408 vacío
# [INFERENCE] batch_id=21409 rows=0
# [INFERENCE] batch_id=21409 vacío
# [INFERENCE] batch_id=21410 rows=0
# [INFERENCE] batch_id=21410 vacío
# [INFERENCE] batch_id=21411 rows=0
# [INFERENCE] batch_id=21411 vacío
# [INFERENCE] batch_id=21412 rows=0
# [INFERENCE] batch_id=21412 vacío
# [INFERENCE] batch_id=21413 rows=0
# [INFERENCE] batch_id=21413 vacío
# [INFERENCE] batch_id=21414 rows=0
# [INFERENCE] batch_id=21414 vacío
# [INFERENCE] batch_id=21415 rows=0
# [INFERENCE] batch_id=21415 vacío
# [INFERENCE] batch_id=21416 rows=0
# [INFERENCE] batch_id=21416 vacío
# [INFERENCE] batch_id=21417 rows=0
# [INFERENCE] batch_id=21417 vacío
# [INFERENCE] batch_id=21418 rows=0
# [INFERENCE] batch_id=21418 vacío
# [INFERENCE] batch_id=21419 rows=0
# [INFERENCE] batch_id=21419 vacío
# [INFERENCE] batch_id=21420 rows=0
# [INFERENCE] batch_id=21420 vacío
# [INFERENCE] batch_id=21421 rows=0
# [INFERENCE] batch_id=21421 vacío
# [INFERENCE] batch_id=21422 rows=0
# [INFERENCE] batch_id=21422 vacío
# [INFERENCE] batch_id=21423 rows=0
# [INFERENCE] batch_id=21423 vacío
# [INFERENCE] batch_id=21424 rows=0
# [INFERENCE] batch_id=21424 vacío
# [INFERENCE] batch_id=21425 rows=0
# [INFERENCE] batch_id=21425 vacío
# [INFERENCE] batch_id=21426 rows=0
# [INFERENCE] batch_id=21426 vacío
# [INFERENCE] batch_id=21427 rows=0
# [INFERENCE] batch_id=21427 vacío
# [INFERENCE] batch_id=21428 rows=0
# [INFERENCE] batch_id=21428 vacío
# [INFERENCE] batch_id=21429 rows=0
# [INFERENCE] batch_id=21429 vacío
# [INFERENCE] batch_id=21430 rows=0
# [INFERENCE] batch_id=21430 vacío
# [INFERENCE] batch_id=21431 rows=0
# [INFERENCE] batch_id=21431 vacío
# [INFERENCE] batch_id=21432 rows=0
# [INFERENCE] batch_id=21432 vacío
# [INFERENCE] batch_id=21433 rows=0
# [INFERENCE] batch_id=21433 vacío
# [INFERENCE] batch_id=21434 rows=0
# [INFERENCE] batch_id=21434 vacío
# [INFERENCE] batch_id=21435 rows=0
# [INFERENCE] batch_id=21435 vacío
# [INFERENCE] batch_id=21436 rows=0
# [INFERENCE] batch_id=21436 vacío
# [INFERENCE] batch_id=21437 rows=0
# [INFERENCE] batch_id=21437 vacío
# [INFERENCE] batch_id=21438 rows=0
# [INFERENCE] batch_id=21438 vacío
# [INFERENCE] batch_id=21439 rows=0
# [INFERENCE] batch_id=21439 vacío
# [INFERENCE] batch_id=21440 rows=0
# [INFERENCE] batch_id=21440 vacío
# [INFERENCE] batch_id=21441 rows=0
# [INFERENCE] batch_id=21441 vacío
# [INFERENCE] batch_id=21442 rows=0
# [INFERENCE] batch_id=21442 vacío
# [INFERENCE] batch_id=21443 rows=0
# [INFERENCE] batch_id=21443 vacío
# [INFERENCE] batch_id=21444 rows=0
# [INFERENCE] batch_id=21444 vacío
# [INFERENCE] batch_id=21445 rows=0
# [INFERENCE] batch_id=21445 vacío
# [INFERENCE] batch_id=21446 rows=0
# [INFERENCE] batch_id=21446 vacío
# [INFERENCE] batch_id=21447 rows=0
# [INFERENCE] batch_id=21447 vacío
# [INFERENCE] batch_id=21448 rows=0
# [INFERENCE] batch_id=21448 vacío
# [INFERENCE] batch_id=21449 rows=0
# [INFERENCE] batch_id=21449 vacío
# [INFERENCE] batch_id=21450 rows=0
# [INFERENCE] batch_id=21450 vacío
# [INFERENCE] batch_id=21451 rows=0
# [INFERENCE] batch_id=21451 vacío
# [INFERENCE] batch_id=21452 rows=0
# [INFERENCE] batch_id=21452 vacío
# [INFERENCE] batch_id=21453 rows=0
# [INFERENCE] batch_id=21453 vacío
# [INFERENCE] batch_id=21454 rows=0
# [INFERENCE] batch_id=21454 vacío
# [INFERENCE] batch_id=21455 rows=0
# [INFERENCE] batch_id=21455 vacío
# [INFERENCE] batch_id=21456 rows=0
# [INFERENCE] batch_id=21456 vacío
# [INFERENCE] batch_id=21457 rows=0
# [INFERENCE] batch_id=21457 vacío
# [INFERENCE] batch_id=21458 rows=0
# [INFERENCE] batch_id=21458 vacío
# [INFERENCE] batch_id=21459 rows=0
# [INFERENCE] batch_id=21459 vacío
# [INFERENCE] batch_id=21460 rows=0
# [INFERENCE] batch_id=21460 vacío
# [INFERENCE] batch_id=21461 rows=0
# [INFERENCE] batch_id=21461 vacío
# [INFERENCE] batch_id=21462 rows=0
# [INFERENCE] batch_id=21462 vacío
# [INFERENCE] batch_id=21463 rows=0
# [INFERENCE] batch_id=21463 vacío
# [INFERENCE] batch_id=21464 rows=0
# [INFERENCE] batch_id=21464 vacío
# [INFERENCE] batch_id=21465 rows=0
# [INFERENCE] batch_id=21465 vacío
# [INFERENCE] batch_id=21466 rows=0
# [INFERENCE] batch_id=21466 vacío
# [INFERENCE] batch_id=21467 rows=0
# [INFERENCE] batch_id=21467 vacío
# [INFERENCE] batch_id=21468 rows=0
# [INFERENCE] batch_id=21468 vacío
# [INFERENCE] batch_id=21469 rows=0
# [INFERENCE] batch_id=21469 vacío
# [INFERENCE] batch_id=21470 rows=0
# [INFERENCE] batch_id=21470 vacío
# [INFERENCE] batch_id=21471 rows=0
# [INFERENCE] batch_id=21471 vacío
# [INFERENCE] batch_id=21472 rows=0
# [INFERENCE] batch_id=21472 vacío
# [INFERENCE] batch_id=21473 rows=0
# [INFERENCE] batch_id=21473 vacío
# [INFERENCE] batch_id=21474 rows=0
# [INFERENCE] batch_id=21474 vacío
# [INFERENCE] batch_id=21475 rows=0
# [INFERENCE] batch_id=21475 vacío
# [INFERENCE] batch_id=21476 rows=0
# [INFERENCE] batch_id=21476 vacío
# [INFERENCE] batch_id=21477 rows=0
# [INFERENCE] batch_id=21477 vacío
# [INFERENCE] batch_id=21478 rows=0
# [INFERENCE] batch_id=21478 vacío
# [INFERENCE] batch_id=21479 rows=0
# [INFERENCE] batch_id=21479 vacío
# [INFERENCE] batch_id=21480 rows=0
# [INFERENCE] batch_id=21480 vacío
# [INFERENCE] batch_id=21481 rows=0
# [INFERENCE] batch_id=21481 vacío
# [INFERENCE] batch_id=21482 rows=0
# [INFERENCE] batch_id=21482 vacío
# [INFERENCE] batch_id=21483 rows=0
# [INFERENCE] batch_id=21483 vacío
# [INFERENCE] batch_id=21484 rows=0
# [INFERENCE] batch_id=21484 vacío
# [INFERENCE] batch_id=21485 rows=0
# [INFERENCE] batch_id=21485 vacío
# [INFERENCE] batch_id=21486 rows=0
# [INFERENCE] batch_id=21486 vacío
# [INFERENCE] batch_id=21487 rows=0
# [INFERENCE] batch_id=21487 vacío
# [INFERENCE] batch_id=21488 rows=0
# [INFERENCE] batch_id=21488 vacío
# [INFERENCE] batch_id=21489 rows=0
# [INFERENCE] batch_id=21489 vacío
# [INFERENCE] batch_id=21490 rows=0
# [INFERENCE] batch_id=21490 vacío
# [INFERENCE] batch_id=21491 rows=0
# [INFERENCE] batch_id=21491 vacío
# [INFERENCE] batch_id=21492 rows=0
# [INFERENCE] batch_id=21492 vacío
# [INFERENCE] batch_id=21493 rows=0
# [INFERENCE] batch_id=21493 vacío
# [INFERENCE] batch_id=21494 rows=0
# [INFERENCE] batch_id=21494 vacío
# [INFERENCE] batch_id=21495 rows=0
# [INFERENCE] batch_id=21495 vacío
# [INFERENCE] batch_id=21496 rows=0
# [INFERENCE] batch_id=21496 vacío
# [INFERENCE] batch_id=21497 rows=0
# [INFERENCE] batch_id=21497 vacío
# [INFERENCE] batch_id=21498 rows=0
# [INFERENCE] batch_id=21498 vacío
# [INFERENCE] batch_id=21499 rows=0
# [INFERENCE] batch_id=21499 vacío
# [INFERENCE] batch_id=21500 rows=0
# [INFERENCE] batch_id=21500 vacío
# [INFERENCE] batch_id=21501 rows=0
# [INFERENCE] batch_id=21501 vacío
# [INFERENCE] batch_id=21502 rows=0
# [INFERENCE] batch_id=21502 vacío
# [INFERENCE] batch_id=21503 rows=0
# [INFERENCE] batch_id=21503 vacío
# [INFERENCE] batch_id=21504 rows=0
# [INFERENCE] batch_id=21504 vacío
# [INFERENCE] batch_id=21505 rows=0
# [INFERENCE] batch_id=21505 vacío
# [INFERENCE] batch_id=21506 rows=0
# [INFERENCE] batch_id=21506 vacío
# [INFERENCE] batch_id=21507 rows=0
# [INFERENCE] batch_id=21507 vacío
# [INFERENCE] batch_id=21508 rows=0
# [INFERENCE] batch_id=21508 vacío
# [INFERENCE] batch_id=21509 rows=0
# [INFERENCE] batch_id=21509 vacío
# [INFERENCE] batch_id=21510 rows=0
# [INFERENCE] batch_id=21510 vacío
# [INFERENCE] batch_id=21511 rows=0
# [INFERENCE] batch_id=21511 vacío
# [INFERENCE] batch_id=21512 rows=0
# [INFERENCE] batch_id=21512 vacío
# [INFERENCE] batch_id=21513 rows=0
# [INFERENCE] batch_id=21513 vacío
# [INFERENCE] batch_id=21514 rows=0
# [INFERENCE] batch_id=21514 vacío
# [INFERENCE] batch_id=21515 rows=0
# [INFERENCE] batch_id=21515 vacío
# [INFERENCE] batch_id=21516 rows=0
# [INFERENCE] batch_id=21516 vacío
# [INFERENCE] batch_id=21517 rows=0
# [INFERENCE] batch_id=21517 vacío
# [INFERENCE] batch_id=21518 rows=0
# [INFERENCE] batch_id=21518 vacío
# [INFERENCE] batch_id=21519 rows=0
# [INFERENCE] batch_id=21519 vacío
# [INFERENCE] batch_id=21520 rows=0
# [INFERENCE] batch_id=21520 vacío
# [INFERENCE] batch_id=21521 rows=0
# [INFERENCE] batch_id=21521 vacío
# [INFERENCE] batch_id=21522 rows=0
# [INFERENCE] batch_id=21522 vacío
# [INFERENCE] batch_id=21523 rows=0
# [INFERENCE] batch_id=21523 vacío
# [INFERENCE] batch_id=21524 rows=0
# [INFERENCE] batch_id=21524 vacío
# [INFERENCE] batch_id=21525 rows=0
# [INFERENCE] batch_id=21525 vacío
# [INFERENCE] batch_id=21526 rows=0
# [INFERENCE] batch_id=21526 vacío
# [INFERENCE] batch_id=21527 rows=0
# [INFERENCE] batch_id=21527 vacío
# [INFERENCE] batch_id=21528 rows=0
# [INFERENCE] batch_id=21528 vacío
# [INFERENCE] batch_id=21529 rows=0
# [INFERENCE] batch_id=21529 vacío
# [INFERENCE] batch_id=21530 rows=0
# [INFERENCE] batch_id=21530 vacío
# [INFERENCE] batch_id=21531 rows=0
# [INFERENCE] batch_id=21531 vacío
# [INFERENCE] batch_id=21532 rows=0
# [INFERENCE] batch_id=21532 vacío
# [INFERENCE] batch_id=21533 rows=0
# [INFERENCE] batch_id=21533 vacío
# [INFERENCE] batch_id=21534 rows=0
# [INFERENCE] batch_id=21534 vacío
# [INFERENCE] batch_id=21535 rows=0
# [INFERENCE] batch_id=21535 vacío
# [INFERENCE] batch_id=21536 rows=0
# [INFERENCE] batch_id=21536 vacío
# [INFERENCE] batch_id=21537 rows=0
# [INFERENCE] batch_id=21537 vacío
# [INFERENCE] batch_id=21538 rows=0
# [INFERENCE] batch_id=21538 vacío
# [INFERENCE] batch_id=21539 rows=0
# [INFERENCE] batch_id=21539 vacío
# [INFERENCE] batch_id=21540 rows=0
# [INFERENCE] batch_id=21540 vacío
# [INFERENCE] batch_id=21541 rows=0
# [INFERENCE] batch_id=21541 vacío
# [INFERENCE] batch_id=21542 rows=0
# [INFERENCE] batch_id=21542 vacío
# [INFERENCE] batch_id=21543 rows=0
# [INFERENCE] batch_id=21543 vacío
# [INFERENCE] batch_id=21544 rows=0
# [INFERENCE] batch_id=21544 vacío
# [INFERENCE] batch_id=21545 rows=0
# [INFERENCE] batch_id=21545 vacío
# [INFERENCE] batch_id=21546 rows=0
# [INFERENCE] batch_id=21546 vacío
# [INFERENCE] batch_id=21547 rows=0
# [INFERENCE] batch_id=21547 vacío
# [INFERENCE] batch_id=21548 rows=0
# [INFERENCE] batch_id=21548 vacío
# [INFERENCE] batch_id=21549 rows=0
# [INFERENCE] batch_id=21549 vacío
# [INFERENCE] batch_id=21550 rows=0
# [INFERENCE] batch_id=21550 vacío
# [INFERENCE] batch_id=21551 rows=0
# [INFERENCE] batch_id=21551 vacío
# [INFERENCE] batch_id=21552 rows=0
# [INFERENCE] batch_id=21552 vacío
# [INFERENCE] batch_id=21553 rows=0
# [INFERENCE] batch_id=21553 vacío
# [INFERENCE] batch_id=21554 rows=0
# [INFERENCE] batch_id=21554 vacío
# [INFERENCE] batch_id=21555 rows=0
# [INFERENCE] batch_id=21555 vacío
# [INFERENCE] batch_id=21556 rows=0
# [INFERENCE] batch_id=21556 vacío
# [INFERENCE] batch_id=21557 rows=0
# [INFERENCE] batch_id=21557 vacío
# [INFERENCE] batch_id=21558 rows=0
# [INFERENCE] batch_id=21558 vacío
# [INFERENCE] batch_id=21559 rows=0
# [INFERENCE] batch_id=21559 vacío
# [INFERENCE] batch_id=21560 rows=0
# [INFERENCE] batch_id=21560 vacío
# [INFERENCE] batch_id=21561 rows=0
# [INFERENCE] batch_id=21561 vacío
# [INFERENCE] batch_id=21562 rows=0
# [INFERENCE] batch_id=21562 vacío
# [INFERENCE] batch_id=21563 rows=0
# [INFERENCE] batch_id=21563 vacío
# [INFERENCE] batch_id=21564 rows=0
# [INFERENCE] batch_id=21564 vacío
# [INFERENCE] batch_id=21565 rows=0
# [INFERENCE] batch_id=21565 vacío
# [INFERENCE] batch_id=21566 rows=0
# [INFERENCE] batch_id=21566 vacío
# [INFERENCE] batch_id=21567 rows=0
# [INFERENCE] batch_id=21567 vacío
# [INFERENCE] batch_id=21568 rows=0
# [INFERENCE] batch_id=21568 vacío
# [INFERENCE] batch_id=21569 rows=0
# [INFERENCE] batch_id=21569 vacío
# [INFERENCE] batch_id=21570 rows=0
# [INFERENCE] batch_id=21570 vacío
# [INFERENCE] batch_id=21571 rows=0
# [INFERENCE] batch_id=21571 vacío
# [INFERENCE] batch_id=21572 rows=0
# [INFERENCE] batch_id=21572 vacío
# [INFERENCE] batch_id=21573 rows=0
# [INFERENCE] batch_id=21573 vacío
# [INFERENCE] batch_id=21574 rows=0
# [INFERENCE] batch_id=21574 vacío
# [INFERENCE] batch_id=21575 rows=0
# [INFERENCE] batch_id=21575 vacío
# [INFERENCE] batch_id=21576 rows=0
# [INFERENCE] batch_id=21576 vacío
# [INFERENCE] batch_id=21577 rows=0
# [INFERENCE] batch_id=21577 vacío
# [INFERENCE] batch_id=21578 rows=0
# [INFERENCE] batch_id=21578 vacío
# [INFERENCE] batch_id=21579 rows=0
# [INFERENCE] batch_id=21579 vacío
# [INFERENCE] batch_id=21580 rows=0
# [INFERENCE] batch_id=21580 vacío
# [INFERENCE] batch_id=21581 rows=0
# [INFERENCE] batch_id=21581 vacío
# [INFERENCE] batch_id=21582 rows=0
# [INFERENCE] batch_id=21582 vacío
# [INFERENCE] batch_id=21583 rows=0
# [INFERENCE] batch_id=21583 vacío
# [INFERENCE] batch_id=21584 rows=0
# [INFERENCE] batch_id=21584 vacío
# [INFERENCE] batch_id=21585 rows=0
# [INFERENCE] batch_id=21585 vacío
# [INFERENCE] batch_id=21586 rows=0
# [INFERENCE] batch_id=21586 vacío
# [INFERENCE] batch_id=21587 rows=0
# [INFERENCE] batch_id=21587 vacío
# [INFERENCE] batch_id=21588 rows=0
# [INFERENCE] batch_id=21588 vacío
# [INFERENCE] batch_id=21589 rows=0
# [INFERENCE] batch_id=21589 vacío
# [INFERENCE] batch_id=21590 rows=0
# [INFERENCE] batch_id=21590 vacío
# [INFERENCE] batch_id=21591 rows=0
# [INFERENCE] batch_id=21591 vacío
# [INFERENCE] batch_id=21592 rows=0
# [INFERENCE] batch_id=21592 vacío
# [INFERENCE] batch_id=21593 rows=0
# [INFERENCE] batch_id=21593 vacío
# [INFERENCE] batch_id=21594 rows=0
# [INFERENCE] batch_id=21594 vacío
# [INFERENCE] batch_id=21595 rows=0
# [INFERENCE] batch_id=21595 vacío
# [INFERENCE] batch_id=21596 rows=0
# [INFERENCE] batch_id=21596 vacío
# [INFERENCE] batch_id=21597 rows=0
# [INFERENCE] batch_id=21597 vacío
# [INFERENCE] batch_id=21598 rows=0
# [INFERENCE] batch_id=21598 vacío
# [INFERENCE] batch_id=21599 rows=0
# [INFERENCE] batch_id=21599 vacío
